# %%
import os
import json
import random
import statistics as stats

# %% [markdown]
# Source: https://www-cs-faculty.stanford.edu/~knuth/sgb.html

# %%
with open("sgb-words.txt", "r") as f:
    words = [w for w in f.read().split("\n") if len(w) == 5]
print(len(words))
print(words[:10])
# Out:
# 5757
# ['which', 'there', 'their', 'about', 'would', 'these', 'other', 'words', 'could', 'write']

# %%
def test_wordle_guess(guess, answer):
    print(guess, answer)
    
    green = {}
    yellow = set()
    red = set()
    bad_duplicates = {}
    good_duplicates = {}
    
    current_chars = []
    
    for i in range(5):
        q_char = guess[i]
        current_chars.append(q_char)
        
        if (q_char in bad_duplicates) or (q_char in red):
            # Letter already used and not present, skip
            continue
        
        if not q_char in answer:
            # Character is not in word
            print(f"Character not present: {q_char}")
            red.add(q_char)
            continue
            
        if answer[i] == q_char:
            # Character is present, and in correct place
            print(f"Character correctly placed: {q_char}, {i}")
            green[i] = q_char
            continue
            
        # Check whether it is a duplicate letter
        guess_count = current_chars.count(q_char)
        answer_count = answer.count(q_char)
        print(f"Guess count: {guess_count}, Answer count: {answer_count}")
        if answer_count < guess_count:
            # Letter is a duplicate, and the subsequent one is not in answer
            print(f"Bad duplicate letter: {q_char}, {guess_count}")
            bad_duplicates[q_char] = guess_count
            continue
        elif guess_count > 1:
            good_duplicates[q_char] = guess_count
            
        # Letter must be present in answer, but in wrong place.
        print(f"Letter incorrectly placed: {q_char}, {i}")
        yellow.add( (q_char, i) )
        continue
        
    return (green, yellow, red, bad_duplicates, good_duplicates)


def wordle_guess(guess, answer):
    green = {}
    yellow = set()
    red = set()
    bad_duplicates = {}
    good_duplicates = {}
    
    current_chars = []
    
    for i in range(5):
        q_char = guess[i]
        current_chars.append(q_char)
        
        if (q_char in bad_duplicates) or (q_char in red):
            # Letter already used and not present, skip
            continue
        
        if not q_char in answer:
            # Character is not in word
            red.add(q_char)
            continue
            
        if answer[i] == q_char:
            # Character is present, and in correct place
            green[i] = q_char
            continue
            
        # Check whether it is a duplicate letter
        guess_count = current_chars.count(q_char)
        answer_count = answer.count(q_char)
        if answer_count < guess_count:
            # Letter is a duplicate, and the subsequent one is not in answer
            bad_duplicates[q_char] = guess_count
            continue
        elif guess_count > 1:
            good_duplicates[q_char] = guess_count
            
        # Letter must be present in answer, but in wrong place.
        yellow.add( (q_char, i) )
        continue
        
    return (green, yellow, red, bad_duplicates, good_duplicates)

# %%
info = test_wordle_guess("henna", "banal")
print(info)
# Out:
# henna banal
# Character not present: h
# Character not present: e
# Character correctly placed: n, 2
# Guess count: 2, Answer count: 1
# Bad duplicate letter: n, 2
# Guess count: 1, Answer count: 2
# Letter incorrectly placed: a, 4
# ({2: 'n'}, {('a', 4)}, {'h', 'e'}, {'n': 2}, {})

# %%
def test_filter_words(word_list, green, yellow, red, bad_dupes, good_dupes):
    fwl = word_list
    
    print("Green:", green)
    print("Yellow:", yellow)
    print("Red:", red)
    
    for i in green:
        print("green", green[i])
        fwl = [w for w in fwl if w[i]==green[i]]
        
    print(fwl)
        
    for tup in yellow:
        char = tup[0]
        loc = tup[1]
        fwl = [w for w in fwl if (char in w) and (w[loc]!=char)]
        
    print(fwl)
    
    for r in red:
        print("red:", r)
        fwl = [w for w in fwl if r not in w]
        
    print(fwl)
        
    for b in bad_dupes:
        print("bad_dupes:", b)
        fwl = [w for w in fwl if w.count(b) < bad_dupes[b]]
        
    print(fwl)
        
    for g in good_dupes:
        print("good_dupes:", g)
        fwl = [w for w in fwl if w.count(g) >= good_dupes[g]]
        
    print(fwl)
    
    
def filter_words(word_list, green, yellow, red, bad_dupes, good_dupes):
    fwl = word_list
    
    for i in green:
        fwl = [w for w in fwl if w[i]==green[i]]
        
    for tup in yellow:
        char = tup[0]
        loc = tup[1]
        fwl = [w for w in fwl if (char in w) and (w[loc]!=char)]
    
    for r in red:
        fwl = [w for w in fwl if r not in w]
        
    for b in bad_dupes:
        fwl = [w for w in fwl if w.count(b) < bad_dupes[b]]
        
    for g in good_dupes:
        fwl = [w for w in fwl if w.count(g) >= good_dupes[g]]
        
    return fwl

# %%
if os.path.isfile("guess_values.txt"):
    with open("guess_values.txt", "r") as f:
        results = json.load(f)
else:
    results = []

total = len(words)
start_point = len(results)

try:
    for i in range(start_point, total):
        print(f"\r{i} / {total}", end="")
        guess_results = []
        guess = words[i]

        for j in range(total):
            answer = words[j]
            info = wordle_guess(guess, answer)
            guess_results.append(len(filter_words(words, *info)))

        score = sum(guess_results) / len(guess_results)
        results.append( (guess, score) )
        
except KeyboardInterrupt:
    pass
    
finally:
    with open("guess_values.txt", "w+") as f:
        json.dump(results, f)
    print("\nCurrent values saved.")
# Out:
# 5756 / 5757
# Current values saved.

# %%
len(results)
# Out:
# 5757

# %%
sorted(results, key=lambda x: x[1])
# Out:
# [('tares', 132.53482716692722),
#  ('rates', 135.8108389786347),
#  ('aloes', 136.6463435817266),
#  ('nares', 139.52110474205315),
#  ('tales', 139.53152683689422),
#  ('saner', 142.1780441202015),
#  ('lores', 143.67569914886226),
#  ('reals', 144.41323606044816),
#  ('roles', 144.67795726941114),
#  ('lanes', 148.23223901337502),
#  ('tears', 151.53778009379886),
#  ('riles', 152.89299982629842),
#  ('earls', 153.78513114469342),
#  ('cares', 155.11082160847664),
#  ('nates', 156.03873545249263),
#  ('laser', 156.0467257252041),
#  ('dares', 157.30328295987493),
#  ('raise', 157.40646169880145),
#  ('races', 158.6119506687511),
#  ('nears', 158.65537606392218),
#  ('teals', 158.68316831683168),
#  ('tires', 158.92635052978983),
#  ('stoae', 159.11638005905854),
#  ('tries', 160.36529442417927),
#  ('pares', 160.42782699322564),
#  ('slier', 160.70818134445022),
#  ('stare', 162.0043425395171),
#  ('dates', 163.25812054889698),
#  ('hares', 163.48914365120723),
#  ('dales', 163.70349140177174),
#  ('mares', 164.43894389438944),
#  ('rapes', 164.5984019454577),
#  ('rites', 164.98054542296336),
#  ('earns', 165.54090672225118),
#  ('slate', 165.6197672398819),
#  ('taels', 165.8799722077471),
#  ('sayer', 166.1988883098836),
#  ('sated', 166.34827166927218),
#  ('leans', 166.575125933646),
#  ('antes', 166.89612645475074),
#  ('names', 191.87476116032656),
#  ('dries', 192.16866423484453),
#  ('stole', 192.20861559840193),
#  ('soled', 192.21208963001564),
#  ('acnes', 192.5250998784089),
#  ('tines', 192.56157721035262),
#  ('tesla', 192.68594754212262),
#  ['later', 192.85756470383882],
#  ('takes', 192.86451276706617),
#  ('sarge', 192.8711134271322),
#  ('hires', 192.88917839152336),
#  ('mires', 193.02640264026402),
#  ('roads', 193.53465346534654),
#  ('cotes', 193.68195240576688),
#  ('spare', 193.94354698627757),
#  ('elans', 194.11863817960744),
#  ('gears', 195.02397081813444),
#  ('sonar', 195.0865033871808),
#  ('sawer', 195.53569567483063),
#  ('poles', 195.7031439986104),
#  ('peals', 195.83585200625325),
#  ('kales', 195.83585200625325),
#  ('sired', 195.89178391523362),
#  ('sabre', 195.96612819176656),
#  ('roils', 196.32291123849228),
#  ('tails', 196.34062879972208),
#  ('banes', 196.5407330206705),
#  ('tarns', 196.61368768455793),
#  ('gores', 196.7443112732326),
#  ('share', 196.80163279485842),
#  ('stela', 196.85791210700017),
#  ('raids', 196.895431648428),
#  ('steal', 197.11881188118812),
#  ('osier', 197.6027444849748),
#  ('bears', 197.6072607260726),
#  ('rides', 197.61455619246135),
#  ('sitar', 197.80180649643913),
#  ('peats', 198.03595622720167),
#  ('shoer', 198.22945978808409),
#  ('leaps', 198.75334375542818),
#  ('runes', 198.75994441549418),
#  ('lakes', 198.77766197672398),
#  ('lased', 198.84505819002953),
#  ('rimes', 199.2890394302588),
#  ('bores', 199.5325690463783),
#  ('meals', 199.5506340107695),
#  ('lopes', 199.73788431474728),
#  ('topes', 199.77714087198194),
#  ('rants', 199.99461525099878),
#  ('lyres', 200.0022581205489),
#  ('moles', 200.28295987493487),
#  ('maser', 200.52162584679522),
#  ('heals', 200.55532395344798),
#  ('holes', 200.77175612298072),
#  ('tomes', 201.3981240229286),
#  ('teams', 201.5284002084419),
#  ('ideas', 201.55584505819002),
#  ('doers', 201.60204967865207),
#  ('meats', 201.68473163105784),
#  ('loans', 201.9678652075734),
#  ('alter', 202.03873545249263),
#  ('darts', 202.26142087893),
#  ('stair', 202.56018759770714),
#  ('fates', 202.57269411151643),
#  ('wales', 203.1278443633837),
#  ('robes', 203.36512072259856),
#  ('orate', 203.6083029355567),
#  ('motes', 203.74483237797463),
#  ('noels', 203.74517978113602),
#  ('lards', 203.76150772972034),
#  ('parse', 203.77262463088414),
#  ('slyer', 204.22702796595448),
#  ('apers', 204.43859649122808),
#  ('bries', 204.56991488622546),
#  ('cones', 204.65468125759944),
#  ('rheas', 204.88639916623242),
#  ('hades', 205.0580163279486),
#  ('shier', 205.10074691679694),
#  ('spear', 205.61003995136355),
#  ('tides', 205.64825429911411),
#  ('spier', 205.83724161889873),
#  ('roast', 205.87580336981065),
#  ('sepia', 205.96508598228243),
#  ('sedan', 206.11203751954142),
#  ('spate', 206.15407330206705),
#  ('dames', 206.17943373284697),
#  ('toads', 206.30762549939203),
#  ('shear', 206.37641132534307),
#  ('trans', 206.43755428174396),
#  ('stead', 206.44728157026228),
#  ('stile', 206.5115511551155),
#  ('capes', 207.02813965607086),
#  ('paces', 207.21087371895084),
#  ('riots', 207.21538996004864),
#  ('scale', 207.2268542643738),
#  ('smear', 207.2490880667014),
#  ('tyres', 207.4860170227549),
#  ('risen', 207.6183776272364),
#  ('cites', 207.86051763071043),
#  ('lutes', 207.90637484801113),
#  ('aegis', 208.09258294250478),
#  ('sober', 208.37120027792253),
#  ('heros', 209.43807538648602),
#  ('fears', 209.53152683689422),
#  ('fores', 209.5461177696717),
#  ('raves', 209.80180649643913),
#  ('iotas', 209.80319610908458),
#  ['means', 209.85252735799895],
#  ('pones', 209.9466736147299),
#  ('irate', 210.12176480805977),
#  ('tiros', 210.27288518325517),
#  ('stone', 210.39447628973423),
#  ('loads', 210.67135660934514),
#  ('nodes', 210.76376585026924),
#  ('piles', 211.60691332291123),
#  ('beats', 211.6440854611777),
#  ('maces', 211.9223553934341),
#  ('anise', 212.1669272190377),
#  ('sited', 212.2013201320132),
#  ('wears', 212.26107347576863),
#  ('plies', 212.274622199062),
#  ('selah', 212.3211742226854),
#  ('heats', 212.8565224943547),
#  ('caste', 212.9520583637311),
#  ('baser', 213.03925655723467),
#  ('shale', 213.0632273753691),
#  ('lunes', 213.26541601528575),
#  ('loges', 213.3713739795032),
#  ('ogres', 213.4860170227549),
#  ('pairs', 213.620809449366),
#  ('trios', 213.66770887615078),
#  ('heirs', 213.94632621156853),
#  ('altos', 213.97377106131665),
#  ['miles', 214.08250825082507],
#  ('nails', 214.30797290255342),
#  ('salon', 214.45978808407156),
#  ('saver', 214.5125933645996),
#  ('darns', 214.82803543512247),
#  ('sepal', 214.98019801980197),
#  ('septa', 215.00382143477506),
#  ('cages', 215.12159110647906),
#  ('sable', 215.31057842626367),
#  ('wanes', 215.31162063574777),
#  ('paste', 215.66423484453708),
#  ('lobes', 215.71113427132187),
#  ('score', 215.76498176133404),
#  ('delis', 215.8295987493486),
#  ('ceils', 216.2770540211916),
#  ('oaten', 216.49209657807887),
#  ('liens', 216.74674309536218),
#  ('limes', 216.8843147472642),
#  ('sauce', 217.07087024491923),
#  ('poser', 217.38075386486017),
#  ('betas', 217.78130970991836),
#  ('spore', 217.81396560708703),
#  ('idles', 218.06062185165885),
#  ('oiler', 218.1113427132187),
#  ('stied', 218.3715476810839),
#  ('strep', 218.79850616640613),
#  ['times', 218.85026923745005],
#  ('razes', 218.93573041514676),
#  ('teaks', 219.627410109432),
#  ('hones', 219.64790689595276),
#  ('roams', 219.79277401424352),
#  ('hairs', 219.89039430258816),
#  ('cures', 219.9310404724683),
#  ('wires', 220.08945631405246),
#  ('tokes', 220.29511898558277),
#  ('snarl', 220.9075907590759),
#  ('fires', 220.9652596838631),
#  ('tunes', 221.0635747785305),
#  ('mites', 221.29112384922703),
#  ('rouse', 221.39291297550807),
#  ('shore', 221.62428348097967),
#  ('beans', 221.99253083203058),
#  ('terms', 222.00955358693764),
#  ('onset', 222.22529095014764),
#  ('dials', 222.2346708355046),
#  ('vales', 222.66058711134272),
#  ('fries', 222.66162932082682),
#  ('toils', 222.81483411499045),
#  ('oared', 222.84262636789995),
#  ('leaks', 223.04585721730066),
#  ('sware', 223.0601007469168),
#  ('hoars', 223.264721208963),
#  ('stern', 223.52318916102138),
#  ('doser', 223.67813097099184),
#  ('learn', 223.7184297377106),
#  ('piers', 223.9567483064096),
#  ('pleas', 224.52336286260206),
#  ('hoers', 224.54524926176828),
#  ('caret', 224.69532742747958),
#  ('tared', 224.7099183602571),
#  ('nards', 224.74326906374847),
#  ('coset', 224.7463956922008),
#  ('tiler', 224.83845752996353),
#  ('rands', 225.11325343060622),
#  ('noise', 225.24978287302415),
#  ('biles', 225.47455271842975),
#  ('laves', 225.48358520062533),
#  ('bones', 225.48983845752997),
#  ('codes', 225.49331248914365),
#  ('socle', 225.634010769498),
#  ('pages', 225.71217648080597),
#  ('spiel', 225.88726767413584),
#  ('meads', 225.90394302588155),
#  ('resay', 225.91471252388396),
#  ('nerds', 225.93069306930693),
#  ('saint', 226.09605697411845),
#  ('spire', 226.2214695153726),
#  ('sower', 226.29511898558277),
#  ('heads', 226.41323606044816),
#  ('skate', 226.46083029355566),
#  ('carts', 226.47368421052633),
#  ('dines', 226.59214868855307),
#  ('agues', 226.62654160152857),
#  ('lapse', 226.7029702970297),
#  ('loner', 226.76237623762376),
#  ('hames', 226.80580163279487),
#  ('gapes', 226.839847142609),
#  ('islet', 226.84505819002953),
#  ('rinse', 227.09379885356958),
#  ('rends', 227.17509119332985),
#  ('suite', 227.52249435469864),
#  ('poset', 227.7840889352093),
#  ('skier', 227.8518325516762),
#  ('resin', 227.98593017196455),
#  ('stage', 228.17422268542643),
#  ('weals', 228.29095014764636),
#  ('diets', 228.42087892999825),
#  ('pines', 228.43199583116206),
#  ('alert', 228.5494180997047),
#  ('shire', 228.866249782873),
#  ('leafs', 228.94163626889005),
#  ('acmes', 228.97915581031788),
#  ('goers', 229.05627931214175),
#  ('ogles', 229.11742226854264),
#  ('sidle', 229.11776967170402),
#  ('feats', 229.38978634705575),
#  ('bites', 229.529442417926),
#  ('marls', 229.69306930693068),
#  ('fades', 229.92166058711135),
#  ('ousel', 230.1023102310231),
#  ('haste', 230.1200277922529),
#  ('slide', 230.32464825429912),
#  ('coals', 230.46916796942853),
#  ('sales', 230.76515546291472),
#  ('toner', 230.88084071565052),
#  ('floes', 230.9777661976724),
#  ('paler', 231.055584505819),
#  ('coats', 231.26402640264027),
#  ('roids', 231.3484453708529),
#  ('alien', 231.5106826472121),
#  ('peons', 231.65867639395518),
#  ('games', 232.01268021538996),
#  ('cafes', 232.01754385964912),
#  ['parts', 232.4194893173528],
#  ('cased', 232.5004342539517),
#  ('vanes', 232.54038561750912),
#  ('dents', 232.5640090324822),
#  ('dopes', 232.6876845579295),
#  ('renal', 232.7252040993573),
#  ('rated', 232.9055063401077),
#  ('tacos', 232.9079381622373),
#  ('lends', 233.03300330033002),
#  ('taxes', 233.4405072086156),
#  ('aired', 233.44849748132708),
#  ('haler', 233.4703838804933),
#  ('dater', 233.5270105957964),
#  ('caner', 243.56036129928782),
#  ('alone', 243.58884835852007),
#  ('slued', 243.5919749869724),
#  ('halos', 243.76949800243182),
#  ('cents', 243.9421573736321),
#  ('aider', 243.9588327253778),
#  ('siree', 244.02640264026402),
#  ('wiles', 244.24995657460482),
#  ('prats', 244.59735973597358),
#  ('lands', 244.61021365294425),
#  ('loams', 244.6473857912107),
#  ('pause', 244.65051241966302),
#  ('louse', 244.72103526142087),
#  ('latus', 244.72346708355047),
#  ('hails', 244.81761334028138),
#  ('vires', 244.8509640437728),
#  ('snail', 244.99791558103178),
#  ('trade', 245.26367899947888),
#  ('trays', 245.3025881535522),
#  ('rears', 245.60100746916797),
#  ('anole', 246.05402119159285),
#  ('cause', 246.20896300156332),
#  ('traps', 246.2881709223554),
#  ('lotsa', 246.32325864165364),
#  ('staid', 246.32638527010596),
#  ('mater', 246.3805801632795),
#  ('lamer', 246.4094146256731),
#  ('beast', 246.50425568872677),
#  ('shoed', 246.5240576689248),
#  ('arses', 246.7062706270627),
#  ('fames', 246.9364252214695),
#  ('harts', 247.0302240750391),
#  ('loins', 247.11290602744484),
#  ('files', 247.25117248566963),
#  ('autos', 247.25221469515373),
#  ('sires', 247.27097446586765),
#  ('serif', 247.53569567483063),
#  ('gaols', 247.63331596317528),
#  ('mails', 247.6739621330554),
#  ('veals', 247.7351050894563),
#  ('yarns', 247.898731978461),
#  ('liner', 248.04498870939724),
#  ('fairs', 248.10508945631406),
#  ('aimer', 248.23432343234325),
#  ('adore', 248.2857391002258),
#  ('litre', 248.31839499739448),
#  ('atone', 248.33958659023799),
#  ('flies', 248.4048983845753),
#  ('toves', 248.46673614729895),
#  ('lions', 248.6876845579295),
#  ('trams', 248.6963696369637),
#  ('doest', 248.7453534827167),
#  ('dealt', 248.76550286607608),
#  ('hater', 248.84644780267502),
#  ('horse', 248.87945110300504),
#  ('janes', 249.11533784957444),
#  ('axles', 249.51867291992357),
#  ('talcs', 249.77992009727288),
#  ('stein', 250.01268021538996),
#  ('asker', 250.1523362862602),
#  ('spite', 250.22876498176134),
#  ('cards', 250.3903074517978),
#  ('salve', 250.4427653291645),
#  ('slime', 250.46951537258988),
#  ('emirs', 250.5094667361473),
#  ('alder', 250.5237102657634),
#  ('noire', 250.67552544728156),
#  ('nosed', 250.78356783046726),
#  ('goats', 250.83463609518847),
#  ('waste', 250.97950321347923),
#  ('tapis', 250.98054542296336),
#  ('space', 251.06114295640091),
#  ('scone', 251.3647733194372),
#  ('torus', 251.4224422442244),
#  ('votes', 251.53048462741012),
#  ('swore', 251.7653291644954),
#  ('heaps', 251.93520931040473),
#  ('lapis', 252.009900990099),
#  ('bodes', 252.18568698975162),
#  ('sutra', 252.1957616814313),
#  ('penis', 252.22980719124544),
#  ('smite', 252.24231370505473),
#  ('loves', 252.27323258641653),
#  ('boats', 252.27531700538475),
#  ('doges', 252.30449887093974),
#  ('snort', 252.45770366510337),
#  ('avers', 252.4851485148515),
#  ('prise', 252.50668751085635),
#  ('poste', 252.57234670835504),
#  ('routs', 252.6574604828904),
#  ('minas', 290.512940767761),
#  ('amuse', 290.6970644432864),
#  ('honer', 290.77140871981936),
#  ('paled', 290.8943894389439),
#  ('sites', 291.0078165711308),
#  ('tamed', 291.05871113427133),
#  ('dregs', 291.06600660066005),
#  ('girls', 291.09206183776274),
#  ('ayins', 291.10630536737887),
#  ('skied', 291.14729894042034),
#  ('sport', 291.30119854090674),
#  ('germs', 291.3140524578774),
#  ('shake', 291.336286260205),
#  ('acids', 291.36859475421227),
#  ('petal', 291.4123675525447),
#  ('laude', 291.46204620462044),
#  ('gelds', 291.51797811360086),
#  ('stoma', 291.55237102657634),
#  ('screw', 291.676393955185),
#  ('lance', 291.70696543338545),
#  ('glare', 291.7229459788084),
#  ('spent', 291.79694285217994),
#  ('trips', 291.94354698627757),
#  ('craps', 291.9584853222164),
#  ('motel', 292.0224075039083),
#  ('splat', 292.1130797290255),
#  ('clots', 292.2426611082161),
#  ('goest', 292.3701580684384),
#  ('veils', 292.38301198540904),
#  ('blare', 292.4180997047073),
#  ('axels', 292.4392912975508),
#  ('hayer', 292.49487580336984),
#  ('hazes', 292.5674830640959),
#  ('lepta', 292.6074344276533),
#  ('rinds', 292.7279833246483),
#  ('horns', 292.78669445891956),
#  ('afore', 292.8610387354525),
#  ('mazes', 292.9881882925135),
#  ('sepoy', 293.03717213826644),
#  ('unate', 293.160152857391),
#  ['earth', 293.2525620983151],
#  ('pikes', 293.26298419315617),
#  ('padre', 293.3359388570436),
#  ('phase', 293.72398818829254),
#  ('talon', 293.9091540733021),
#  ('flues', 293.970297029703),
#  ('trims', 293.9991314920966),
#  ('opera', 294.08632968560016),
#  ('table', 294.3044988709397),
#  ('trees', 294.4894910543686),
#  ('plane', 294.5907590759076),
#  ('dupes', 294.666492965086),
#  ('blats', 294.6717040125065),
#  ('turns', 294.6932430085114),
#  ('curse', 294.915233628626),
#  ('harps', 295.1021365294424),
#  ('mikes', 295.1500781657113),
#  ('crams', 295.2254646517283),
#  ('yikes', 295.27410109432),
#  ('timer', 295.4894910543686),
#  ('haled', 295.50651380927565),
#  ('cadre', 295.5808580858086),
#  ('meson', 295.59753343755426),
#  ...]

# %%
def random_word():
    value = int(random.random() * len(words))
    return words[value]


def get_word_scores(all_words, remaining_words, current_info=None):
    results = []
    for assumed_guess in all_words:
        guess_results = []
        for assumed_answer in remaining_words:
            guess_info = wordle_guess(assumed_guess, assumed_answer)
            assumed_info = merge_guess_info(guess_info, current_info)
            assumed_remaining_words = filter_words(remaining_words, (*assumed_info))
            guess_results.append(len(assumed_remaining_words))
        
        score = sum(guess_results) / len(guess_results)
        results.append( (assumed_guess, score) )
        
    return sorted(results, key=lambda x: x[1])


def merge_guess_info(info1, info2):
    default_info = ({}, {}, set(), {}, {})
    
    if info1 == None:
        info1 = default_info
    if info2 == None:
        info2 = default_info
        
    # Merge Greens
    green = {**info1[0], **info2[0]}
    
    # Merge Yellows
    yellow = info1[1].union(info2[1])
    
    # Merge Reds
    red = info1[2].union(info2[2])
    
    # Merge bad_dupes
    bad_dupes = {**info1[3], **info2[3]}
    
    # Merge good_dupes
    good_dupes = info1[4]
    for key in info2[4]:
        if key in good_dupes:
            good_dupes[key] = max(good_dupes[key], info2[4][key])
        else:
            good_dupes[key] = info2[4][key]

    return (green, yellow, red, bad_dupes, good_dupes)
    
        

def work_out_word(answer, print_guesses=False):
    guess = "tares"
    remaining_words = words
    guess_info = None
    guesses = []
    
    while True:
        if print_guesses:
            print(guess)
        guesses.append(guess)
        guess_info = merge_guess_info(wordle_guess(guess, answer), guess_info)
        remaining_words = filter_words(remaining_words, *guess_info)
        if len(remaining_words) == 1:
            guesses.append(remaining_words[0])
            if print_guesses:
                print(f"Final Guess: {remaining_words[0]}")
                print(f"Number of guesses: {len(guesses)}")
            return len(guesses)
        else:
            word_scores = get_word_scores(words, remaining_words, guess_info)
            guess = sorted(word_scores, key=lambda x: x[1])[0][0]

# %% [markdown]
# #### Test 1

# %%
answer = random_word()
guess = "tares"
guess_info = merge_guess_info(wordle_guess(guess, answer), None)
remaining_words = filter_words(words, *guess_info)
remaining_words
# Out:
# ['steps',
#  'cents',
#  'items',
#  'stems',
#  'nests',
#  'poets',
#  'belts',
#  'melts',
#  'debts',
#  'beets',
#  'meets',
#  'pests',
#  'pelts',
#  'diets',
#  'exits',
#  'sects',
#  'vents',
#  'fetus',
#  'stews',
#  'dents',
#  'duets',
#  'felts',
#  'emits',
#  'welts',
#  'jests',
#  'edits',
#  'vests',
#  'lefts',
#  'zests',
#  'bests',
#  'hefts',
#  'suets',
#  'whets',
#  'newts',
#  'ethos',
#  'gents',
#  'bents',
#  'stets',
#  'beths',
#  'wefts',
#  'wests']

# %%
word_scores = get_word_scores(remaining_words, guess_info)
print(word_scores)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('nests', 7.7317073170731705), ('bents', 8.170731707317072), ('newts', 8.463414634146341), ('bests', 8.560975609756097), ('wests', 8.609756097560975), ('belts', 8.804878048780488), ('welts', 8.902439024390244), ('dents', 9.292682926829269), ('pests', 10.073170731707316), ('felts', 10.21951219512195), ('lefts', 10.21951219512195), ('wefts', 10.21951219512195), ('cents', 10.268292682926829), ('vents', 10.268292682926829), ('melts', 10.365853658536585), ('pelts', 10.463414634146341), ('vests', 10.658536585365853), ('debts', 10.902439024390244), ('gents', 11.097560975609756), ('beets', 11.195121951219512), ('jests', 11.487804878048781), ('zests', 11.487804878048781), ('diets', 12.365853658536585), ('whets', 12.609756097560975), ('beths', 12.902439024390244), ('hefts', 12.951219512195122), ('meets', 13.536585365853659), ('duets', 14.21951219512195), ('stews', 14.268292682926829), ('sects', 14.658536585365853), ('fetus', 14.658536585365853), ('items', 15.146341463414634), ('poets', 15.731707317073171), ('steps', 16.317073170731707), ('stems', 16.317073170731707), ('suets', 16.317073170731707), ('stets', 17.78048780487805), ('edits', 18.804878048780488), ('emits', 19.829268292682926), ('ethos', 20.21951219512195), ('exits', 22.75609756097561)]
# [('nests', 7.7317073170731705),
#  ('bents', 8.170731707317072),
#  ('newts', 8.463414634146341),
#  ('bests', 8.560975609756097),
#  ('wests', 8.609756097560975),
#  ('belts', 8.804878048780488),
#  ('welts', 8.902439024390244),
#  ('dents', 9.292682926829269),
#  ('pests', 10.073170731707316),
#  ('felts', 10.21951219512195),
#  ('lefts', 10.21951219512195),
#  ('wefts', 10.21951219512195),
#  ('cents', 10.268292682926829),
#  ('vents', 10.268292682926829),
#  ('melts', 10.365853658536585),
#  ('pelts', 10.463414634146341),
#  ('vests', 10.658536585365853),
#  ('debts', 10.902439024390244),
#  ('gents', 11.097560975609756),
#  ('beets', 11.195121951219512),
#  ('jests', 11.487804878048781),
#  ('zests', 11.487804878048781),
#  ('diets', 12.365853658536585),
#  ('whets', 12.609756097560975),
#  ('beths', 12.902439024390244),
#  ('hefts', 12.951219512195122),
#  ('meets', 13.536585365853659),
#  ('duets', 14.21951219512195),
#  ('stews', 14.268292682926829),
#  ('sects', 14.658536585365853),
#  ('fetus', 14.658536585365853),
#  ('items', 15.146341463414634),
#  ('poets', 15.731707317073171),
#  ('steps', 16.317073170731707),
#  ('stems', 16.317073170731707),
#  ('suets', 16.317073170731707),
#  ('stets', 17.78048780487805),
#  ('edits', 18.804878048780488),
#  ('emits', 19.829268292682926),
#  ('ethos', 20.21951219512195),
#  ('exits', 22.75609756097561)]

# %%
guess2 = "nests"
guess_info = merge_guess_info(guess_info, wordle_guess(guess2, answer))
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ['cents', 'vents', 'dents', 'gents', 'bents']

# %% [markdown]
# So if we only consider words that might be the answer (i.e. Hard Mode), we can end up in a situation where there is one letter missing that could be any of a handful of letters, with no way to eliminate them other than try them all. This can easily take us over the 6 guess limit. Therefore, we need to check the Expected Value of EVERY word in the full word list, for every guess. This will presumably take about 4 seconds per iteration, but will give us a much better chance.
#
# EDIT: Okay, it's a lot more than 4 seconds per iteration. This may not be entirely feasible...
#
# EDIT 2: Okay, it's fine. A run only takes up to about a minute.

# %% [markdown]
# #### Test 2

# %%
guess = "tares"
guess_info = merge_guess_info(wordle_guess(guess, answer), None)
remaining_words = filter_words(words, *guess_info)
remaining_words
# Out:
# ['steps',
#  'cents',
#  'items',
#  'stems',
#  'nests',
#  'poets',
#  'belts',
#  'melts',
#  'debts',
#  'beets',
#  'meets',
#  'pests',
#  'pelts',
#  'diets',
#  'exits',
#  'sects',
#  'vents',
#  'fetus',
#  'stews',
#  'dents',
#  'duets',
#  'felts',
#  'emits',
#  'welts',
#  'jests',
#  'edits',
#  'vests',
#  'lefts',
#  'zests',
#  'bests',
#  'hefts',
#  'suets',
#  'whets',
#  'newts',
#  'ethos',
#  'gents',
#  'bents',
#  'stets',
#  'beths',
#  'wefts',
#  'wests']

# %%
word_scores = get_word_scores(words, remaining_words, guess_info)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('lento', 6.951219512195122),
#  ('blend', 7.048780487804878),
#  ('sense', 7.195121951219512),
#  ('plein', 7.2926829268292686),
#  ('fiend', 7.536585365853658),
#  ('newel', 7.536585365853658),
#  ('below', 7.634146341463414),
#  ('meson', 7.634146341463414),
#  ('nests', 7.7317073170731705),
#  ('wield', 7.780487804878049),
#  ('mesne', 7.975609756097561),
#  ('lemon', 8.024390243902438),
#  ('melon', 8.024390243902438),
#  ('mufti', 12.951219512195122),
#  ('redly', 12.951219512195122),
#  ('doeth', 12.951219512195122),
#  ('login', 12.951219512195122),
#  ('scene', 13.0),
#  ('finds', 13.0),
#  ('steal', 13.0),
#  ('sells', 13.0),
#  ('teens', 13.0),
#  ('scold', 13.0),
#  ('fined', 13.0),
#  ('bossy', 13.0),
#  ('sidle', 13.0),
#  ('snubs', 13.0),
#  ('serif', 13.0),
#  ('teeny', 13.0),
#  ('legit', 13.0),
#  ('bossa', 13.0),
#  ('milch', 13.0),
#  ('solum', 13.0),
#  ('keens', 13.0),
#  ('sahib', 13.0),
#  ('eland', 13.0),
#  ('stela', 13.0),
#  ('winds', 13.048780487804878),
#  ('issue', 13.048780487804878),
#  ('freed', 13.048780487804878),
#  ('windy', 13.048780487804878),
#  ('wilds', 13.048780487804878),
#  ('filch', 13.048780487804878),
#  ('basso', 13.048780487804878),
#  ('wined', 13.048780487804878),
#  ('wiled', 13.048780487804878),
#  ('lions', 13.097560975609756),
#  ('punch', 13.097560975609756),
#  ('cello', 13.097560975609756),
#  ('hyena', 13.097560975609756),
#  ('mulch', 13.097560975609756),
#  ('bingo', 13.097560975609756),
#  ('hells', 13.097560975609756),
#  ('zebus', 13.097560975609756),
#  ('blips', 13.097560975609756),
#  ('pismo', 13.097560975609756),
#  ('liest', 13.097560975609756),
#  ('liers', 13.097560975609756),
#  ('bebug', 13.097560975609756),
#  ('death', 13.146341463414634),
#  ('bound', 13.146341463414634),
#  ('dusty', 13.146341463414634),
#  ('tents', 13.146341463414634),
#  ('leash', 13.146341463414634),
#  ('dusts', 13.146341463414634),
#  ('feces', 13.146341463414634),
#  ('while', 13.195121951219512),
#  ('fever', 13.195121951219512),
#  ('whirl', 13.195121951219512),
#  ('rosin', 13.195121951219512),
#  ('unzip', 13.195121951219512),
#  ('amens', 13.195121951219512),
#  ('fusty', 13.195121951219512),
#  ('fossa', 13.195121951219512),
#  ('fosse', 13.195121951219512),
#  ('thens', 13.195121951219512),
#  ('swept', 13.24390243902439),
#  ('noble', 13.24390243902439),
#  ('reins', 13.24390243902439),
#  ('seals', 13.24390243902439),
#  ('lifts', 13.24390243902439),
#  ('widen', 13.24390243902439),
#  ('snobs', 13.24390243902439),
#  ('spews', 13.24390243902439),
#  ('flits', 13.24390243902439),
#  ('fells', 13.24390243902439),
#  ('hilts', 13.24390243902439),
#  ('nobly', 13.24390243902439),
#  ('fella', 13.24390243902439),
#  ('mould', 13.24390243902439),
#  ('septa', 13.24390243902439),
#  ('humpf', 13.24390243902439),
#  ('feral', 13.24390243902439),
#  ('refly', 13.24390243902439),
#  ('found', 13.292682926829269),
#  ('built', 13.292682926829269),
#  ('piece', 13.292682926829269),
#  ('fungi', 13.292682926829269),
#  ('trend', 13.292682926829269),
#  ('genes', 13.292682926829269),
#  ('sneer', 13.292682926829269),
#  ('knead', 13.292682926829269),
#  ('chefs', 13.292682926829269),
#  ('genre', 13.292682926829269),
#  ('pesky', 13.292682926829269),
#  ('latin', 13.292682926829269),
#  ('pinup', 13.292682926829269),
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ['cents', 'vents', 'dents', 'gents', 'bents']

# %%
word_scores = get_word_scores(words, remaining_words, guess_info)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('budge', 1.4),
#  ('badge', 1.4),
#  ('caged', 1.4),
#  ('cubed', 1.4),
#  ('caved', 1.4),
#  ('debug', 1.4),
#  ('cadge', 1.4),
#  ('gibed', 1.4),
#  ('bodge', 1.4),
#  ('vocab', 1.4),
#  ('gyved', 1.4),
#  ('could', 2.2),
#  ('being', 2.2),
#  ('began', 2.2),
#  ('above', 2.2),
#  ('given', 2.2),
#  ('black', 2.2),
#  ('voice', 2.2),
#  ('lived', 2.2),
#  ('bring', 2.2),
#  ('birds', 2.2),
#  ('moved', 2.2),
#  ('doing', 2.2),
#  ('cried', 2.2),
#  ('begin', 2.2),
#  ('child', 2.2),
#  ('build', 2.2),
#  ('blood', 2.2),
#  ('gives', 2.2),
#  ('board', 2.2),
#  ('cover', 2.2),
#  ('dance', 2.2),
#  ('basic', 2.2),
#  ('drive', 2.2),
#  ('bread', 2.2),
#  ('verbs', 2.2),
#  ('based', 2.2),
#  ('goods', 2.2),
#  ('crowd', 2.2),
#  ('loved', 2.2),
#  ('drove', 2.2),
#  ('cabin', 2.2),
#  ('doubt', 2.2),
#  ('guide', 2.2),
#  ('block', 2.2),
#  ('cloud', 2.2),
#  ('broad', 2.2),
#  ('beach', 2.2),
#  ('saved', 2.2),
#  ('avoid', 2.2),
#  ('edges', 2.2),
#  ('magic', 2.2),
#  ('chord', 2.2),
#  ('brave', 2.2),
#  ('climb', 2.2),
#  ('globe', 2.2),
#  ('judge', 2.2),
#  ('begun', 2.2),
#  ('bound', 2.2),
#  ('candy', 2.2),
#  ('curve', 2.2),
#  ('blind', 2.2),
#  ('guard', 2.2),
#  ('cards', 2.2),
#  ('grade', 2.2),
#  ('digit', 2.2),
#  ('badly', 2.2),
#  ('faced', 2.2),
#  ('raced', 2.2),
#  ('waved', 2.2),
#  ('blend', 2.2),
#  ('bench', 2.2),
#  ('bands', 2.2),
#  ('civil', 2.2),
#  ('blade', 2.2),
#  ('ducks', 2.2),
#  ('brick', 2.2),
#  ('beads', 2.2),
#  ('grand', 2.2),
#  ('dying', 2.2),
#  ('drugs', 2.2),
#  ('bunch', 2.2),
#  ('grace', 2.2),
#  ('grave', 2.2),
#  ('urged', 2.2),
#  ('vocal', 2.2),
#  ('bacon', 2.2),
#  ('cargo', 2.2),
#  ('acted', 2.2),
#  ('backs', 2.2),
#  ('beard', 2.2),
#  ('cubic', 2.2),
#  ('baked', 2.2),
#  ('clubs', 2.2),
#  ('ridge', 2.2),
#  ('devil', 2.2),
#  ('bowed', 2.2),
#  ('diver', 2.2),
#  ('vivid', 2.2),
#  ('decay', 2.2),
#  ('bride', 2.2),
#  ('bonds', 2.2),
#  ('crude', 2.2),
#  ('voted', 2.2),
#  ('caves', 2.2),
#  ('cared', 2.2),
#  ('bends', 2.2),
#  ('cable', 2.2),
#  ('gazed', 2.2),
#  ('cubes', 2.2),
#  ('rigid', 2.2),
#  ('brand', 2.2),
#  ('ditch', 2.2),
#  ('cords', 2.2),
#  ('ledge', 2.2),
#  ('dived', 2.2),
#  ('clung', 2.2),
#  ('breed', 2.2),
#  ('bored', 2.2),
#  ('acids', 2.2),
#  ('dough', 2.2),
#  ('valid', 2.2),
#  ('vague', 2.2),
#  ('buggy', 2.2),
#  ('codes', 2.2),
#  ('lodge', 2.2),
#  ('paved', 2.2),
#  ('bugle', 2.2),
#  ('debts', 2.2),
#  ('glove', 2.2),
#  ('docks', 2.2),
#  ('cedar', 2.2),
#  ('cages', 2.2),
#  ('barge', 2.2),
#  ('scrub', 2.2),
#  ('crabs', 2.2),
#  ('logic', 2.2),
#  ('adobe', 2.2),
#  ('grind', 2.2),
#  ('cling', 2.2),
#  ('grove', 2.2),
#  ('brace', 2.2),
#  ('hedge', 2.2),
#  ('cigar', 2.2),
#  ('wedge', 2.2),
#  ('cough', 2.2),
#  ('vigor', 2.2),
#  ('cured', 2.2),
#  ('gland', 2.2),
#  ('birch', 2.2),
#  ('blond', 2.2),
#  ('glued', 2.2),
#  ('carve', 2.2),
#  ('ached', 2.2),
#  ('raged', 2.2),
#  ('glide', 2.2),
#  ('decks', 2.2),
#  ('brood', 2.2),
#  ('edged', 2.2),
#  ('civic', 2.2),
#  ('bevel', 2.2),
#  ('doves', 2.2),
#  ('cited', 2.2),
#  ('abide', 2.2),
#  ('fudge', 2.2),
#  ('gravy', 2.2),
#  ('beech', 2.2),
#  ('bough', 2.2),
#  ('paced', 2.2),
#  ('braid', 2.2),
#  ('discs', 2.2),
#  ('cider', 2.2),
#  ('curds', 2.2),
#  ('bulge', 2.2),
#  ('drags', 2.2),
#  ('icing', 2.2),
#  ('scold', 2.2),
#  ('ducts', 2.2),
#  ('nudge', 2.2),
#  ('debut', 2.2),
#  ('dives', 2.2),
#  ('batch', 2.2),
#  ('greed', 2.2),
#  ('beige', 2.2),
#  ('laced', 2.2),
#  ('dodge', 2.2),
#  ('godly', 2.2),
#  ('colds', 2.2),
#  ('cobra', 2.2),
#  ('vowed', 2.2),
#  ('grubs', 2.2),
#  ('bared', 2.2),
#  ('buddy', 2.2),
#  ('bleed', 2.2),
#  ('baggy', 2.2),
#  ('grabs', 2.2),
#  ('waged', 2.2),
#  ('dingy', 2.2),
#  ('combs', 2.2),
#  ('scuba', 2.2),
#  ('gaudy', 2.2),
#  ('creed', 2.2),
#  ('boxed', 2.2),
#  ('bucks', 2.2),
#  ('caked', 2.2),
#  ('bangs', 2.2),
#  ('gaped', 2.2),
#  ('bland', 2.2),
#  ('vicar', 2.2),
#  ('vexed', 2.2),
#  ('clang', 2.2),
#  ('havoc', 2.2),
#  ('binds', 2.2),
#  ('livid', 2.2),
#  ('vigil', 2.2),
#  ('crags', 2.2),
#  ('cadet', 2.2),
#  ('grids', 2.2),
#  ('covet', 2.2),
#  ('guild', 2.2),
#  ('giddy', 2.2),
#  ('verge', 2.2),
#  ('crumb', 2.2),
#  ('lucid', 2.2),
#  ('clogs', 2.2),
#  ('goody', 2.2),
#  ('bitch', 2.2),
#  ('coded', 2.2),
#  ('clods', 2.2),
#  ('bravo', 2.2),
#  ('gable', 2.2),
#  ('glade', 2.2),
#  ('curbs', 2.2),
#  ('evade', 2.2),
#  ('vogue', 2.2),
#  ('dogma', 2.2),
#  ('edict', 2.2),
#  ('decoy', 2.2),
#  ('derby', 2.2),
#  ('gavel', 2.2),
#  ('adage', 2.2),
#  ('rugby', 2.2),
#  ('aback', 2.2),
#  ('robed', 2.2),
#  ('cooed', 2.2),
#  ('chugs', 2.2),
#  ('booed', 2.2),
#  ('dogie', 2.2),
#  ('brags', 2.2),
#  ('chide', 2.2),
#  ('video', 2.2),
#  ('clove', 2.2),
#  ('dregs', 2.2),
#  ('coves', 2.2),
#  ('cribs', 2.2),
#  ('divan', 2.2),
#  ('vices', 2.2),
#  ('acrid', 2.2),
#  ('baled', 2.2),
#  ('crave', 2.2),
#  ('bogey', 2.2),
#  ('coped', 2.2),
#  ('vying', 2.2),
#  ('scabs', 2.2),
#  ('belch', 2.2),
#  ('civet', 2.2),
#  ('vouch', 2.2),
#  ('bingo', 2.2),
#  ('scald', 2.2),
#  ('covey', 2.2),
#  ('dirge', 2.2),
#  ('bayed', 2.2),
#  ('delve', 2.2),
#  ('embed', 2.2),
#  ('ceded', 2.2),
#  ('bongs', 2.2),
#  ('evict', 2.2),
#  ('jibed', 2.2),
#  ('diced', 2.2),
#  ('rabid', 2.2),
#  ('golds', 2.2),
#  ('boned', 2.2),
#  ('raved', 2.2),
#  ('gumbo', 2.2),
#  ('goads', 2.2),
#  ('deign', 2.2),
#  ('girds', 2.2),
#  ('daubs', 2.2),
#  ('cased', 2.2),
#  ('coeds', 2.2),
#  ('cowed', 2.2),
#  ('roved', 2.2),
#  ('voids', 2.2),
#  ('bused', 2.2),
#  ('bided', 2.2),
#  ('bogie', 2.2),
#  ('scads', 2.2),
#  ('biked', 2.2),
#  ('caned', 2.2),
#  ('dunce', 2.2),
#  ('bigot', 2.2),
#  ('arced', 2.2),
#  ('cored', 2.2),
#  ('clued', 2.2),
#  ('cupid', 2.2),
#  ('sedge', 2.2),
#  ('dices', 2.2),
#  ('cedes', 2.2),
#  ('gulch', 2.2),
#  ('garbs', 2.2),
#  ('bagel', 2.2),
#  ('gilds', 2.2),
#  ('bides', 2.2),
#  ('paged', 2.2),
#  ('medic', 2.2),
#  ('acing', 2.2),
#  ('decal', 2.2),
#  ('vends', 2.2),
#  ('geode', 2.2),
#  ('gourd', 2.2),
#  ('cubit', 2.2),
#  ('abode', 2.2),
#  ('combo', 2.2),
#  ('veldt', 2.2),
#  ('beady', 2.2),
#  ('giver', 2.2),
#  ('codex', 2.2),
#  ('vodka', 2.2),
#  ('decor', 2.2),
#  ('bogus', 2.2),
#  ('bongo', 2.2),
#  ('credo', 2.2),
#  ('garde', 2.2),
#  ('boric', 2.2),
#  ('gecko', 2.2),
#  ('beget', 2.2),
#  ('cawed', 2.2),
#  ('gamba', 2.2),
#  ('gored', 2.2),
#  ('bandy', 2.2),
#  ('bards', 2.2),
#  ('edger', 2.2),
#  ('ebbed', 2.2),
#  ('breve', 2.2),
#  ('blocs', 2.2),
#  ('bronc', 2.2),
#  ('conga', 2.2),
#  ('bawdy', 2.2),
#  ('cadre', 2.2),
#  ('egged', 2.2),
#  ('caped', 2.2),
#  ('agave', 2.2),
#  ('bated', 2.2),
#  ('bilge', 2.2),
#  ('pudgy', 2.2),
#  ('brads', 2.2),
#  ('curvy', 2.2),
#  ('bodes', 2.2),
#  ('chive', 2.2),
#  ('decry', 2.2),
#  ('ducal', 2.2),
#  ('bidet', 2.2),
#  ('bulgy', 2.2),
#  ('brung', 2.2),
#  ('binge', 2.2),
#  ('abaci', 2.2),
#  ('grads', 2.2),
#  ('blued', 2.2),
#  ('ducat', 2.2),
#  ('divot', 2.2),
#  ('vetch', 2.2),
#  ('dacha', 2.2),
#  ('dicta', 2.2),
#  ('globs', 2.2),
#  ('butch', 2.2),
#  ('cagey', 2.2),
#  ('fudgy', 2.2),
#  ('caddy', 2.2),
#  ('ogled', 2.2),
#  ('begot', 2.2),
#  ('dings', 2.2),
#  ('dicks', 2.2),
#  ('gibes', 2.2),
#  ('guava', 2.2),
#  ('carob', 2.2),
#  ('cubby', 2.2),
#  ('clave', 2.2),
#  ('boded', 2.2),
#  ('lobed', 2.2),
#  ('dingo', 2.2),
#  ('calve', 2.2),
#  ('ducky', 2.2),
#  ('vibes', 2.2),
#  ('dicey', 2.2),
#  ('codon', 2.2),
#  ('befog', 2.2),
#  ('gamed', 2.2),
#  ('coder', 2.2),
#  ('chard', 2.2),
#  ('decaf', 2.2),
#  ('adlib', 2.2),
#  ('coned', 2.2),
#  ('vegan', 2.2),
#  ('biped', 2.2),
#  ('bunco', 2.2),
#  ('debit', 2.2),
#  ('vagus', 2.2),
#  ('educe', 2.2),
#  ('gated', 2.2),
#  ('divas', 2.2),
#  ('cavil', 2.2),
#  ('botch', 2.2),
#  ('gelds', 2.2),
#  ('rebid', 2.2),
#  ('biddy', 2.2),
#  ('disco', 2.2),
#  ('brigs', 2.2),
#  ('vapid', 2.2),
#  ('divvy', 2.2),
#  ('jived', 2.2),
#  ('cager', 2.2),
#  ('codas', 2.2),
#  ('ivied', 2.2),
#  ('cabal', 2.2),
#  ('burgs', 2.2),
#  ('cabby', 2.2),
#  ('egads', 2.2),
#  ('drubs', 2.2),
#  ('deuce', 2.2),
#  ('clads', 2.2),
#  ('doggy', 2.2),
#  ('viand', 2.2),
#  ('condo', 2.2),
#  ('scrod', 2.2),
#  ('coxed', 2.2),
#  ('dutch', 2.2),
#  ('duvet', 2.2),
#  ('gabby', 2.2),
#  ('gouda', 2.2),
#  ('deice', 2.2),
#  ('duchy', 2.2),
#  ('coked', 2.2),
#  ('boggy', 2.2),
#  ('abaca', 2.2),
#  ('ovoid', 2.2),
#  ('bipod', 2.2),
#  ('grebe', 2.2),
#  ('dicot', 2.2),
#  ('begat', 2.2),
#  ('gyves', 2.2),
#  ('bergs', 2.2),
#  ('cycad', 2.2),
#  ('dolce', 2.2),
#  ('brack', 2.2),
#  ('podgy', 2.2),
#  ('dictu', 2.2),
#  ('vacuo', 2.2),
#  ('bocks', 2.2),
#  ('dweeb', 2.2),
#  ('imbed', 2.2),
#  ('bunds', 2.2),
#  ('degum', 2.2),
#  ('dungy', 2.2),
#  ('wedgy', 2.2),
#  ('glebe', 2.2),
#  ('ridgy', 2.2),
#  ('davit', 2.2),
#  ('acked', 2.2),
#  ('duces', 2.2),
#  ('drabs', 2.2),
#  ('baric', 2.2),
#  ('geoid', 2.2),
#  ('defog', 2.2),
#  ('bigly', 2.2),
#  ('vised', 2.2),
#  ('celeb', 2.2),
#  ('dodgy', 2.2),
#  ('scudi', 2.2),
#  ('bilgy', 2.2),
#  ('gamic', 2.2),
#  ('bedew', 2.2),
#  ('giber', 2.2),
#  ('glads', 2.2),
#  ('sedgy', 2.2),
#  ('pubic', 2.2),
#  ('orbed', 2.2),
#  ('baddy', 2.2),
#  ('riced', 2.2),
#  ('velds', 2.2),
#  ('dribs', 2.2),
#  ('bauds', 2.2),
#  ('scuds', 2.2),
#  ('vined', 2.2),
#  ('degas', 2.2),
#  ('coven', 2.2),
#  ('nicad', 2.2),
#  ('vacua', 2.2),
#  ('dreck', 2.2),
#  ('grody', 2.2),
#  ('bocci', 2.2),
#  ('rived', 2.2),
#  ('hived', 2.2),
#  ('yogic', 2.2),
#  ('gonad', 2.2),
#  ('brava', 2.2),
#  ('dicer', 2.2),
#  ('vinca', 2.2),
#  ('debar', 2.2),
#  ('maced', 2.2),
#  ('tubed', 2.2),
#  ('vaned', 2.2),
#  ('acned', 2.2),
#  ('guyed', 2.2),
#  ('iodic', 2.2),
#  ('becks', 2.2),
#  ('abled', 2.2),
#  ('civvy', 2.2),
#  ('scudo', 2.2),
#  ('bhang', 2.2),
#  ('balds', 2.2),
#  ('bungs', 2.2),
#  ('dungs', 2.2),
#  ('ceder', 2.2),
#  ('doges', 2.2),
#  ('cordy', 2.2),
#  ('curdy', 2.2),
#  ('bract', 2.2),
#  ('corgi', 2.2),
#  ('bedim', 2.2),
#  ('dicut', 2.2),
#  ('cruds', 2.2),
#  ('bebug', 2.2),
#  ('bider', 2.2),
#  ('cuing', 2.2),
#  ('bight', 2.2),
#  ('dovey', 2.2),
#  ('cuber', 2.2),
#  ('doggo', 2.2),
#  ('bocce', 2.2),
#  ('dicky', 2.2),
#  ('abend', 2.2),
#  ('biggy', 2.2),
#  ('laved', 2.2),
#  ('baldy', 2.2),
#  ('which', 3.4),
#  ('about', 3.4),
#  ('would', 3.4),
#  ('words', 3.4),
#  ('right', 3.4),
#  ('place', 3.4),
#  ('sound', 3.4),
#  ('great', 3.4),
#  ('again', 3.4),
#  ('every', 3.4),
#  ('found', 3.4),
#  ('never', 3.4),
#  ('under', 3.4),
#  ('might', 3.4),
#  ('world', 3.4),
#  ('below', 3.4),
#  ('asked', 3.4),
#  ('going', 3.4),
#  ('large', 3.4),
#  ('along', 3.4),
#  ('since', 3.4),
#  ('study', 3.4),
#  ('night', 3.4),
#  ('light', 3.4),
#  ('young', 3.4),
#  ('heard', 3.4),
#  ('music', 3.4),
#  ('thing', 3.4),
#  ('today', 3.4),
#  ('using', 3.4),
#  ('order', 3.4),
#  ('group', 3.4),
#  ('among', 3.4),
#  ('space', 3.4),
#  ('table', 3.4),
#  ('hands', 3.4),
#  ('stood', 3.4),
#  ('kinds', 3.4),
#  ('comes', 3.4),
#  ('close', 3.4),
#  ('vowel', 3.4),
#  ('built', 3.4),
#  ('ready', 3.4),
#  ('class', 3.4),
#  ('round', 3.4),
#  ('piece', 3.4),
#  ('green', 3.4),
#  ('stand', 3.4),
#  ('river', 3.4),
#  ('tried', 3.4),
#  ('field', 3.4),
#  ('girls', 3.4),
#  ('leave', 3.4),
#  ('added', 3.4),
#  ('color', 3.4),
#  ('third', 3.4),
#  ('heavy', 3.4),
#  ('ideas', 3.4),
#  ('check', 3.4),
#  ('watch', 3.4),
#  ('carry', 3.4),
#  ('clear', 3.4),
#  ('named', 3.4),
#  ('books', 3.4),
#  ('glass', 3.4),
#  ('sides', 3.4),
#  ('seven', 3.4),
#  ('solve', 3.4),
#  ('value', 3.4),
#  ('death', 3.4),
#  ('maybe', 3.4),
#  ('lives', 3.4),
#  ('force', 3.4),
#  ('ocean', 3.4),
#  ('speed', 3.4),
#  ('grass', 3.4),
#  ('scale', 3.4),
#  ('cells', 3.4),
#  ('wrong', 3.4),
#  ('pages', 3.4),
#  ('needs', 3.4),
#  ('rocks', 3.4),
#  ('eight', 3.4),
#  ('level', 3.4),
#  ('ahead', 3.4),
#  ('reach', 3.4),
#  ('sight', 3.4),
#  ('catch', 3.4),
#  ('songs', 3.4),
#  ('waves', 3.4),
#  ('guess', 3.4),
#  ('break', 3.4),
#  ('cause', 3.4),
#  ('radio', 3.4),
#  ('lands', 3.4),
#  ('liked', 3.4),
#  ('trade', 3.4),
#  ('fight', 3.4),
#  ('local', 3.4),
#  ('coast', 3.4),
#  ('thick', 3.4),
#  ('brown', 3.4),
#  ('clean', 3.4),
#  ('sugar', 3.4),
#  ('facts', 3.4),
#  ('peace', 3.4),
#  ('seeds', 3.4),
#  ('visit', 3.4),
#  ('woods', 3.4),
#  ('chief', 3.4),
#  ('cross', 3.4),
#  ('wings', 3.4),
#  ('grown', 3.4),
#  ('cases', 3.4),
#  ('foods', 3.4),
#  ('crops', 3.4),
#  ('stick', 3.4),
#  ('stage', 3.4),
#  ('drink', 3.4),
#  ('bones', 3.4),
#  ('moves', 3.4),
#  ('touch', 3.4),
#  ('angle', 3.4),
#  ('range', 3.4),
#  ('tired', 3.4),
#  ('older', 3.4),
#  ('spend', 3.4),
#  ('chair', 3.4),
#  ('twice', 3.4),
#  ('cents', 3.4),
#  ('broke', 3.4),
#  ('count', 3.4),
#  ('score', 3.4),
#  ('heads', 3.4),
#  ('serve', 3.4),
#  ('angry', 3.4),
#  ('quick', 3.4),
#  ('dress', 3.4),
#  ('alive', 3.4),
#  ('solid', 3.4),
#  ('cloth', 3.4),
#  ('signs', 3.4),
#  ('drawn', 3.4),
#  ('truck', 3.4),
#  ('faces', 3.4),
#  ('boats', 3.4),
#  ('proud', 3.4),
#  ('court', 3.4),
#  ('model', 3.4),
#  ('yards', 3.4),
#  ('prove', 3.4),
#  ('price', 3.4),
#  ('boxes', 3.4),
#  ('match', 3.4),
#  ('roads', 3.4),
#  ('lunch', 3.4),
#  ('chart', 3.4),
#  ('scene', 3.4),
#  ('graph', 3.4),
#  ('winds', 3.4),
#  ('grain', 3.4),
#  ('mixed', 3.4),
#  ('games', 3.4),
#  ('wagon', 3.4),
#  ('topic', 3.4),
#  ('fence', 3.4),
#  ('lying', 3.4),
#  ('basis', 3.4),
#  ('clock', 3.4),
#  ('grows', 3.4),
#  ('agree', 3.4),
#  ('brain', 3.4),
#  ('track', 3.4),
#  ('stock', 3.4),
#  ('giant', 3.4),
#  ('ought', 3.4),
#  ('rough', 3.4),
#  ('daily', 3.4),
#  ('cream', 3.4),
#  ('laugh', 3.4),
#  ('teach', 3.4),
#  ('bells', 3.4),
#  ('dream', 3.4),
#  ('occur', 3.4),
#  ('ended', 3.4),
#  ('dozen', 3.4),
#  ('pitch', 3.4),
#  ('holds', 3.4),
#  ('fixed', 3.4),
#  ('costs', 3.4),
#  ('calls', 3.4),
#  ('blank', 3.4),
#  ('labor', 3.4),
#  ('gases', 3.4),
#  ('doors', 3.4),
#  ('exact', 3.4),
#  ('brush', 3.4),
#  ('chest', 3.4),
#  ('hoped', 3.4),
#  ('aside', 3.4),
#  ('depth', 3.4),
#  ('event', 3.4),
#  ('ranch', 3.4),
#  ('image', 3.4),
#  ('aloud', 3.4),
#  ('dried', 3.4),
#  ('pound', 3.4),
#  ('chain', 3.4),
#  ('drops', 3.4),
#  ('orbit', 3.4),
#  ('banks', 3.4),
#  ('tribe', 3.4),
#  ('tight', 3.4),
#  ('shade', 3.4),
#  ('claim', 3.4),
#  ('hence', 3.4),
#  ('birth', 3.4),
#  ('anger', 3.4),
#  ('brief', 3.4),
#  ('glory', 3.4),
#  ('owned', 3.4),
#  ('trick', 3.4),
#  ('noted', 3.4),
#  ('width', 3.4),
#  ('burst', 3.4),
#  ('lungs', 3.4),
#  ('uncle', 3.4),
#  ('bears', 3.4),
#  ('kings', 3.4),
#  ('brass', 3.4),
#  ('chose', 3.4),
#  ('vapor', 3.4),
#  ('beats', 3.4),
#  ('tough', 3.4),
#  ('finds', 3.4),
#  ('stuck', 3.4),
#  ('label', 3.4),
#  ('swing', 3.4),
#  ('beans', 3.4),
#  ('weigh', 3.4),
#  ('pride', 3.4),
#  ('swung', 3.4),
#  ('boots', 3.4),
#  ('lucky', 3.4),
#  ('stove', 3.4),
#  ('tubes', 3.4),
#  ('acres', 3.4),
#  ('wound', 3.4),
#  ('slide', 3.4),
#  ('porch', 3.4),
#  ('slave', 3.4),
#  ('juice', 3.4),
#  ('goose', 3.4),
#  ('favor', 3.4),
#  ('views', 3.4),
#  ('eager', 3.4),
#  ('rings', 3.4),
#  ('adult', 3.4),
#  ('index', 3.4),
#  ('balls', 3.4),
#  ('drill', 3.4),
#  ('trace', 3.4),
#  ('waxed', 3.4),
#  ('minds', 3.4),
#  ('dirty', 3.4),
#  ('coins', 3.4),
#  ('leads', 3.4),
#  ('bases', 3.4),
#  ('cycle', 3.4),
#  ('movie', 3.4),
#  ('canoe', 3.4),
#  ('fired', 3.4),
#  ('thumb', 3.4),
#  ('canal', 3.4),
#  ('habit', 3.4),
#  ('ruled', 3.4),
#  ('fever', 3.4),
#  ('crust', 3.4),
#  ('midst', 3.4),
#  ('crack', 3.4),
#  ('coach', 3.4),
#  ('flood', 3.4),
#  ('verse', 3.4),
#  ('rocky', 3.4),
#  ('march', 3.4),
#  ('ghost', 3.4),
#  ('germs', 3.4),
#  ('reads', 3.4),
#  ('dairy', 3.4),
#  ('gifts', 3.4),
#  ('rapid', 3.4),
#  ('claws', 3.4),
#  ('beast', 3.4),
#  ('cakes', 3.4),
#  ('frogs', 3.4),
#  ('nerve', 3.4),
#  ('armed', 3.4),
#  ('legal', 3.4),
#  ('crown', 3.4),
#  ('shock', 3.4),
#  ('drums', 3.4),
#  ('dates', 3.4),
#  ('drank', 3.4),
#  ('blows', 3.4),
#  ('lever', 3.4),
#  ('wages', 3.4),
#  ('sings', 3.4),
#  ('herds', 3.4),
#  ('hated', 3.4),
#  ('clues', 3.4),
#  ('novel', 3.4),
#  ('burnt', 3.4),
#  ('races', 3.4),
#  ('coats', 3.4),
#  ('dimes', 3.4),
#  ('clerk', 3.4),
#  ('mercy', 3.4),
#  ('guest', 3.4),
#  ('bills', 3.4),
#  ('sandy', 3.4),
#  ('sadly', 3.4),
#  ('fancy', 3.4),
#  ('rider', 3.4),
#  ('crash', 3.4),
#  ('craft', 3.4),
#  ('gates', 3.4),
#  ('hatch', 3.4),
#  ('funds', 3.4),
#  ('wider', 3.4),
#  ('tides', 3.4),
#  ('admit', 3.4),
#  ('tiger', 3.4),
#  ('angel', 3.4),
#  ('cruel', 3.4),
#  ('agent', 3.4),
#  ('drama', 3.4),
#  ('patch', 3.4),
#  ('vital', 3.4),
#  ('sword', 3.4),
#  ('blame', 3.4),
#  ('weeds', 3.4),
#  ('screw', 3.4),
#  ('chalk', 3.4),
#  ('crazy', 3.4),
#  ('goats', 3.4),
#  ('witch', 3.4),
#  ('loves', 3.4),
#  ('dwell', 3.4),
#  ('cheek', 3.4),
#  ('ideal', 3.4),
#  ('eagle', 3.4),
#  ('creek', 3.4),
#  ('cries', 3.4),
#  ('yield', 3.4),
#  ('wives', 3.4),
#  ('burns', 3.4),
#  ('organ', 3.4),
#  ('cliff', 3.4),
#  ('chase', 3.4),
#  ('slice', 3.4),
#  ('knock', 3.4),
#  ('wiped', 3.4),
#  ('blown', 3.4),
#  ('piled', 3.4),
#  ('cheer', 3.4),
#  ('widow', 3.4),
#  ('hides', 3.4),
#  ('comma', 3.4),
#  ('crept', 3.4),
#  ('deeds', 3.4),
#  ('rides', 3.4),
#  ('muddy', 3.4),
#  ('crime', 3.4),
#  ('drift', 3.4),
#  ('dusty', 3.4),
#  ('sends', 3.4),
#  ('reign', 3.4),
#  ('noble', 3.4),
#  ('cheap', 3.4),
#  ('dense', 3.4),
#  ('geese', 3.4),
#  ('woven', 3.4),
#  ('hired', 3.4),
#  ('salad', 3.4),
#  ('belts', 3.4),
#  ('grasp', 3.4),
#  ('blast', 3.4),
#  ('fungi', 3.4),
#  ('tends', 3.4),
#  ('loads', 3.4),
#  ('veins', 3.4),
#  ('toads', 3.4),
#  ('coral', 3.4),
#  ('focus', 3.4),
#  ('naked', 3.4),
#  ('macro', 3.4),
#  ('flung', 3.4),
#  ('brook', 3.4),
#  ('socks', 3.4),
#  ('urban', 3.4),
#  ('goals', 3.4),
#  ('grant', 3.4),
#  ('wreck', 3.4),
#  ('flock', 3.4),
#  ('hobby', 3.4),
#  ('dared', 3.4),
#  ('faded', 3.4),
#  ('votes', 3.4),
#  ('radar', 3.4),
#  ('argue', 3.4),
#  ('dolls', 3.4),
#  ('broom', 3.4),
#  ('scent', 3.4),
#  ('olive', 3.4),
#  ('peach', 3.4),
#  ('schwa', 3.4),
#  ('lambs', 3.4),
#  ('cools', 3.4),
#  ('draft', 3.4),
#  ('charm', 3.4),
#  ('limbs', 3.4),
#  ('brake', 3.4),
#  ('delay', 3.4),
#  ('beams', 3.4),
#  ('fetch', 3.4),
#  ('camel', 3.4),
#  ('vines', 3.4),
#  ('picks', 3.4),
#  ('naval', 3.4),
#  ('crawl', 3.4),
#  ('sauce', 3.4),
#  ('basin', 3.4),
#  ('ponds', 3.4),
#  ('fluid', 3.4),
#  ('robot', 3.4),
#  ('reeds', 3.4),
#  ('buses', 3.4),
#  ('grief', 3.4),
#  ('bloom', 3.4),
#  ('dwelt', 3.4),
#  ('flags', 3.4),
#  ('fiber', 3.4),
#  ('freed', 3.4),
#  ('aimed', 3.4),
#  ('algae', 3.4),
#  ('twigs', 3.4),
#  ('drunk', 3.4),
#  ('chill', 3.4),
#  ('panic', 3.4),
#  ('tuned', 3.4),
#  ('crisp', 3.4),
#  ('molds', 3.4),
#  ('liver', 3.4),
#  ('gauge', 3.4),
#  ('gulls', 3.4),
#  ('gross', 3.4),
#  ...]

# %%
guess3 = "budge"
guess_info = merge_guess_info(wordle_guess(guess3, answer), guess_info)
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ['cents', 'vents']

# %%
word_scores = get_word_scores(words, remaining_words, guess_info)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('which', 1.0),
#  ('could', 1.0),
#  ('place', 1.0),
#  ('every', 1.0),
#  ('never', 1.0),
#  ('since', 1.0),
#  ('above', 1.0),
#  ('given', 1.0),
#  ('music', 1.0),
#  ('space', 1.0),
#  ('black', 1.0),
#  ('voice', 1.0),
#  ('comes', 1.0),
#  ('close', 1.0),
#  ('lived', 1.0),
#  ('vowel', 1.0),
#  ('class', 1.0),
#  ('piece', 1.0),
#  ('river', 1.0),
#  ('leave', 1.0),
#  ('color', 1.0),
#  ('moved', 1.0),
#  ('heavy', 1.0),
#  ('cried', 1.0),
#  ('check', 1.0),
#  ('watch', 1.0),
#  ('carry', 1.0),
#  ('clear', 1.0),
#  ('child', 1.0),
#  ('seven', 1.0),
#  ('solve', 1.0),
#  ('value', 1.0),
#  ('gives', 1.0),
#  ('lives', 1.0),
#  ('force', 1.0),
#  ('ocean', 1.0),
#  ('scale', 1.0),
#  ('cells', 1.0),
#  ('rocks', 1.0),
#  ('level', 1.0),
#  ('reach', 1.0),
#  ('catch', 1.0),
#  ('cover', 1.0),
#  ('waves', 1.0),
#  ('dance', 1.0),
#  ('cause', 1.0),
#  ('basic', 1.0),
#  ('drive', 1.0),
#  ('local', 1.0),
#  ('coast', 1.0),
#  ('thick', 1.0),
#  ('clean', 1.0),
#  ('facts', 1.0),
#  ('peace', 1.0),
#  ('verbs', 1.0),
#  ('visit', 1.0),
#  ('chief', 1.0),
#  ('cross', 1.0),
#  ('cases', 1.0),
#  ('crops', 1.0),
#  ('stick', 1.0),
#  ('moves', 1.0),
#  ('touch', 1.0),
#  ('chair', 1.0),
#  ('twice', 1.0),
#  ('cents', 1.0),
#  ('count', 1.0),
#  ('score', 1.0),
#  ('serve', 1.0),
#  ('crowd', 1.0),
#  ('quick', 1.0),
#  ('alive', 1.0),
#  ('cloth', 1.0),
#  ('truck', 1.0),
#  ('loved', 1.0),
#  ('faces', 1.0),
#  ('drove', 1.0),
#  ('cabin', 1.0),
#  ('court', 1.0),
#  ('prove', 1.0),
#  ('price', 1.0),
#  ('match', 1.0),
#  ('lunch', 1.0),
#  ('chart', 1.0),
#  ('scene', 1.0),
#  ('block', 1.0),
#  ('topic', 1.0),
#  ('fence', 1.0),
#  ('cloud', 1.0),
#  ('clock', 1.0),
#  ('track', 1.0),
#  ('beach', 1.0),
#  ('stock', 1.0),
#  ('saved', 1.0),
#  ('avoid', 1.0),
#  ('cream', 1.0),
#  ('teach', 1.0),
#  ('magic', 1.0),
#  ('occur', 1.0),
#  ('chord', 1.0),
#  ('brave', 1.0),
#  ('climb', 1.0),
#  ('pitch', 1.0),
#  ('costs', 1.0),
#  ('calls', 1.0),
#  ('exact', 1.0),
#  ('chest', 1.0),
#  ('candy', 1.0),
#  ('event', 1.0),
#  ('ranch', 1.0),
#  ('chain', 1.0),
#  ('curve', 1.0),
#  ('claim', 1.0),
#  ('hence', 1.0),
#  ('trick', 1.0),
#  ('uncle', 1.0),
#  ('cards', 1.0),
#  ('chose', 1.0),
#  ('vapor', 1.0),
#  ('stuck', 1.0),
#  ('lucky', 1.0),
#  ('stove', 1.0),
#  ('acres', 1.0),
#  ('porch', 1.0),
#  ('slave', 1.0),
#  ('faced', 1.0),
#  ('juice', 1.0),
#  ('raced', 1.0),
#  ('waved', 1.0),
#  ('favor', 1.0),
#  ('views', 1.0),
#  ('trace', 1.0),
#  ('coins', 1.0),
#  ('bench', 1.0),
#  ('cycle', 1.0),
#  ('movie', 1.0),
#  ('canoe', 1.0),
#  ('canal', 1.0),
#  ('fever', 1.0),
#  ('crust', 1.0),
#  ('crack', 1.0),
#  ('coach', 1.0),
#  ('verse', 1.0),
#  ('rocky', 1.0),
#  ('march', 1.0),
#  ('civil', 1.0),
#  ('ducks', 1.0),
#  ('brick', 1.0),
#  ('claws', 1.0),
#  ('cakes', 1.0),
#  ('nerve', 1.0),
#  ('crown', 1.0),
#  ('shock', 1.0),
#  ('lever', 1.0),
#  ('clues', 1.0),
#  ('novel', 1.0),
#  ('races', 1.0),
#  ('coats', 1.0),
#  ('clerk', 1.0),
#  ('mercy', 1.0),
#  ('fancy', 1.0),
#  ('bunch', 1.0),
#  ('crash', 1.0),
#  ('craft', 1.0),
#  ('hatch', 1.0),
#  ('grace', 1.0),
#  ('grave', 1.0),
#  ('cruel', 1.0),
#  ('patch', 1.0),
#  ('vital', 1.0),
#  ('screw', 1.0),
#  ('vocal', 1.0),
#  ('bacon', 1.0),
#  ('chalk', 1.0),
#  ('cargo', 1.0),
#  ('crazy', 1.0),
#  ('acted', 1.0),
#  ('witch', 1.0),
#  ('loves', 1.0),
#  ('backs', 1.0),
#  ('cheek', 1.0),
#  ('creek', 1.0),
#  ('cries', 1.0),
#  ('cubic', 1.0),
#  ('wives', 1.0),
#  ('cliff', 1.0),
#  ('chase', 1.0),
#  ('slice', 1.0),
#  ('knock', 1.0),
#  ('clubs', 1.0),
#  ('cheer', 1.0),
#  ('comma', 1.0),
#  ('crept', 1.0),
#  ('crime', 1.0),
#  ('devil', 1.0),
#  ('cheap', 1.0),
#  ('woven', 1.0),
#  ('veins', 1.0),
#  ('diver', 1.0),
#  ('coral', 1.0),
#  ('focus', 1.0),
#  ('macro', 1.0),
#  ('vivid', 1.0),
#  ('decay', 1.0),
#  ('socks', 1.0),
#  ('wreck', 1.0),
#  ('flock', 1.0),
#  ('crude', 1.0),
#  ('votes', 1.0),
#  ('voted', 1.0),
#  ('caves', 1.0),
#  ('cared', 1.0),
#  ('scent', 1.0),
#  ('olive', 1.0),
#  ('cable', 1.0),
#  ('peach', 1.0),
#  ('schwa', 1.0),
#  ('cools', 1.0),
#  ('charm', 1.0),
#  ('cubes', 1.0),
#  ('fetch', 1.0),
#  ('camel', 1.0),
#  ('vines', 1.0),
#  ('picks', 1.0),
#  ('naval', 1.0),
#  ('crawl', 1.0),
#  ('sauce', 1.0),
#  ('ditch', 1.0),
#  ('chill', 1.0),
#  ('panic', 1.0),
#  ('cords', 1.0),
#  ('crisp', 1.0),
#  ('dived', 1.0),
#  ('clung', 1.0),
#  ('liver', 1.0),
#  ('actor', 1.0),
#  ('scope', 1.0),
#  ('clown', 1.0),
#  ('cones', 1.0),
#  ('chant', 1.0),
#  ('acids', 1.0),
#  ('camps', 1.0),
#  ('lover', 1.0),
#  ('cocoa', 1.0),
#  ('punch', 1.0),
#  ('attic', 1.0),
#  ('scare', 1.0),
#  ('react', 1.0),
#  ('valid', 1.0),
#  ('cease', 1.0),
#  ('vague', 1.0),
#  ('weave', 1.0),
#  ('virus', 1.0),
#  ('scout', 1.0),
#  ('acute', 1.0),
#  ('pluck', 1.0),
#  ('stack', 1.0),
#  ('scarf', 1.0),
#  ('coals', 1.0),
#  ('elect', 1.0),
#  ('rival', 1.0),
#  ('curly', 1.0),
#  ('comic', 1.0),
#  ('cloak', 1.0),
#  ('clams', 1.0),
#  ('scrap', 1.0),
#  ('couch', 1.0),
#  ('codes', 1.0),
#  ('ounce', 1.0),
#  ('paved', 1.0),
#  ('crest', 1.0),
#  ('erect', 1.0),
#  ('glove', 1.0),
#  ('docks', 1.0),
#  ('curse', 1.0),
#  ('cedar', 1.0),
#  ('curls', 1.0),
#  ('cages', 1.0),
#  ('locks', 1.0),
#  ('crows', 1.0),
#  ('creep', 1.0),
#  ('chips', 1.0),
#  ('cares', 1.0),
#  ('valve', 1.0),
#  ('ivory', 1.0),
#  ('necks', 1.0),
#  ('clamp', 1.0),
#  ('crews', 1.0),
#  ('shack', 1.0),
#  ('saves', 1.0),
#  ('cooks', 1.0),
#  ('juicy', 1.0),
#  ('carts', 1.0),
#  ('crane', 1.0),
#  ('scrub', 1.0),
#  ('crabs', 1.0),
#  ('logic', 1.0),
#  ('cling', 1.0),
#  ('grove', 1.0),
#  ('china', 1.0),
#  ('sacks', 1.0),
#  ('brace', 1.0),
#  ('scalp', 1.0),
#  ('clump', 1.0),
#  ('perch', 1.0),
#  ('crank', 1.0),
#  ('tract', 1.0),
#  ('cigar', 1.0),
#  ('cough', 1.0),
#  ('choir', 1.0),
#  ('pouch', 1.0),
#  ('pinch', 1.0),
#  ('torch', 1.0),
#  ('vigor', 1.0),
#  ('click', 1.0),
#  ('lacks', 1.0),
#  ('chaos', 1.0),
#  ('cured', 1.0),
#  ('colts', 1.0),
#  ('birch', 1.0),
#  ('anvil', 1.0),
#  ('speck', 1.0),
#  ('slick', 1.0),
#  ('coils', 1.0),
#  ('snack', 1.0),
#  ('carve', 1.0),
#  ('notch', 1.0),
#  ('ached', 1.0),
#  ('fives', 1.0),
#  ('cuffs', 1.0),
#  ('clips', 1.0),
#  ('casts', 1.0),
#  ('lyric', 1.0),
#  ('decks', 1.0),
#  ('ovary', 1.0),
#  ('quack', 1.0),
#  ('civic', 1.0),
#  ('bevel', 1.0),
#  ('packs', 1.0),
#  ('tonic', 1.0),
#  ('corps', 1.0),
#  ('niece', 1.0),
#  ('cello', 1.0),
#  ('chuck', 1.0),
#  ('spice', 1.0),
#  ('doves', 1.0),
#  ('paces', 1.0),
#  ('colon', 1.0),
#  ('cacao', 1.0),
#  ('tacks', 1.0),
#  ('cited', 1.0),
#  ('larva', 1.0),
#  ('crush', 1.0),
#  ('kicks', 1.0),
#  ('scary', 1.0),
#  ('evils', 1.0),
#  ('pivot', 1.0),
#  ('yacht', 1.0),
#  ('viola', 1.0),
#  ('comet', 1.0),
#  ('scars', 1.0),
#  ('chops', 1.0),
#  ('carol', 1.0),
#  ('canon', 1.0),
#  ('scorn', 1.0),
#  ('chess', 1.0),
#  ('crate', 1.0),
#  ('rivet', 1.0),
#  ('heave', 1.0),
#  ('gravy', 1.0),
#  ('beech', 1.0),
#  ('chick', 1.0),
#  ('clash', 1.0),
#  ('shave', 1.0),
#  ('chunk', 1.0),
#  ('paced', 1.0),
#  ('slack', 1.0),
#  ('mucus', 1.0),
#  ('discs', 1.0),
#  ('cider', 1.0),
#  ('churn', 1.0),
#  ('curds', 1.0),
#  ('lance', 1.0),
#  ('caste', 1.0),
#  ('crook', 1.0),
#  ('epoch', 1.0),
#  ('icing', 1.0),
#  ('choke', 1.0),
#  ('ticks', 1.0),
#  ('vault', 1.0),
#  ('scold', 1.0),
#  ('sieve', 1.0),
#  ('ducts', 1.0),
#  ('scoop', 1.0),
#  ('hitch', 1.0),
#  ('chute', 1.0),
#  ('cheat', 1.0),
#  ('dives', 1.0),
#  ('flick', 1.0),
#  ('batch', 1.0),
#  ('chore', 1.0),
#  ('volts', 1.0),
#  ('laced', 1.0),
#  ('shove', 1.0),
#  ('nicer', 1.0),
#  ('vases', 1.0),
#  ('colds', 1.0),
#  ('curry', 1.0),
#  ('cobra', 1.0),
#  ('cores', 1.0),
#  ('vowed', 1.0),
#  ('chili', 1.0),
#  ('cleft', 1.0),
#  ('latch', 1.0),
#  ('chaps', 1.0),
#  ('ovens', 1.0),
#  ('elves', 1.0),
#  ('scant', 1.0),
#  ('cooky', 1.0),
#  ('creak', 1.0),
#  ('vanes', 1.0),
#  ('combs', 1.0),
#  ('laces', 1.0),
#  ('cafes', 1.0),
#  ('naive', 1.0),
#  ('valor', 1.0),
#  ('scuba', 1.0),
#  ('creed', 1.0),
#  ('lilac', 1.0),
#  ('cures', 1.0),
#  ('niche', 1.0),
#  ('yucca', 1.0),
#  ('whack', 1.0),
#  ('bucks', 1.0),
#  ('haven', 1.0),
#  ('clasp', 1.0),
#  ('champ', 1.0),
#  ('chirp', 1.0),
#  ('knack', 1.0),
#  ('caked', 1.0),
#  ('cramp', 1.0),
#  ('voter', 1.0),
#  ('roach', 1.0),
#  ('cocks', 1.0),
#  ('eaves', 1.0),
#  ('veils', 1.0),
#  ('racks', 1.0),
#  ('hover', 1.0),
#  ('aches', 1.0),
#  ('claps', 1.0),
#  ('spicy', 1.0),
#  ('vicar', 1.0),
#  ('acorn', 1.0),
#  ('hunch', 1.0),
#  ('truce', 1.0),
#  ('vexed', 1.0),
#  ('clang', 1.0),
#  ('croak', 1.0),
#  ('avert', 1.0),
#  ('havoc', 1.0),
#  ('villa', 1.0),
#  ('farce', 1.0),
#  ('cites', 1.0),
#  ('livid', 1.0),
#  ('chews', 1.0),
#  ('licks', 1.0),
#  ('scoff', 1.0),
#  ('sonic', 1.0),
#  ('tucks', 1.0),
#  ('vigil', 1.0),
#  ('sects', 1.0),
#  ('scaly', 1.0),
#  ('mince', 1.0),
#  ('relic', 1.0),
#  ('ulcer', 1.0),
#  ('crags', 1.0),
#  ('caged', 1.0),
#  ('cadet', 1.0),
#  ('saucy', 1.0),
#  ('enact', 1.0),
#  ('toxic', 1.0),
#  ('covet', 1.0),
#  ('venom', 1.0),
#  ('stave', 1.0),
#  ('pecks', 1.0),
#  ('capes', 1.0),
#  ('evoke', 1.0),
#  ('cluck', 1.0),
#  ('canes', 1.0),
#  ('verge', 1.0),
#  ('crumb', 1.0),
#  ('lucid', 1.0),
#  ('clogs', 1.0),
#  ('cinch', 1.0),
#  ('calms', 1.0),
#  ('bitch', 1.0),
#  ('scowl', 1.0),
#  ('coded', 1.0),
#  ('waver', 1.0),
#  ('clods', 1.0),
#  ('clays', 1.0),
#  ('ketch', 1.0),
#  ('clink', 1.0),
#  ('scamp', 1.0),
#  ('bravo', 1.0),
#  ('sever', 1.0),
#  ('visor', 1.0),
#  ('pecan', 1.0),
#  ('pence', 1.0),
#  ('curbs', 1.0),
#  ('cheep', 1.0),
#  ('evade', 1.0),
#  ('vogue', 1.0),
#  ('tunic', 1.0),
#  ('clank', 1.0),
#  ('finch', 1.0),
#  ('chaff', 1.0),
#  ('copra', 1.0),
#  ('lurch', 1.0),
#  ('chins', 1.0),
#  ('smock', 1.0),
#  ('cache', 1.0),
#  ('mocks', 1.0),
#  ('scans', 1.0),
#  ('revel', 1.0),
#  ('raven', 1.0),
#  ('scuff', 1.0),
#  ('mimic', 1.0),
#  ('corny', 1.0),
#  ('edict', 1.0),
#  ('recur', 1.0),
#  ('franc', 1.0),
#  ('facet', 1.0),
#  ('cater', 1.0),
#  ('decoy', 1.0),
#  ('ovals', 1.0),
#  ('rover', 1.0),
#  ('carat', 1.0),
#  ('vents', 1.0),
#  ('chimp', 1.0),
#  ('vinyl', 1.0),
#  ('clout', 1.0),
#  ('frock', 1.0),
#  ('navel', 1.0),
#  ('casks', 1.0),
#  ('gavel', 1.0),
#  ('vomit', 1.0),
#  ('viper', 1.0),
#  ('aback', 1.0),
#  ('hutch', 1.0),
#  ('valet', 1.0),
#  ('epics', 1.0),
#  ('caper', 1.0),
#  ('chime', 1.0),
#  ('leech', 1.0),
#  ('salve', 1.0),
#  ('conic', 1.0),
#  ('craze', 1.0),
#  ('jacks', 1.0),
#  ('wince', 1.0),
#  ('cooed', 1.0),
#  ('chugs', 1.0),
#  ('clots', 1.0),
#  ('cocky', 1.0),
#  ('coyly', 1.0),
#  ('chide', 1.0),
#  ('video', 1.0),
#  ('chasm', 1.0),
#  ('excel', 1.0),
#  ('savor', 1.0),
#  ('clove', 1.0),
#  ('halve', 1.0),
#  ('mauve', 1.0),
#  ('envoy', 1.0),
#  ('coves', 1.0),
#  ('chums', 1.0),
#  ('scour', 1.0),
#  ('cribs', 1.0),
#  ('coupe', 1.0),
#  ('munch', 1.0),
#  ('divan', 1.0),
#  ('vices', 1.0),
#  ('acrid', 1.0),
#  ('cubed', 1.0),
#  ('clans', 1.0),
#  ('canny', 1.0),
#  ('clefs', 1.0),
#  ('nicks', 1.0),
#  ('mulch', 1.0),
#  ('vista', 1.0),
#  ('croon', 1.0),
#  ('conch', 1.0),
#  ('tacos', 1.0),
#  ('scows', 1.0),
#  ('hovel', 1.0),
#  ('lavas', 1.0),
#  ('crave', 1.0),
#  ('optic', 1.0),
#  ('knave', 1.0),
#  ('scoot', 1.0),
#  ('crock', 1.0),
#  ('veers', 1.0),
#  ('hacks', 1.0),
#  ('levee', 1.0),
#  ('antic', 1.0),
#  ('corks', 1.0),
#  ('fleck', 1.0),
#  ('scram', 1.0),
#  ('vales', 1.0),
#  ('coped', 1.0),
#  ('vying', 1.0),
#  ('cocci', 1.0),
#  ('pacts', 1.0),
#  ('scabs', 1.0),
#  ('eject', 1.0),
#  ('belch', 1.0),
#  ('chewy', 1.0),
#  ('voile', 1.0),
#  ('raves', 1.0),
#  ('vixen', 1.0),
#  ('civet', 1.0),
#  ('vouch', 1.0),
#  ('corns', 1.0),
#  ('ravel', 1.0),
#  ('ovule', 1.0),
#  ('icily', 1.0),
#  ('waive', 1.0),
#  ('lynch', 1.0),
#  ('roves', 1.0),
#  ('scald', 1.0),
#  ('cynic', 1.0),
#  ('crone', 1.0),
#  ('cysts', 1.0),
#  ('coops', 1.0),
#  ('covey', 1.0),
#  ('talcs', 1.0),
#  ('cleat', 1.0),
#  ('vests', 1.0),
#  ('delve', 1.0),
#  ('ceded', 1.0),
#  ('novas', 1.0),
#  ('larch', 1.0),
#  ('aspic', 1.0),
#  ('chats', 1.0),
#  ('vials', 1.0),
#  ('evict', 1.0),
#  ('cocos', 1.0),
#  ('hives', 1.0),
#  ('diced', 1.0),
#  ('chafe', 1.0),
#  ('cower', 1.0),
#  ('chefs', 1.0),
#  ('racer', 1.0),
#  ('sucks', 1.0),
#  ('micas', 1.0),
#  ('czars', 1.0),
#  ('copse', 1.0),
#  ('croup', 1.0),
#  ('visas', 1.0),
#  ('raved', 1.0),
#  ('poach', 1.0),
#  ('copes', 1.0),
#  ('culls', 1.0),
#  ('haves', 1.0),
#  ('lucks', 1.0),
#  ('icons', 1.0),
#  ('comas', 1.0),
#  ('paves', 1.0),
#  ('cokes', 1.0),
#  ('cased', 1.0),
#  ('coeds', 1.0),
#  ('cowed', 1.0),
#  ('roved', 1.0),
#  ('scull', 1.0),
#  ('vexes', 1.0),
#  ('voids', 1.0),
#  ('colic', 1.0),
#  ('ivies', 1.0),
#  ('cruet', 1.0),
#  ('filch', 1.0),
#  ('carps', 1.0),
#  ('shuck', 1.0),
#  ('viler', 1.0),
#  ('scums', 1.0),
#  ('scads', 1.0),
#  ('evens', 1.0),
#  ('caned', 1.0),
#  ('dunce', 1.0),
#  ('crony', 1.0),
#  ('parch', 1.0),
#  ('avers', 1.0),
#  ('crams', 1.0),
#  ('leach', 1.0),
#  ('pooch', 1.0),
#  ('arced', 1.0),
#  ('acnes', 1.0),
#  ('cored', 1.0),
#  ('cowls', 1.0),
#  ('clued', 1.0),
#  ('vireo', 1.0),
#  ('cuter', 1.0),
#  ('cupid', 1.0),
#  ('dices', 1.0),
#  ('cedes', 1.0),
#  ('cress', 1.0),
#  ('pucks', 1.0),
#  ('gulch', 1.0),
#  ('icier', 1.0),
#  ('medic', 1.0),
#  ('veals', 1.0),
#  ('acing', 1.0),
#  ('chows', 1.0),
#  ('decal', 1.0),
#  ('cilia', 1.0),
#  ('novae', 1.0),
#  ('wicks', 1.0),
#  ('vends', 1.0),
#  ('mucks', 1.0),
#  ('vises', 1.0),
#  ('mocha', 1.0),
#  ('smack', 1.0),
#  ('cubit', 1.0),
#  ('cacti', 1.0),
#  ('focal', 1.0),
#  ('avail', 1.0),
#  ('versa', 1.0),
#  ('combo', 1.0),
#  ('overt', 1.0),
#  ('prick', 1.0),
#  ('veldt', 1.0),
#  ('crepe', 1.0),
#  ('locus', 1.0),
#  ('canst', 1.0),
#  ('pacer', 1.0),
#  ('octal', 1.0),
#  ('sumac', 1.0),
#  ('giver', 1.0),
#  ('codex', 1.0),
#  ('vodka', 1.0),
#  ('revue', 1.0),
#  ('crier', 1.0),
#  ('alack', 1.0),
#  ('cults', 1.0),
#  ('decor', 1.0),
#  ('mover', 1.0),
#  ('verve', 1.0),
#  ('ethic', 1.0),
#  ('incur', 1.0),
#  ('avant', 1.0),
#  ('calyx', 1.0),
#  ('coons', 1.0),
#  ('winch', 1.0),
#  ('ionic', 1.0),
#  ('saver', 1.0),
#  ('facto', 1.0),
#  ('caved', 1.0),
#  ('toves', 1.0),
#  ('credo', 1.0),
#  ('scrip', 1.0),
#  ('itchy', 1.0),
#  ('trice', 1.0),
#  ('boric', 1.0),
#  ('tacit', 1.0),
#  ('gecko', 1.0),
#  ('uncut', 1.0),
#  ('clunk', 1.0),
#  ('salvo', 1.0),
#  ('apace', 1.0),
#  ('cawed', 1.0),
#  ('wench', 1.0),
#  ('cohos', 1.0),
#  ('aleck', 1.0),
#  ('clomp', 1.0),
#  ('runic', 1.0),
#  ('hocks', 1.0),
#  ('ochre', 1.0),
#  ('cameo', 1.0),
#  ('breve', 1.0),
#  ('servo', 1.0),
#  ('blocs', 1.0),
#  ('welch', 1.0),
#  ('vitae', 1.0),
#  ('cumin', 1.0),
#  ('bronc', 1.0),
#  ('comer', 1.0),
#  ('privy', 1.0),
#  ('conga', 1.0),
#  ('cadre', 1.0),
#  ('picky', 1.0),
#  ('echos', 1.0),
#  ('caped', 1.0),
#  ('amuck', 1.0),
#  ('agave', 1.0),
#  ('vitro', 1.0),
#  ('manic', 1.0),
#  ('caret', 1.0),
#  ('coups', 1.0),
#  ('circa', 1.0),
#  ('carne', 1.0),
#  ('suave', 1.0),
#  ('curvy', 1.0),
#  ('liven', 1.0),
#  ('canto', 1.0),
#  ('curio', 1.0),
#  ('wrack', 1.0),
#  ('chive', 1.0),
#  ('cusps', 1.0),
#  ('specs', 1.0),
#  ('decry', 1.0),
#  ('clack', 1.0),
#  ('ducal', 1.0),
#  ('coypu', 1.0),
#  ('savvy', 1.0),
#  ('monic', 1.0),
#  ('laver', 1.0),
#  ('picas', 1.0),
#  ('mecca', 1.0),
#  ('crimp', 1.0),
#  ('chink', 1.0),
#  ('abaci', 1.0),
#  ('vaunt', 1.0),
#  ('cutie', 1.0),
#  ('levis', 1.0),
#  ('viral', 1.0),
#  ('comfy', 1.0),
#  ('voila', 1.0),
#  ('chine', 1.0),
#  ('coati', 1.0),
#  ('ducat', 1.0),
#  ('stoic', 1.0),
#  ('venue', 1.0),
#  ('crick', 1.0),
#  ('vizor', 1.0),
#  ('divot', 1.0),
#  ('vetch', 1.0),
#  ('cotta', 1.0),
#  ('crass', 1.0),
#  ('dacha', 1.0),
#  ('dicta', 1.0),
#  ('tacky', 1.0),
#  ('butch', 1.0),
#  ('croft', 1.0),
#  ('achoo', 1.0),
#  ('viols', 1.0),
#  ('cagey', 1.0),
#  ('coots', 1.0),
#  ('caddy', 1.0),
#  ('lacey', 1.0),
#  ('retch', 1.0),
#  ('cruse', 1.0),
#  ('riven', 1.0),
#  ('scion', 1.0),
#  ('dicks', 1.0),
#  ('hooch', 1.0),
#  ('snuck', 1.0),
#  ('techs', 1.0),
#  ('guava', 1.0),
#  ('scarp', 1.0),
#  ('carob', 1.0),
#  ('emcee', 1.0),
#  ('verso', 1.0),
#  ('scrim', 1.0),
#  ('cubby', 1.0),
#  ('clave', 1.0),
#  ('chump', 1.0),
#  ('fichu', 1.0),
#  ('chomp', 1.0),
#  ('avast', 1.0),
#  ('natch', 1.0),
#  ('chary', 1.0),
#  ('clime', 1.0),
#  ('wacky', 1.0),
#  ('crypt', 1.0),
#  ('nonce', 1.0),
#  ('calve', 1.0),
#  ('ducky', 1.0),
#  ('vibes', 1.0),
#  ('nervy', 1.0),
#  ('fiche', 1.0),
#  ('recap', 1.0),
#  ('synch', 1.0),
#  ('facie', 1.0),
#  ('dicey', 1.0),
#  ('caron', 1.0),
#  ('trove', 1.0),
#  ('creel', 1.0),
#  ('cadge', 1.0),
#  ('curie', 1.0),
#  ('veiny', 1.0),
#  ('codon', 1.0),
#  ('jocks', 1.0),
#  ('avian', 1.0),
#  ('chock', 1.0),
#  ('cushy', 1.0),
#  ('spacy', 1.0),
#  ('fiver', 1.0),
#  ('capos', 1.0),
#  ('coder', 1.0),
#  ('chard', 1.0),
#  ('cutup', 1.0),
#  ('decaf', 1.0),
#  ('peeve', 1.0),
#  ('epact', 1.0),
#  ('coned', 1.0),
#  ('narco', 1.0),
#  ('vegan', 1.0),
#  ('clops', 1.0),
#  ('hocus', 1.0),
#  ('bunco', 1.0),
#  ('chaws', 1.0),
#  ('yucky', 1.0),
#  ('maven', 1.0),
#  ('scuzz', 1.0),
#  ('nacho', 1.0),
#  ('vagus', 1.0),
#  ('educe', 1.0),
#  ('octet', 1.0),
#  ('socko', 1.0),
#  ('macaw', 1.0),
#  ('scone', 1.0),
#  ('mooch', 1.0),
#  ('venal', 1.0),
#  ('divas', 1.0),
#  ('recut', 1.0),
#  ('caulk', 1.0),
#  ('cavil', 1.0),
#  ('botch', 1.0),
#  ('hicks', 1.0),
#  ('wacko', 1.0),
#  ('acmes', 1.0),
#  ('disco', 1.0),
#  ('vamps', 1.0),
#  ('catty', 1.0),
#  ('comps', 1.0),
#  ('corer', 1.0),
#  ('colas', 1.0),
#  ('vapid', 1.0),
#  ('cairn', 1.0),
#  ('craps', 1.0),
#  ('clone', 1.0),
#  ('macho', 1.0),
#  ('recto', 1.0),
#  ('divvy', 1.0),
#  ('jived', 1.0),
#  ('cager', 1.0),
#  ('vivas', 1.0),
#  ('codas', 1.0),
#  ('zilch', 1.0),
#  ('orcas', 1.0),
#  ('chiff', 1.0),
#  ('micro', 1.0),
#  ('veeps', 1.0),
#  ('ivied', 1.0),
#  ('cabal', 1.0),
#  ('cuspy', 1.0),
#  ('vitas', 1.0),
#  ('capon', 1.0),
#  ('cabby', 1.0),
#  ('conks', 1.0),
#  ('chits', 1.0),
#  ('deuce', 1.0),
#  ('clads', 1.0),
#  ('scams', 1.0),
#  ('viand', 1.0),
#  ('coset', 1.0),
#  ('craws', 1.0),
#  ('condo', 1.0),
#  ('coxes', 1.0),
#  ('ascot', 1.0),
#  ('execs', 1.0),
#  ('envoi', 1.0),
#  ('jives', 1.0),
#  ('campy', 1.0),
#  ('narcs', 1.0),
#  ('scrod', 1.0),
#  ('avows', 1.0),
#  ('carom', 1.0),
#  ('psych', 1.0),
#  ('sicko', 1.0),
#  ('coxed', 1.0),
#  ('cloys', 1.0),
#  ('flack', 1.0),
#  ('dutch', 1.0),
#  ('mucky', 1.0),
#  ('duvet', 1.0),
#  ('cowry', 1.0),
#  ('coifs', 1.0),
#  ('deice', 1.0),
#  ('duchy', 1.0),
#  ('carny', 1.0),
#  ('coked', 1.0),
#  ('iliac', 1.0),
#  ('cills', 1.0),
#  ('locos', 1.0),
#  ('vroom', 1.0),
#  ('crocs', 1.0),
#  ('vires', 1.0),
#  ('culpa', 1.0),
#  ('kivas', 1.0),
#  ('abaca', 1.0),
#  ...]

# %% [markdown]
# #### Final Test

# %%
# This will possibly take up to 2 minutes to run
answer = random_word()
work_out_word(answer, True)
print(f"Answer: {answer}")
# Out:
# tares
# doily
# begin
# Final Guess: jingo
# Number of guesses: 4
# Answer: jingo

# %% [markdown]
# #### Real World Test

# %%
# First Guess
guess_info = wordle_guess("tares","___ra")
print(guess_info)
remaining_words = filter_words(words, *guess_info)
print(len(remaining_words))
word_scores = get_word_scores(words, remaining_words, guess_info)
word_scores[:5]
# Out:
# ({}, {('r', 2), ('a', 1)}, {'e', 's', 't'}, {}, {})
# 102
# [('blond', 6.0588235294117645),
#  ('bland', 6.411764705882353),
#  ('crony', 6.450980392156863),
#  ('bronc', 6.450980392156863),
#  ('irony', 6.490196078431373)]

# %%
# Second Guess
guess_info = merge_guess_info(guess_info, wordle_guess("blond", "___n_"))
print(guess_info)
remaining_words = filter_words(words, *guess_info)
print(remaining_words)
word_scores = get_word_scores(words, remaining_words, guess_info)
word_scores[:5]
# Out:
# ({3: 'n'}, {('r', 2), ('a', 1)}, {'d', 'l', 't', 'b', 'o', 's', 'e'}, {}, {})
# ['crank', 'frank', 'franc', 'prank']
# [('force', 1.0),
#  ('facts', 1.0),
#  ('chief', 1.0),
#  ('crops', 1.0),
#  ('faces', 1.0)]

# %%
guess_info = merge_guess_info(guess_info, wordle_guess("force", "rc   "))
print(guess_info)
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ({3: 'n'}, {('r', 2), ('c', 3), ('a', 1)}, {'d', 'l', 't', 'f', 'b', 'o', 's', 'e'}, {}, {})
# ['crank']

# %% [markdown]
# CRANK was correct.
