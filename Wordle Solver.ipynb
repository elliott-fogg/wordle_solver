# %%
import os
import json
import random
import statistics as stats

# %% [markdown]
# Source: https://www-cs-faculty.stanford.edu/~knuth/sgb.html

# %%
with open("sgb-words.txt", "r") as f:
    words = [w for w in f.read().split("\n") if len(w) == 5]
print(len(words))
print(words[:10])
# Out:
# 5757
# ['which', 'there', 'their', 'about', 'would', 'these', 'other', 'words', 'could', 'write']

# %%
def test_wordle_guess(guess, answer):
    print(guess, answer)
    
    green = {}
    yellow = set()
    red = set()
    bad_duplicates = {}
    good_duplicates = {}
    
    current_chars = []
    
    for i in range(5):
        q_char = guess[i]
        current_chars.append(q_char)
        
        if (q_char in bad_duplicates) or (q_char in red):
            # Letter already used and not present, skip
            continue
        
        if not q_char in answer:
            # Character is not in word
            print(f"Character not present: {q_char}")
            red.add(q_char)
            continue
            
        if answer[i] == q_char:
            # Character is present, and in correct place
            print(f"Character correctly placed: {q_char}, {i}")
            green[i] = q_char
            continue
            
        # Check whether it is a duplicate letter
        guess_count = current_chars.count(q_char)
        answer_count = answer.count(q_char)
        print(f"Guess count: {guess_count}, Answer count: {answer_count}")
        if answer_count < guess_count:
            # Letter is a duplicate, and the subsequent one is not in answer
            print(f"Bad duplicate letter: {q_char}, {guess_count}")
            bad_duplicates[q_char] = guess_count
            continue
        elif guess_count > 1:
            good_duplicates[q_char] = guess_count
            
        # Letter must be present in answer, but in wrong place.
        print(f"Letter incorrectly placed: {q_char}, {i}")
        yellow.add( (q_char, i) )
        continue
        
    return (green, yellow, red, bad_duplicates, good_duplicates)


def wordle_guess(guess, answer):
    green = {}
    yellow = set()
    red = set()
    bad_duplicates = {}
    good_duplicates = {}
    
    current_chars = []
    
    for i in range(5):
        q_char = guess[i]
        current_chars.append(q_char)
        
        if (q_char in bad_duplicates) or (q_char in red):
            # Letter already used and not present, skip
            continue
        
        if not q_char in answer:
            # Character is not in word
            red.add(q_char)
            continue
            
        if answer[i] == q_char:
            # Character is present, and in correct place
            green[i] = q_char
            continue
            
        # Check whether it is a duplicate letter
        guess_count = current_chars.count(q_char)
        answer_count = answer.count(q_char)
        if answer_count < guess_count:
            # Letter is a duplicate, and the subsequent one is not in answer
            bad_duplicates[q_char] = guess_count
            continue
        elif guess_count > 1:
            good_duplicates[q_char] = guess_count
            
        # Letter must be present in answer, but in wrong place.
        yellow.add( (q_char, i) )
        continue
        
    return (green, yellow, red, bad_duplicates, good_duplicates)


def dummy_wordle_guess(guess, code):
    green = {}
    yellow = set()
    red = set()
    bad_duplicates = {}
    good_duplicates = {}
    
    current_chars = []
    
    for i in range(len(code)):
        char = guess[i]
        
        if code[i] in "Gg":
            green[i] = char
        
        elif code[i] in "Yy":
            yellow.add( (char, i) )
            if char in current_chars:
                good_duplicates[char] = current_chars.count(char) + 1
                
        elif code[i] in "Rr_":
            if char in current_chars:
                if char not in bad_duplicates:
                    bad_duplicates[char] = current_chars.count(char) + 1
            
            else :
                red.add(char)
            
        current_chars.append(char)
    
    return (green, yellow, red, bad_duplicates, good_duplicates)

# %%
info = test_wordle_guess("henna", "banal")
print(info)
# Out:
# henna banal
# Character not present: h
# Character not present: e
# Character correctly placed: n, 2
# Guess count: 2, Answer count: 1
# Bad duplicate letter: n, 2
# Guess count: 1, Answer count: 2
# Letter incorrectly placed: a, 4
# ({2: 'n'}, {('a', 4)}, {'e', 'h'}, {'n': 2}, {})

# %%
print(wordle_guess("henna", "banal"))
print(dummy_wordle_guess("henna", "rrgry"))
# Out:
# ({2: 'n'}, {('a', 4)}, {'e', 'h'}, {'n': 2}, {})
# ({2: 'n'}, {('a', 4)}, {'e', 'h'}, {'n': 2}, {})

# %%
def test_filter_words(word_list, green, yellow, red, bad_dupes, good_dupes):
    fwl = word_list
    
    print("Green:", green)
    print("Yellow:", yellow)
    print("Red:", red)
    
    for i in green:
        print("green", green[i])
        fwl = [w for w in fwl if w[i]==green[i]]
        
    print(fwl)
        
    for tup in yellow:
        char = tup[0]
        loc = tup[1]
        fwl = [w for w in fwl if (char in w) and (w[loc]!=char)]
        
    print(fwl)
    
    for r in red:
        print("red:", r)
        fwl = [w for w in fwl if r not in w]
        
    print(fwl)
        
    for b in bad_dupes:
        print("bad_dupes:", b)
        fwl = [w for w in fwl if w.count(b) < bad_dupes[b]]
        
    print(fwl)
        
    for g in good_dupes:
        print("good_dupes:", g)
        fwl = [w for w in fwl if w.count(g) >= good_dupes[g]]
        
    print(fwl)
    
    
def filter_words(word_list, green, yellow, red, bad_dupes, good_dupes):
    fwl = word_list
    
    for i in green:
        fwl = [w for w in fwl if w[i]==green[i]]
        
    for tup in yellow:
        char = tup[0]
        loc = tup[1]
        fwl = [w for w in fwl if (char in w) and (w[loc]!=char)]
    
    for r in red:
        fwl = [w for w in fwl if r not in w]
        
    for b in bad_dupes:
        fwl = [w for w in fwl if w.count(b) < bad_dupes[b]]
        
    for g in good_dupes:
        fwl = [w for w in fwl if w.count(g) >= good_dupes[g]]
        
    return fwl

# %%
if os.path.isfile("guess_values.txt"):
    with open("guess_values.txt", "r") as f:
        results = json.load(f)
else:
    results = []

total = len(words)
start_point = len(results)

try:
    for i in range(start_point, total):
        print(f"\r{i} / {total}", end="")
        guess_results = []
        guess = words[i]

        for j in range(total):
            answer = words[j]
            info = wordle_guess(guess, answer)
            guess_results.append(len(filter_words(words, *info)))

        score = sum(guess_results) / len(guess_results)
        results.append( (guess, score) )
        
except KeyboardInterrupt:
    pass
    
finally:
    with open("guess_values.txt", "w+") as f:
        json.dump(results, f)
    print("\nCurrent values saved.")
# Out:
# Current values saved.

# %%
len(results)
# Out:
# 5757

# %%
sorted(results, key=lambda x: x[1], reverse=True)
# Out:
# [['ohhhh', 2492.348966475595],
#  ['immix', 2445.5280528052804],
#  ['gyppy', 2421.6913322911237],
#  ['yukky', 2347.1269758554804],
#  ['fuzzy', 2296.7576862949454],
#  ['buzzy', 2182.3569567483064],
#  ['yummy', 2173.8410630536737],
#  ['mummy', 2161.462914712524],
#  ['ahhhh', 2127.9423310752127],
#  ['civic', 2097.3546986277574],
#  ['puppy', 2083.715476810839],
#  ['kudzu', 2016.0541948931734],
#  ['pffft', 2003.2485669619593],
#  ['vivid', 2003.1024839326037],
#  ['fluff', 1998.348966475595],
#  ['whooo', 1986.1966301893347],
#  ['oxbow', 1979.133229112385],
#  ['whizz', 1978.6539864512768],
#  ['boffo', 1970.2433559145388],
#  ['mamma', 1936.2072259857564],
#  ['jiffy', 1924.8731978461003],
#  ['duddy', 1901.039603960396],
#  ['fizzy', 1897.0015633142261],
#  ['buggy', 1820.8999478895257],
#  ['infix', 1809.924092409241],
#  ['quiff', 1806.859649122807],
#  ['finif', 1800.5528921313185],
#  ['jazzy', 1795.0795553239534],
#  ['pygmy', 1793.4844537085287],
#  ['chuff', 1792.806322737537],
#  ['kooky', 1792.5348271669272],
#  ['chuck', 1789.0524578773666],
#  ['bobby', 1786.6039603960396],
#  ['woozy', 1780.3145735626194],
#  ['huffy', 1771.802327601181],
#  ['villi', 1768.0529789821087],
#  ['yobbo', 1765.0667014069827],
#  ['mimic', 1747.0597533437553],
#  ['booby', 1741.975855480285],
#  ['muggy', 1719.6352266805627],
#  ['hooch', 1718.6256730936252],
#  ['gummy', 1717.471078686816],
#  ['cooch', 1714.3312489143652],
#  ['whiff', 1714.1862080944936],
#  ['puffy', 1714.1671009206184],
#  ['jimmy', 1711.3317700191071],
#  ['mommy', 1709.3665103352441],
#  ['yucky', 1704.0840715650513],
#  ['flyby', 1677.417752301546],
#  ['boozy', 1675.6298419315615],
#  ['hubby', 1667.0590585374327],
#  ['guppy', 1648.7589022060101],
#  ['poppy', 1647.6975855480284],
#  ['zippy', 1631.7500434253952],
#  ['doggo', 1618.162932082682],
#  ['minim', 1593.3663366336634],
#  ['diddy', 1590.1691853395866],
#  ['bluff', 1585.093104047247],
#  ['cubby', 1580.1950668751085],
#  ['fixit', 1577.7938162237276],
#  ['humph', 1577.1912454403334],
#  ['ninny', 1553.1396560708702],
#  ['bubba', 1545.62688900469],
#  ['jujus', 1536.552023623415],
#  ['gonzo', 1536.512940767761],
#  ['jumpy', 1534.7116553760638],
#  ['dizzy', 1534.0267500434254],
#  ['quipu', 1533.1950668751085],
#  ['twixt', 1527.1627583811012],
#  ['magma', 1511.783741532048],
#  ['biffy', 1510.9187076602398],
#  ['abaca', 1509.1907243355915],
#  ['gamma', 1508.9244398124024],
#  ['papaw', 1507.6182039256557],
#  ['kayak', 1505.620288344624],
#  ['funny', 1504.7219037693244],
#  ['buddy', 1504.0896300156332],
#  ['gunny', 1502.2120896300157],
#  ['which', 1496.9133229112385],
#  ['queue', 1493.0642695848533],
#  ['chick', 1489.6803890915407],
#  ['chiff', 1487.990099009901],
#  ['injun', 1484.8777140871982],
#  ['junky', 1483.254299114122],
#  ['foggy', 1481.6836894215737],
#  ['kappa', 1481.5455966649297],
#  ['jaggy', 1478.1651902032308],
#  ['nonny', 1471.2704533611256],
#  ['civvy', 1465.663713739795],
#  ['peeve', 1463.7979850616641],
#  ['cuppy', 1462.9767239881883],
#  ['chock', 1461.3545249261767],
#  ['quaff', 1452.6077818308147],
#  ['abuzz', 1447.69289560535],
#  ['biggy', 1444.1075212784435],
#  ['goofy', 1444.0347403161368],
#  ['mammy', 1443.3328122285914],
#  ['wheee', 1433.995136355741],
#  ['vigil', 1433.8613861386139],
#  ['divvy', 1432.3067569914886],
#  ['doozy', 1430.6661455619246],
#  ['buffo', 1430.4196630189335],
#  ['bunny', 1429.5541080423832],
#  ['djinn', 1427.5125933645995],
#  ['dummy', 1425.2131318394997],
#  ['fully', 1424.277401424353],
#  ['muddy', 1422.5914538822303],
#  ['whoop', 1419.8044120201494],
#  ['known', 1419.1994094146257],
#  ['boggy', 1412.103526142088],
#  ['etext', 1412.0929303456662],
#  ['frizz', 1404.181691853396],
#  ['pampa', 1400.3807538648603],
#  ['ajuga', 1400.0906722251173],
#  ['booky', 1399.9562272016676],
#  ['jammy', 1398.0887615077297],
#  ['gooky', 1394.405072086156],
#  ['gruff', 1392.8108389786346],
#  ['vexed', 1389.727462219906],
#  ['pappy', 1389.4092409240925],
#  ['kicky', 1383.7406635400382],
#  ['tufty', 1382.4613513982977],
#  ['hamza', 1382.0262289386833],
#  ['cluck', 1374.2763592148688],
#  ['huzza', 1372.9272190376932],
#  ['titty', 1362.1848184818482],
#  ['wanna', 1357.992183428869],
#  ['hunch', 1356.8942157373633],
#  ['bully', 1345.5310057321522],
#  ['tutti', 1344.3937814834114],
#  ['zappy', 1342.1651902032308],
#  ['gully', 1341.942678478374],
#  ['tooth', 1339.9308667708876],
#  ['hooky', 1335.4801111690117],
#  ['piggy', 1334.6842105263158],
#  ['femme', 1334.08372416189],
#  ['lolly', 1332.4835852006254],
#  ['byway', 1331.4151467778356],
#  ['cocky', 1330.841410456835],
#  ['hobby', 1320.7102657634184],
#  ['edged', 1318.7741879451103],
#  ['tizzy', 1318.7658502692375],
#  ['affix', 1318.3199583116207],
#  ['mumbo', 1317.0076428695502],
#  ['egged', 1311.699496265416],
#  ['tubby', 1309.7590759075908],
#  ['boomy', 1304.9319089803716],
#  ['ebbed', 1302.499218342887],
#  ['motto', 1302.248219558798],
#  ['pewee', 1300.5798158763246],
#  ['cooky', 1299.062185165885],
#  ['hutch', 1298.9209657807885],
#  ['gutty', 1297.339065485496],
#  ['punny', 1297.3145735626194],
#  ['totty', 1295.7931214174048],
#  ['mujik', 1295.4679520583638],
#  ['dewed', 1294.3666840368248],
#  ['cocci', 1289.8348097967692],
#  ['algal', 1289.43147472642],
#  ['jolly', 1289.4240055584505],
#  ['nohow', 1288.7529963522668],
#  ['oomph', 1287.9531005732151],
#  ['hapax', 1286.5268368942156],
#  ['jumbo', 1285.068785825951],
#  ['buffa', 1281.9821087371895],
#  ['mooch', 1280.3342018412368],
#  ['peppy', 1279.4504081987145],
#  ['kinky', 1278.8846621504256],
#  ['combo', 1276.107868681605],
#  ['mebbe', 1272.6060448150079],
#  ['quick', 1271.3449713392392],
#  ['whump', 1271.0416883793644],
#  ['humpf', 1269.8810144172312],
#  ['dowdy', 1269.5033871808234],
#  ['finny', 1268.8579121070002],
#  ['madam', 1265.495918012854],
#  ['daddy', 1264.1287128712872],
#  ['civil', 1264.068264721209],
#  ['giddy', 1263.0658328990794],
#  ['goopy', 1261.417752301546],
#  ['fudgy', 1259.8792774014244],
#  ['quill', 1257.0844189682125],
#  ['hippy', 1255.9239187076603],
#  ['emcee', 1254.980198019802],
#  ['icing', 1254.0802501302762],
#  ['nimbi', 1252.7757512593364],
#  ['axman', 1250.4945284002085],
#  ['woody', 1249.3315963175264],
#  ['knock', 1248.6678825777315],
#  ['plump', 1247.9562272016676],
#  ['mucky', 1242.9350356088241],
#  ['funky', 1242.4552718429738],
#  ['ginny', 1242.2793121417405],
#  ['bongo', 1240.445197151294],
#  ['aback', 1240.2146951537259],
#  ['tummy', 1238.941115164148],
#  ['chaff', 1229.5634879277402],
#  ['gunky', 1229.0927566440855],
#  ['hadda', 1228.1813444502345],
#  ['fifth', 1227.4076776098661],
#  ['pulpy', 1227.140350877193],
#  ['hoppy', 1226.9909675178044],
#  ['nanny', 1226.58884835852],
#  ['buxom', 1225.1445197151295],
#  ['dixit', 1224.4533611255863],
#  ['cubic', 1220.8306409588326],
#  ['biddy', 1217.9270453361125],
#  ['furry', 1216.5980545422963],
#  ['pooch', 1215.992183428869],
#  ['bumpy', 1210.3805801632795],
#  ['levee', 1206.888830988362],
#  ['unfix', 1206.2697585548028],
#  ['piing', 1205.8631231544207],
#  ['doggy', 1201.3039777661977],
#  ['gabby', 1199.3814486711829],
#  ['baggy', 1199.3802327601181],
#  ['manna', 1198.1726593712003],
#  ['zingy', 1196.9419836720515],
#  ['dodgy', 1195.3336807364947],
#  ['cutup', 1194.1509466736147],
#  ['bumph', 1192.8527010595797],
#  ['gamba', 1191.9161021365294],
#  ['klunk', 1189.8127496960221],
#  ['nooky', 1187.828730241445],
#  ['putty', 1185.3401076949801],
#  ['livid', 1183.718777140872],
#  ['level', 1181.0458572173006],
#  ['filly', 1177.2211221122113],
#  ['goody', 1176.4009032482195],
#  ['cliff', 1175.682994615251],
#  ['allay', 1174.9727288518325],
#  ['guava', 1174.3322911238492],
#  ['middy', 1174.0283133576515],
#  ['cirri', 1173.2602049678653],
#  ['llama', 1170.715476810839],
#  ['momma', 1168.5433385443807],
#  ['check', 1167.5584505819004],
#  ['fluky', 1166.7554281743965],
#  ['unwon', 1165.5980545422963],
#  ['myrrh', 1164.0757338891783],
#  ['goony', 1162.0595796421746],
#  ['nobby', 1155.858606913323],
#  ['reeve', 1155.343408025013],
#  ['chump', 1154.5852006253258],
#  ['click', 1153.5098141393087],
#  ['fifty', 1152.358867465694],
#  ['canna', 1152.136529442418],
#  ['burry', 1149.363731109953],
#  ['cinch', 1146.0026055237104],
#  ['humpy', 1145.893173527879],
#  ['couch', 1143.0647906895954],
#  ['vying', 1141.9001215911064],
#  ['webby', 1141.1896821261073],
#  ['onion', 1140.8825777314573],
#  ['thigh', 1134.8377627236407],
#  ['dippy', 1134.0369984366857],
#  ['rummy', 1133.7059232239014],
#  ['chunk', 1131.7173875282265],
#  ['hubba', 1131.0898037172137],
#  ['shush', 1127.40611429564],
#  ['japan', 1124.3319437206878],
#  ['mixup', 1122.957616814313],
#  ['gypsy', 1121.697238144867],
#  ['pukka', 1120.3486190724336],
#  ['macaw', 1118.5150251867292],
#  ['bonny', 1117.9689074170576],
#  ['papal', 1116.858606913323],
#  ['tight', 1116.203578252562],
#  ['scuzz', 1115.8103178738927],
#  ['mungy', 1113.767760986625],
#  ['nippy', 1112.8775403856175],
#  ['moody', 1112.2985930171965],
#  ['pizza', 1111.1427826993227],
#  ['witty', 1110.0460309188813],
#  ['verve', 1105.9372937293729],
#  ['clock', 1105.820045162411],
#  ['fugue', 1105.8004168837936],
#  ['lowly', 1104.5091193329858],
#  ['folly', 1104.4815007816571],
#  ['tweet', 1098.4530137224249],
#  ['tatty', 1097.209657807886],
#  ['cynic', 1096.6440854611776],
#  ['bulky', 1095.9960048636442],
#  ['conch', 1095.0653117943373],
#  ['klugy', 1094.617509119333],
#  ['dully', 1094.3262115685252],
#  ['laxly', 1092.8000694806324],
#  ['yolky', 1091.0224075039082],
#  ['wooly', 1089.753517457009],
#  ['calla', 1088.9103699843668],
#  ['kaiak', 1088.4585721730068],
#  ['hunky', 1088.2885183255169],
#  ['ducky', 1087.2893868334202],
#  ['plaza', 1087.2833072780961],
#  ['jowly', 1086.4851485148515],
#  ['bwana', 1086.0667014069827],
#  ['pssst', 1086.0052110474205],
#  ['kitty', 1085.83758902206],
#  ['gappy', 1085.1686642348445],
#  ['toffy', 1084.5488969949627],
#  ['bulgy', 1083.897689768977],
#  ['wazoo', 1082.912454403335],
#  ['bloom', 1082.8877887788778],
#  ['vroom', 1081.7472642001042],
#  ['jenny', 1081.7460482890394],
#  ['billy', 1080.5768629494528],
#  ['hexed', 1078.4927913844017],
#  ['uncut', 1077.7038388049332],
#  ['cocoa', 1074.5686989751607],
#  ['lobby', 1074.4170574952232],
#  ['loggy', 1074.402813965607],
#  ['gloom', 1074.0799027271148],
#  ['exude', 1072.9914886225465],
#  ['whomp', 1072.7491749174917],
#  ['hitch', 1071.4286955011291],
#  ['unbox', 1070.8210873718951],
#  ['vacua', 1069.4453708528747],
#  ['ovoid', 1069.338370679173],
#  ['busby', 1068.6451276706619],
#  ['ended', 1067.9968733715477],
#  ['punky', 1067.8448844884488],
#  ['knack', 1065.9709918360256],
#  ['hammy', 1065.6805627931215],
#  ['looky', 1065.4519715129409],
#  ['pudgy', 1065.2470036477332],
#  ['nymph', 1064.159631752649],
#  ['jiffs', 1063.461698801459],
#  ['ceded', 1061.2925134618724],
#  ['busks', 1058.8797985061665],
#  ['unpin', 1057.8896994962654],
#  ['nutty', 1056.688031961091],
#  ['maxim', 1056.3998610387355],
#  ['jewel', 1055.8441896821262],
#  ['quack', 1052.9673441028312],
#  ['moony', 1050.109431995831],
#  ['cabby', 1050.104568351572],
#  ['hurry', 1049.2275490706966],
#  ['whirr', 1048.2265068612123],
#  ['gumbo', 1047.966475594928],
#  ['uvula', 1047.7443112732326],
#  ['golly', 1046.4071565051242],
#  ['juror', 1045.9461525099878],
#  ['swiss', 1045.8759770713914],
#  ['forgo', 1043.1241966301893],
#  ['bimbo', 1042.0505471599793],
#  ['daffy', 1041.4339065485497],
#  ['tunny', 1040.9694285217995],
#  ['whack', 1040.7318047594233],
#  ['faddy', 1040.1405245787737],
#  ['ninja', 1039.9539690811187],
#  ['esses', 1039.7714087198194],
#  ['egger', 1039.3470557582075],
#  ['kazoo', 1038.8092756644085],
#  ['dweeb', 1038.627410109432],
#  ['chili', 1037.6638874413757],
#  ['juicy', 1035.0343929129756],
#  ['bazar', 1034.5148514851485],
#  ['bunch', 1033.660413409762],
#  ['fatwa', 1033.6121243703317],
#  ['brook', 1033.576341844711],
#  ['bitty', 1032.9143651207226],
#  ['booth', 1032.7198193503561],
#  ['wryly', 1031.9183602570783],
#  ['vulva', 1030.861907243356],
#  ['glyph', 1030.8426263679],
#  ['wimpy', 1029.7219037693244],
#  ['chill', 1028.3929129755081],
#  ['beefy', 1027.0107694980024],
#  ['bebug', 1025.5252735799895],
#  ['happy', 1024.8103178738927],
#  ['pavan', 1024.6585026923744],
#  ['buffs', 1023.3399339933993],
#  ['unzip', 1021.3060621851658],
#  ['lippy', 1021.0244919228765],
#  ['freer', 1020.6699669966997],
#  ['gizmo', 1020.4295640090324],
#  ['yawny', 1019.9244398124023],
#  ['grook', 1019.3189161021365],
#  ['crick', 1018.1914191419141],
#  ['lotto', 1017.9025534132361],
#  ['fungi', 1016.957616814313],
#  ['dumpy', 1015.226159458051],
#  ['slyly', 1011.7846100399514],
#  ['abaft', 1010.6107347576863],
#  ['hilly', 1010.2226854264374],
#  ['undid', 1008.8742400555846],
#  ['icily', 1008.0842452666319],
#  ['zombi', 1007.571825603613],
#  ['duomo', 1007.4997394476289],
#  ['deque', 1007.0541948931735],
#  ['ruddy', 1006.4240055584506],
#  ['wedge', 1005.9407677609867],
#  ['refer', 1004.911933298593],
#  ['cheek', 1004.5653986451276],
#  ['alkyl', 1004.4326906374848],
#  ['thumb', 1004.330206704881],
#  ['curry', 1003.9412888657287],
#  ['jelly', 1003.8207399687337],
#  ['yucca', 1003.7771408719819],
#  ['klutz', 1003.0917144346014],
#  ['bibbs', 1002.3494875803369],
#  ['quell', 1002.3163105784263],
#  ['cuppa', 1002.072086155984],
#  ['belle', 1001.7217300677436],
#  ['bedew', 1001.6585026923746],
#  ['idyll', 1001.394649991315],
#  ['vouch', 998.8523536564182],
#  ['ilium', 998.4156678825777],
#  ['musks', 997.5911064790689],
#  ['widow', 996.0819871460831],
#  ['husks', 996.0092061837763],
#  ['flung', 995.8254299114122],
#  ['gawky', 995.2789647385791],
#  ['pinup', 994.490880667014],
#  ['wonky', 993.8271669272191],
#  ['munch', 993.0402987667188],
#  ['dungy', 992.9360778183081],
#  ['fichu', 992.9124544033351],
#  ['duchy', 992.9110647906896],
#  ['hulky', 992.8151815181518],
#  ['bocci', 992.7717561229807],
#  ['fussy', 992.329685600139],
#  ['gimpy', 992.2437033177002],
#  ['lucky', 992.2127844363383],
#  ['kooks', 992.1391349661282],
#  ['brava', 992.1036998436686],
#  ['eject', 992.0746916796943],
#  ['digit', 991.0213652944242],
#  ['noddy', 990.2876498176133],
#  ['crock', 990.2202536043078],
#  ['zilch', 990.2051415667883],
#  ['expel', 989.7658502692375],
#  ['baddy', 989.3006774361646],
#  ['bezel', 988.729199235713],
#  ['pigmy', 988.633489664756],
#  ['array', 988.4088935209311],
#  ['cacao', 987.2384922702796],
#  ['lymph', 987.209136703144],
#  ['fanny', 986.4035087719299],
#  ['junco', 986.3694632621157],
#  ['tippy', 986.137571651902],
#  ['flood', 986.0875455966649],
#  ['booty', 985.4472815702622],
#  ['alway', 985.3960396039604],
#  ['jetty', 985.3416710092062],
#  ['picky', 984.134271321869],
#  ['flunk', 983.7990272711481],
#  ['butch', 983.0232760118117],
#  ['molly', 982.4867118290776],
#  ['muffs', 980.5115511551155],
#  ['loppy', 980.2607260726072],
#  ['pluck', 978.4764634358173],
#  ['huffs', 978.4007295466389],
#  ['teeth', 977.4575299635227],
#  ['unban', 975.0569741184645],
#  ['holly', 975.0118117074866],
#  ['polyp', 974.8224769845406],
#  ['mezzo', 973.6803890915407],
#  ['comfy', 973.6440854611777],
#  ['scuff', 971.9883619940941],
#  ['rugby', 971.6069133229113],
#  ['clack', 971.5341323606045],
#  ['flick', 971.2928608650338],
#  ['photo', 971.2350182386659],
#  ['blini', 970.7026228938684],
#  ['kiddo', 970.1231544207052],
#  ['ribby', 969.4846274101094],
#  ['rajah', 969.3355914538822],
#  ['crook', 967.8056279312142],
#  ['magna', 967.2664582247698],
#  ['plumb', 966.6671877714087],
#  ['outgo', 966.2320653117944],
#  ['broom', 965.9416362688901],
#  ['chink', 965.3981240229286],
#  ['tommy', 964.5584505819003],
#  ['booze', 962.9048115337849],
#  ['bromo', 962.7476116032656],
#  ['excel', 962.6923745006079],
#  ['weepy', 960.4491922876498],
#  ['mondo', 960.1387875629669],
#  ['groom', 959.2688900468994],
#  ['whish', 958.8494007295467],
#  ['winch', 958.6136876845579],
#  ['worry', 958.2456140350877],
#  ['lemme', 957.6498176133402],
#  ['pocky', 956.3031092582943],
#  ['blurb', 956.3008511377453],
#  ['loopy', 955.7535174570089],
#  ['alack', 954.7998957790516],
#  ['howdy', 953.3425395171096],
#  ['embed', 952.7165190203231],
#  ['polly', 952.0540211915928],
#  ['coyly', 950.532221643217],
#  ['oddly', 949.9039430258815],
#  ['gulch', 949.5516762202536],
#  ['chimp', 948.5025186729199],
#  ['queen', 948.3932603786694],
#  ['whiny', 948.0345666145562],
#  ['yecch', 947.9951363557408],
#  ['knoll', 947.5825951016154],
#  ['proof', 947.4623936077818],
#  ['pixie', 947.4580510682647],
#  ['gauzy', 947.2358867465693],
#  ['bevel', 946.8091019628279],
#  ['bough', 946.6609345145041],
#  ['punch', 946.3857912107001],
#  ['hippo', 946.3529616119507],
#  ['tutus', 945.9937467430954],
#  ['puffs', 945.7279833246482],
#  ['fungo', 945.3286433906549],
#  ['chomp', 945.0625325690464],
#  ['ninth', 944.898731978461],
#  ['khaki', 944.6069133229113],
#  ['zooks', 944.4425916275839],
#  ['melee', 944.3937814834115],
#  ['hewed', 944.2219906201146],
#  ['theft', 944.1811707486538],
#  ['boobs', 943.5461177696717],
#  ['fight', 942.6859475421227],
#  ['rooky', 942.6616293208268],
#  ['codon', 941.8890046899427],
#  ['finch', 941.2101789126281],
#  ['jingo', 940.8391523362862],
#  ['mahua', 940.4953969081118],
#  ['weedy', 940.2893868334202],
#  ['phlox', 939.7413583463609],
#  ['skiff', 939.5306583289907],
#  ['pupil', 938.1090845926698],
#  ['blood', 937.4153204794163],
#  ['cycad', 936.7364947021018],
#  ['nihil', 936.5956227201667],
#  ['thump', 936.4292166058711],
#  ['runny', 935.7759249609171],
#  ['lawzy', 933.2817439638701],
#  ['fever', 931.4945284002084],
#  ['shish', 931.4252214695153],
#  ['mewed', 931.3541775230154],
#  ['hafta', 931.1235018238666],
#  ['whoso', 930.7425742574258],
#  ['gayly', 930.2117422268543],
#  ['annum', 928.9862775751259],
#  ['condo', 927.5874587458746],
#  ['idiom', 927.3364599617856],
#  ['rotor', 926.4243529616119],
#  ['hokum', 926.3830119854091],
#  ['rigid', 925.8846621504256],
#  ['evoke', 923.617509119333],
#  ['potty', 922.8443633837068],
#  ['wacky', 922.428174396387],
#  ['comic', 921.9004689942678],
#  ['lumpy', 921.8994267847837],
#  ['twill', 921.8966475594927],
#  ['cuffs', 921.6461698801459],
#  ['unman', 921.3903074517979],
#  ['dilly', 919.7156505124196],
#  ['taffy', 918.8445370852875],
#  ['lulls', 918.3097099183602],
#  ['dunno', 917.5605350008685],
#  ['hying', 917.2160847663714],
#  ['primp', 917.202014938336],
#  ['tepee', 916.8080597533437],
#  ['lulus', 916.2892131318395],
#  ['pagan', 915.258120548897],
#  ['pawky', 914.8012853916971],
#  ['dewey', 914.3011985409067],
#  ['woosh', 913.8876150772973],
#  ['fenny', 913.7896473857912],
#  ['beech', 913.6916796942852],
#  ['plumy', 913.2633315963175],
#  ['hullo', 913.2119159284349],
#  ['mucho', 913.1559840194545],
#  ['timid', 912.682994615251],
#  ['flock', 912.4632621156852],
#  ['mulch', 911.3897863470557],
#  ['unjam', 911.3852701059579],
#  ['quoth', 910.5803369810666],
#  ['lipid', 909.7899947889525],
#  ['frump', 909.5891957616815],
#  ['panga', 908.7953795379537],
#  ['fatty', 908.7545596664929],
#  ['umpty', 908.6126454750738],
#  ['bally', 907.7872155636617],
#  ['dacha', 906.9869723814487],
#  ['avian', 904.9121070001737],
#  ['furor', 904.5534132360605],
#  ['going', 904.0653117943373],
#  ['bozos', 903.3397602918186],
#  ['breve', 903.0053847490012],
#  ['dicky', 902.5719993051937],
#  ['quirk', 901.9233976029182],
#  ['apply', 901.2150425568873],
#  ['bunko', 900.6407851311446],
#  ['curvy', 899.1889873197846],
#  ['kulak', 899.1142956400903],
#  ['rhumb', 898.7081813444503],
#  ['sucks', 897.9225290950147],
#  ['paddy', 897.4877540385618],
#  ['erred', 895.7436164669099],
#  ['mussy', 895.2640264026403],
#  ['folky', 893.4811533784957],
#  ['shoos', 893.382490880667],
#  ['naval', 892.768803196109],
#  ['lulab', 892.3729372937294],
#  ['pinky', 891.9848879624805],
#  ['nitty', 891.8632968560014],
#  ['wassa', 891.6133402813965],
#  ['kabob', 890.4224422442244],
#  ['fjord', 889.4797637658503],
#  ['gutta', 887.504081987146],
#  ['gulag', 887.480458572173],
#  ['cough', 886.627931214174],
#  ['fugit', 886.3774535348272],
#  ['humus', 885.9088066701407],
#  ['wowee', 885.7038388049331],
#  ['radar', 885.0779920097273],
#  ['hussy', 884.5237102657634],
#  ['tinny', 883.5141566788258],
#  ['blowy', 883.4630884141046],
#  ['truth', 883.3708528747611],
#  ['avant', 882.6491228070175],
#  ['burro', 882.5471599791558],
#  ['jerry', 882.4462393607782],
#  ['clump', 882.355567135661],
#  ['nappy', 882.2787910369984],
#  ['roomy', 881.9277401424353],
#  ['nixie', 881.7377106131665],
#  ['ditty', 881.3989925308321],
#  ['yoyos', 880.9298245614035],
#  ['axial', 880.5028660760813],
#  ['cheep', 880.0788605176307],
#  ['poops', 880.0764286955011],
#  ['mafia', 879.8495744311273],
#  ['nylon', 879.1757859996526],
#  ['villa', 878.4947021017891],
#  ['caddy', 877.5612298071912],
#  ['judge', 876.5334375542817],
#  ['kiwis', 876.2732325864165],
#  ['pussy', 875.5124196630189],
#  ['cabal', 874.8872676741358],
#  ['sissy', 873.7724509293034],
#  ['murky', 873.6124717734931],
#  ['mumps', 873.4346013548724],
#  ['hatch', 872.5011290602745],
#  ['snuff', 872.4731631057842],
#  ['witch', 872.2006253256905],
#  ['keyed', 872.0576689247872],
#  ['oxeye', 871.8714608302936],
#  ['grump', 871.7257252040994],
#  ['every', 871.4674309536217],
#  ['honky', 871.3178738926524],
#  ['thunk', 870.7759249609171],
#  ['pumps', 870.5452492617683],
#  ['promo', 870.5325690463783],
#  ['zooms', 869.8594754212263],
#  ['alpha', 869.4813270800764],
#  ['unify', 868.7338891783916],
#  ['adman', 868.6399166232412],
#  ['filmy', 868.5928434948758],
#  ['catch', 867.8594754212263],
#  ['bigly', 867.4214000347404],
#  ['whang', 867.2529095014764],
#  ['windy', 866.989577905159],
#  ['ivied', 866.4978287302414],
#  ['dolly', 866.0569741184645],
#  ['thick', 866.0519367726247],
#  ['mecum', 865.6981066527705],
#  ['abaci', 865.3795379537954],
#  ['hedge', 865.3414973076254],
#  ['filch', 865.1973249956575],
#  ['skunk', 865.0229286086503],
#  ['bilgy', 864.8752822650686],
#  ['fauna', 864.1354872329338],
#  ['block', 862.9784610039951],
#  ['rutty', 862.8791036998437],
#  ['crumb', 861.918533958659],
#  ['whipt', 861.242140003474],
#  ['tabby', 860.9029008163974],
#  ['dusks', 860.0260552371027],
#  ['verge', 858.365989230502],
#  ['mambo', 858.0571478200452],
#  ['cocos', 857.392391870766],
#  ['pubic', 856.699496265416],
#  ['dying', 856.627931214174],
#  ['wahoo', 856.0496786520757],
#  ['iodic', 855.9986103873546],
#  ['asana', 855.4109779398992],
#  ['brood', 855.1170748653813],
#  ['fling', 854.5511551155115],
#  ['crack', 854.1983672051416],
#  ['aging', 854.1598054542296],
#  ['dwell', 853.9498002431823],
#  ['clunk', 852.1165537606392],
#  ['achoo', 851.9060274448498],
#  ['stuff', 851.209136703144],
#  ['twink', 851.0917144346014],
#  ['wrung', 850.11169011638],
#  ['batty', 849.7001910717388],
#  ['assay', 849.4759423310752],
#  ['jumps', 849.0284870592322],
#  ['mufti', 848.9927045336112],
#  ['hexer', 848.6948063227376],
#  ['cusps', 847.9843668577385],
#  ['igloo', 846.7912107000174],
#  ['bight', 846.4476289734237],
#  ['toddy', 846.4052457877367],
#  ['attar', 846.0958832725378],
#  ['dived', 845.8613861386139],
#  ['chewy', 845.4901858606913],
#  ['avail', 845.3399339933993],
#  ['halma', 845.2589890568004],
#  ['amass', 844.5051241966302],
#  ['occur', 844.2937293729373],
#  ['duffs', 844.0184123675525],
#  ['dinky', 843.9942678478374],
#  ['dingy', 842.7366684036825],
#  ['sumps', 842.5204099357304],
#  ['fewer', 841.4783741532048],
#  ['wheel', 841.2756644085462],
#  ['amuck', 840.9756817787041],
#  ['weeny', 839.7430953621678],
#  ['podgy', 839.7059232239013],
#  ['quint', 839.1754385964912],
#  ['leggy', 837.5872850442939],
#  ['elegy', 837.5457703665103],
#  ['comma', 837.2697585548028],
#  ['woofs', 837.2103526142088],
#  ['canny', 836.8000694806323],
#  ['coqui', 836.5407330206705],
#  ['glebe', 835.6696195935383],
#  ['playa', 835.6447802675004],
#  ['brung', 835.5964912280701],
#  ['dotty', 835.3225638353309],
#  ['mucus', 835.143651207226],
#  ['enemy', 834.3651207225986],
#  ['bosom', 834.3116206357478],
#  ['glitz', 834.2808754559667],
#  ['ionic', 833.7163453187424],
#  ['kelly', 833.506861212437],
#  ['kebob', 833.4662150425569],
#  ['delve', 832.5160673962133],
#  ['spivs', 832.0675699148862],
#  ['fuzed', 830.9051589369463],
#  ['psych', 829.7243355914538],
#  ['agave', 828.1915928434948],
#  ['biffs', 827.54820218864],
#  ['toyon', 826.6996699669967],
#  ['oozed', 826.3241271495571],
#  ['limit', 826.219037693243],
#  ['spiff', 826.0825082508251],
#  ['milky', 825.8532221643217],
#  ['event', 825.6531179433733],
#  ['folio', 825.4670835504603],
#  ['holon', 825.2166058711134],
#  ['vinyl', 825.1969775924961],
#  ['jived', 824.620288344624],
#  ['gimme', 824.3988188292514],
#  ['amaze', 824.3939551849921],
#  ['rumor', 824.0111169011637],
#  ['blitz', 823.8504429390307],
#  ['might', 823.277922529095],
#  ['loony', 822.574604828904],
#  ['venue', 822.3619940941462],
#  ['pally', 821.7146083029355],
#  ['ozone', 821.5313531353136],
#  ['plunk', 821.271321869029],
#  ['shiki', 821.0724335591453],
#  ['offal', 820.886051763071],
#  ['fawny', 820.2506513809276],
#  ['jinns', 819.6426958485322],
#  ['feued', 819.5947542122633],
#  ['visit', 818.552544728157],
#  ['gyved', 818.5372589890568],
#  ['frill', 818.5231891610214],
#  ['bawdy', 818.3607781830815],
#  ['tilth', 817.9649122807018],
#  ['clung', 817.6955011290603],
#  ['swigs', 817.519541427827],
#  ['belly', 817.4476289734237],
#  ['sluff', 816.7813097099183],
#  ['flown', 816.0977939899253],
#  ['owing', 815.2292860865034],
#  ['goosy', 815.1462567309362],
#  ['kneed', 814.7620288344624],
#  ['frock', 814.3962133055411],
#  ['pouch', 813.6937641132535],
#  ['geese', 813.4580510682647],
#  ['proxy', 812.4632621156852],
#  ['wisps', 812.2181691853395],
#  ['bylaw', 811.6298419315616],
#  ['dryly', 811.1785652249436],
#  ['pupal', 811.1688379364252],
#  ['conic', 811.046204620462],
#  ['axing', 810.8881361820393],
#  ['error', 810.771061316658],
#  ['kapok', 810.3036303630363],
#  ['scums', 810.2885183255167],
#  ['again', 810.2470036477332],
#  ['queer', 809.4118464478026],
#  ['limby', 809.3606044815008],
#  ['aargh', 809.0687858259511],
#  ['downy', 808.3680736494703],
#  ['musky', 808.081466041341],
#  ['junks', 808.0265763418447],
#  ['xenon', 807.6767413583464],
#  ['dozed', 807.362688900469],
#  ['mimsy', 806.2206010074692],
#  ['miffs', 805.8540906722251],
#  ['admix', 805.4009032482196],
#  ['lynch', 804.3097099183602],
#  ['flaky', 803.4175785999653],
#  ['gonna', 802.7813097099183],
#  ['spazz', 802.7754038561751],
#  ['henge', 801.8886572867813],
#  ['champ', 801.8879624804586],
#  ['young', 801.366510335244],
#  ['vizor', 801.0746916796943],
#  ['cuing', 801.0038214347751],
#  ['flack', 800.8207399687337],
#  ['husky', 799.9310404724683],
#  ['sexes', 798.7166927219038],
#  ['dutch', 798.5021712697586],
#  ['imply', 797.8935209310405],
#  ['itchy', 797.7569914886226],
#  ['tusks', 796.870071217648],
#  ['colon', 796.407851311447],
#  ['karma', 795.6063922181692],
#  ['where', 795.1653639048116],
#  ['skulk', 795.1179433732847],
#  ['licit', 794.5061664061143],
#  ['qualm', 794.3944762897343],
#  ['added', 794.2600312662845],
#  ['shahs', 794.1981935035609],
#  ['pinch', 793.8143130102484],
#  ['weber', 793.3286433906549],
#  ['blink', 792.9673441028314],
#  ['coypu', 792.3903074517979],
#  ['wedgy', 791.8045857217301],
#  ['boron', 791.7800937988536],
#  ['tufts', 791.0760812923397],
#  ['outdo', 790.4766371373979],
#  ['dandy', 789.5362167795727],
#  ['fanin', 789.1891610213653],
#  ['educe', 788.8348097967692],
#  ['blimp', 788.781483411499],
#  ['shows', 787.9228764981762],
#  ['dodos', 787.7099183602571],
#  ['penny', 787.5275317005385],
#  ['swoop', 787.519541427827],
#  ['bitch', 786.9555323953448],
#  ['award', 786.633489664756],
#  ['bhang', 786.6067396213306],
#  ['snugs', 786.3762376237623],
#  ['humid', 786.3381969775925],
#  ['gushy', 786.3375021712698],
#  ['butyl', 786.1036998436686],
#  ['skull', 784.262463088414],
#  ['bunco', 784.1023102310231],
#  ['awash', 784.0404724682994],
#  ['boffs', 783.8066701406983],
#  ['swish', 783.552544728157],
#  ['augur', 783.304325169359],
#  ['bushy', 783.0118117074866],
#  ['unhip', 782.6046552023623],
#  ['epoxy', 782.052284175786],
#  ['privy', 781.931735278791],
#  ['refry', 781.6380059058538],
#  ['patty', 781.5209310404724],
#  ['zooey', 781.1792600312663],
#  ['crump', 781.1622372763592],
#  ['shook', 780.9593538301199],
#  ['lilty', 780.6869897516067],
#  ['tenet', 779.4361646690985],
#  ['wanta', 778.9409414625673],
#  ['grebe', 778.6185513288171],
#  ['coach', 778.3751954142783],
#  ['usury', 777.911933298593],
#  ['width', 777.7955532395345],
#  ['brick', 777.5937120027792],
#  ['floor', 777.1928087545597],
#  ['exile', 777.100746916797],
#  ['fence', 777.0762549939204],
#  ['noons', 776.9864512767066],
#  ['dough', 776.4316484280007],
#  ['forky', 776.3260378669446],
#  ['botch', 776.2982456140351],
#  ['awful', 776.046725725204],
#  ['emend', 775.8264721208963],
#  ['climb', 775.1132534306062],
#  ['swims', 773.649470210179],
#  ['busts', 773.4498870939725],
#  ['heigh', 773.4319958311621],
#  ['krill', 771.5461177696717],
#  ['fucks', 771.4259162758381],
#  ['whisk', 771.2723640785131],
#  ['calyx', 771.1295813791905],
#  ['exurb', 770.4288692027097],
#  ['usurp', 770.1917665450756],
#  ['kicks', 769.9800243182212],
#  ['cumin', 769.8817092235539],
#  ['ohmic', 769.8108389786347],
#  ['gusts', 769.7592496091714],
#  ['scoff', 769.5957964217474],
#  ['weave', 769.3315963175265],
#  ['exert', 769.2541254125413],
#  ['tagua', 768.9419836720514],
#  ['equip', 768.7835678304673],
#  ['goofs', 768.7665450755602],
#  ['allow', 768.3277748827514],
#  ['bombe', 767.654333854438],
#  ['vexes', 767.0062532569046],
#  ['fulls', 766.9475421226333],
#  ['droop', 766.4135834636095],
#  ['phony', 765.8084071565052],
#  ['himbo', 765.1532047941636],
#  ['knell', 764.8452318916102],
#  ['blown', 764.6484280006948],
#  ['grill', 764.444676046552],
#  ['books', 764.4234844537085],
#  ['nabla', 764.2143477505646],
#  ['union', 763.764460656592],
#  ['ember', 763.711655376064],
#  ['flail', 762.653812749696],
#  ['ville', 762.5815528921313],
#  ['spook', 762.4509293034566],
#  ['ferry', 762.4276532916449],
#  ['beget', 761.8553065832899],
#  ['shyly', 761.0896300156331],
#  ['bronx', 761.0201493833594],
#  ['whelk', 760.865207573389],
#  ['parka', 760.6678825777315],
#  ['mamas', 760.5435122459614],
#  ['upped', 760.1966301893348],
#  ['greek', 759.522320653118],
#  ['skims', 759.1714434601355],
#  ['skips', 759.064964391176],
#  ['catty', 758.4919228764982],
#  ['wharf', 758.343408025013],
#  ['black', 758.0759075907591],
#  ['fugal', 758.0251867291993],
#  ['oxlip', 757.9647385791211],
#  ['ought', 757.8570435990968],
#  ['milch', 757.5659197498697],
#  ['tweed', 757.3232586416536],
#  ['lunch', 756.7071391349662],
#  ['anima', 756.3531353135313],
#  ['luvya', 756.3388917839152],
#  ['snubs', 756.2216432169532],
#  ['jello', 756.1994094146256],
#  ['spoof', 756.1163800590585],
#  ['fatal', 755.6718777140871],
#  ['gooks', 755.6079555323953],
#  ['banal', 755.2073996873371],
#  ['butte', 755.1822129581379],
#  ['unfit', 754.8846621504256],
#  ['think', 754.405593190898],
#  ['druid', 754.1813444502345],
#  ['quark', 753.5777314573562],
#  ['highs', 753.5284002084419],
#  ['sagas', 752.7149557060969],
#  ['gigue', 752.1075212784436],
#  ['aquae', 751.4313010248393],
#  ['offed', 750.3121417404899],
#  ['shuck', 749.9883619940941],
#  ['pitch', 749.8146604134098],
#  ['night', 749.301545944068],
#  ['sunup', 748.9628278617336],
#  ['sniff', 748.9440680910196],
#  ['alibi', 748.8313357651555],
#  ['wring', 748.6616293208268],
#  ['undue', 747.4099357304151],
#  ['hoofs', 747.3564356435644],
#  ['vixen', 746.6209831509467],
#  ['nifty', 745.974118464478],
#  ['casas', 745.8674656939378],
#  ['hewer', 745.0144172311968],
#  ['vocab', 745.0111169011637],
#  ['pithy', 744.5285739100226],
#  ['socko', 743.9211394823693],
#  ['quilt', 743.8952579468473],
#  ['mothy', 743.8410630536738],
#  ['mushy', 743.7708876150773],
#  ['twist', 743.2173006774361],
#  ['awake', 743.0151120375195],
#  ['hooks', 742.9423310752128],
#  ['moron', 742.7799200972729],
#  ['robot', 742.7564703838805],
#  ['thwap', 741.9980892826125],
#  ['lying', 741.2633315963175],
#  ['plebe', 741.2046204620463],
#  ['dally', 741.1337502171269],
#  ['odour', 741.0369984366857],
#  ['ennui', 740.9624804585721],
#  ['kebab', 740.9230501997569],
#  ['musts', 740.8829251346187],
#  ['croon', 740.0687858259511],
#  ['edger', 739.9888830988363],
#  ['epees', 739.9881882925134],
#  ['fudge', 739.5158936946326],
#  ['thing', 738.5098141393087],
#  ['papas', 738.4498870939725],
#  ...]

# %%
def random_word():
    value = int(random.random() * len(words))
    return words[value]


def get_word_scores(all_words, remaining_words, current_info=None):
    results = []
    for assumed_guess in all_words:
        guess_results = []
        for assumed_answer in remaining_words:
            guess_info = wordle_guess(assumed_guess, assumed_answer)
            assumed_info = merge_guess_info(guess_info, current_info)
            assumed_remaining_words = filter_words(remaining_words, (*assumed_info))
            guess_results.append(len(assumed_remaining_words))
        
        score = sum(guess_results) / len(guess_results)
        results.append( (assumed_guess, score) )
        
    return sorted(results, key=lambda x: x[1])


def merge_guess_info(info1, info2):
    default_info = ({}, set(), set(), {}, {})
    
    if info1 == None:
        info1 = default_info
    if info2 == None:
        info2 = default_info
        
    # Merge Greens
    green = {**info1[0], **info2[0]}
    
    # Merge Yellows
    yellow = info1[1].union(info2[1])
    
    # Merge Reds
    red = info1[2].union(info2[2])
    
    # Merge bad_dupes
    bad_dupes = {**info1[3], **info2[3]}
    
    # Merge good_dupes
    good_dupes = info1[4]
    for key in info2[4]:
        if key in good_dupes:
            good_dupes[key] = max(good_dupes[key], info2[4][key])
        else:
            good_dupes[key] = info2[4][key]

    return (green, yellow, red, bad_dupes, good_dupes)
    
        

def work_out_word(answer, print_guesses=False):
    guess = "tares"
    remaining_words = words
    guess_info = None
    guesses = []
    
    while True:
        if print_guesses:
            print(guess)
        guesses.append(guess)
        guess_info = merge_guess_info(wordle_guess(guess, answer), guess_info)
        remaining_words = filter_words(remaining_words, *guess_info)
        if len(remaining_words) == 1:
            guesses.append(remaining_words[0])
            if print_guesses:
                print(f"Final Guess: {remaining_words[0]}")
                print(f"Number of guesses: {len(guesses)}")
            return len(guesses)
        else:
            word_scores = get_word_scores(words, remaining_words, guess_info)
            guess = sorted(word_scores, key=lambda x: x[1])[0][0]

# %% [markdown]
# #### Test 1

# %%
answer = random_word()
guess = "tares"
guess_info = merge_guess_info(wordle_guess(guess, answer), None)
remaining_words = filter_words(words, *guess_info)
remaining_words
# Out:
# ['rules',
#  'rises',
#  'ropes',
#  'cries',
#  'rides',
#  'roses',
#  'roles',
#  'robes',
#  'dries',
#  'urges',
#  'frees',
#  'pries',
#  'fries',
#  'roves',
#  'ruses',
#  'runes',
#  'riles',
#  'rubes',
#  'bries',
#  'rives',
#  'rimes',
#  'rices']

# %%
word_scores = get_word_scores(remaining_words, guess_info)
print(word_scores)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('rules', 5.0), ('rises', 5.0), ('ropes', 5.0), ('cries', 5.0), ('rides', 5.0), ('roses', 5.0), ('roles', 5.0), ('robes', 5.0), ('dries', 5.0), ('urges', 5.0), ('frees', 5.0), ('pries', 5.0), ('fries', 5.0), ('roves', 5.0), ('ruses', 5.0), ('runes', 5.0), ('riles', 5.0), ('rubes', 5.0), ('bries', 5.0), ('rives', 5.0), ('rimes', 5.0), ('rices', 5.0)]
# [('rules', 5.0),
#  ('rises', 5.0),
#  ('ropes', 5.0),
#  ('cries', 5.0),
#  ('rides', 5.0),
#  ('roses', 5.0),
#  ('roles', 5.0),
#  ('robes', 5.0),
#  ('dries', 5.0),
#  ('urges', 5.0),
#  ('frees', 5.0),
#  ('pries', 5.0),
#  ('fries', 5.0),
#  ('roves', 5.0),
#  ('ruses', 5.0),
#  ('runes', 5.0),
#  ('riles', 5.0),
#  ('rubes', 5.0),
#  ('bries', 5.0),
#  ('rives', 5.0),
#  ('rimes', 5.0),
#  ('rices', 5.0)]

# %%
guess2 = "nests"
guess_info = merge_guess_info(guess_info, wordle_guess(guess2, answer))
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ['rises', 'roses', 'ruses']

# %% [markdown]
# So if we only consider words that might be the answer (i.e. Hard Mode), we can end up in a situation where there is one letter missing that could be any of a handful of letters, with no way to eliminate them other than try them all. This can easily take us over the 6 guess limit. Therefore, we need to check the Expected Value of EVERY word in the full word list, for every guess. This will presumably take about 4 seconds per iteration, but will give us a much better chance.
#
# EDIT: Okay, it's a lot more than 4 seconds per iteration. This may not be entirely feasible...
#
# EDIT 2: Okay, it's fine. A run only takes up to about a minute.

# %% [markdown]
# #### Test 2

# %%
guess = "tares"
guess_info = merge_guess_info(wordle_guess(guess, answer), None)
remaining_words = filter_words(words, *guess_info)
remaining_words
# Out:
# ['rules',
#  'rises',
#  'ropes',
#  'cries',
#  'rides',
#  'roses',
#  'roles',
#  'robes',
#  'dries',
#  'urges',
#  'frees',
#  'pries',
#  'fries',
#  'roves',
#  'ruses',
#  'runes',
#  'riles',
#  'rubes',
#  'bries',
#  'rives',
#  'rimes',
#  'rices']

# %%
word_scores = get_word_scores(words, remaining_words, guess_info)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('build', 2.4545454545454546),
#  ('broil', 2.909090909090909),
#  ('limbo', 2.909090909090909),
#  ('bison', 3.0),
#  ('disco', 3.0),
#  ('built', 3.090909090909091),
#  ('bipod', 3.1818181818181817),
#  ('boils', 3.272727272727273),
#  ('guild', 3.272727272727273),
#  ('pismo', 3.272727272727273),
#  ('blind', 3.3636363636363638),
#  ('blimp', 3.3636363636363638),
#  ('proud', 3.5454545454545454),
#  ('coils', 3.5454545454545454),
#  ('foils', 3.5454545454545454),
#  ('croup', 3.5454545454545454),
#  ('doily', 3.5454545454545454),
#  ('oiled', 3.5454545454545454),
#  ('rosin', 3.5454545454545454),
#  ('bruin', 3.5454545454545454),
#  ('gismo', 3.5454545454545454),
#  ('wilco', 3.5454545454545454),
#  ('dildo', 3.5454545454545454),
#  ('pilau', 3.5454545454545454),
#  ('climb', 3.6363636363636362),
#  ('pilot', 3.6363636363636362),
#  ('olive', 3.6363636363636362),
#  ('robin', 3.6363636363636362),
#  ('viola', 3.6363636363636362),
#  ('lucid', 3.6363636363636362),
#  ('visor', 3.6363636363636362),
#  ('voile', 3.6363636363636362),
#  ('lisps', 3.6363636363636362),
#  ('lingo', 3.6363636363636362),
#  ('runic', 3.6363636363636362),
#  ('voila', 3.6363636363636362),
#  ('viols', 3.6363636363636362),
#  ('primo', 3.6363636363636362),
#  ('bingo', 3.727272727272727),
#  ('blips', 3.727272727272727),
#  ('roils', 3.727272727272727),
#  ('bruit', 3.727272727272727),
#  ('roily', 3.727272727272727),
#  ('orbit', 3.8181818181818183),
#  ('pubic', 3.8181818181818183),
#  ('doing', 3.909090909090909),
#  ('lions', 3.909090909090909),
#  ('loins', 3.909090909090909),
#  ('fling', 3.909090909090909),
#  ('opium', 3.909090909090909),
#  ('cupid', 3.909090909090909),
#  ('odium', 3.909090909090909),
#  ('dingo', 3.909090909090909),
#  ('hilum', 3.909090909090909),
#  ('bimbo', 3.909090909090909),
#  ('druid', 3.909090909090909),
#  ('limos', 3.909090909090909),
#  ('biome', 3.909090909090909),
#  ('himbo', 3.909090909090909),
#  ('voice', 4.0),
#  ('round', 4.0),
#  ('radio', 4.0),
#  ('rival', 4.0),
#  ('quilt', 4.0),
#  ('guilt', 4.0),
#  ('quill', 4.0),
#  ('blink', 4.0),
#  ('guile', 4.0),
#  ('fiord', 4.0),
#  ('video', 4.0),
#  ('voids', 4.0),
#  ('bigot', 4.0),
#  ('bilge', 4.0),
#  ('divot', 4.0),
#  ('fichu', 4.0),
#  ('droid', 4.0),
#  ('coifs', 4.0),
#  ('roids', 4.0),
#  ('bigly', 4.0),
#  ('bilgy', 4.0),
#  ('blini', 4.0),
#  ('could', 4.090909090909091),
#  ('cloud', 4.090909090909091),
#  ('fluid', 4.090909090909091),
#  ('prior', 4.090909090909091),
#  ('cling', 4.090909090909091),
#  ('pivot', 4.090909090909091),
#  ('unify', 4.090909090909091),
#  ('dicot', 4.090909090909091),
#  ('dictu', 4.090909090909091),
#  ('dipso', 4.090909090909091),
#  ('folic', 4.090909090909091),
#  ('picot', 4.090909090909091),
#  ('dicut', 4.090909090909091),
#  ('cuing', 4.090909090909091),
#  ('music', 4.181818181818182),
#  ('sling', 4.818181818181818),
#  ('glint', 4.818181818181818),
#  ('binds', 4.818181818181818),
#  ('lurid', 4.818181818181818),
#  ('drips', 4.818181818181818),
#  ('pried', 4.818181818181818),
#  ('trios', 4.818181818181818),
#  ('prick', 4.818181818181818),
#  ('align', 4.818181818181818),
#  ('hippo', 4.818181818181818),
#  ('riven', 4.818181818181818),
#  ('liege', 4.818181818181818),
#  ('liens', 4.818181818181818),
#  ('gibed', 4.818181818181818),
#  ('grail', 4.818181818181818),
#  ('ligne', 4.818181818181818),
#  ('redip', 4.818181818181818),
#  ('ilium', 4.818181818181818),
#  ('lings', 4.818181818181818),
#  ('being', 4.909090909090909),
#  ('using', 4.909090909090909),
#  ('child', 4.909090909090909),
#  ('units', 4.909090909090909),
#  ('trail', 4.909090909090909),
#  ('trial', 4.909090909090909),
#  ('rises', 4.909090909090909),
#  ('print', 4.909090909090909),
#  ('unity', 4.909090909090909),
#  ('rails', 4.909090909090909),
#  ('unite', 4.909090909090909),
#  ('risks', 4.909090909090909),
#  ('discs', 4.909090909090909),
#  ('risky', 4.909090909090909),
#  ('beige', 4.909090909090909),
#  ('ripen', 4.909090909090909),
#  ('trill', 4.909090909090909),
#  ('suing', 4.909090909090909),
#  ('rills', 4.909090909090909),
#  ('drool', 4.909090909090909),
#  ('droll', 4.909090909090909),
#  ('riser', 4.909090909090909),
#  ('krill', 4.909090909090909),
#  ('quint', 4.909090909090909),
#  ('binge', 4.909090909090909),
#  ('riles', 4.909090909090909),
#  ('prink', 4.909090909090909),
#  ('brigs', 4.909090909090909),
#  ('rille', 4.909090909090909),
#  ('rials', 4.909090909090909),
#  ('broad', 5.0),
#  ('tribe', 5.0),
#  ('grind', 5.0),
#  ('brisk', 5.0),
#  ('brood', 5.0),
#  ('bribe', 5.0),
#  ('rabbi', 5.0),
#  ('robed', 5.0),
#  ('briar', 5.0),
#  ('colic', 5.0),
#  ('brier', 5.0),
#  ('credo', 5.0),
#  ('bunco', 5.0),
#  ('bries', 5.0),
#  ('oldie', 5.0),
#  ('ioctl', 5.0),
#  ('orbed', 5.0),
#  ('ribby', 5.0),
#  ('bocci', 5.0),
#  ('tribs', 5.0),
#  ('lives', 5.090909090909091),
#  ('basic', 5.090909090909091),
#  ('visit', 5.090909090909091),
#  ('drink', 5.090909090909091),
#  ('alive', 5.090909090909091),
#  ('noise', 5.090909090909091),
#  ('solid', 5.090909090909091),
#  ('prime', 5.090909090909091),
#  ('flies', 5.090909090909091),
#  ('joint', 5.090909090909091),
#  ('moist', 5.090909090909091),
#  ('pupil', 5.090909090909091),
#  ('vital', 5.090909090909091),
#  ('noisy', 5.090909090909091),
#  ('prism', 5.090909090909091),
#  ('piles', 5.090909090909091),
#  ('liver', 5.090909090909091),
#  ('drain', 5.090909090909091),
#  ('fills', 5.090909090909091),
#  ('joins', 5.090909090909091),
#  ('files', 5.090909090909091),
#  ('onion', 5.090909090909091),
#  ('fails', 5.090909090909091),
#  ('lifts', 5.090909090909091),
#  ('fists', 5.090909090909091),
#  ('idols', 5.090909090909091),
#  ('slips', 5.090909090909091),
#  ('spill', 5.090909090909091),
#  ('evils', 5.090909090909091),
#  ('pails', 5.090909090909091),
#  ('tulip', 5.090909090909091),
#  ('pills', 5.090909090909091),
#  ('pixel', 5.090909090909091),
#  ('filly', 5.090909090909091),
#  ('veils', 5.090909090909091),
#  ('filth', 5.090909090909091),
#  ('villa', 5.090909090909091),
#  ('wisps', 5.090909090909091),
#  ('flier', 5.090909090909091),
#  ('omits', 5.090909090909091),
#  ('spilt', 5.090909090909091),
#  ('fishy', 5.090909090909091),
#  ('flirt', 5.090909090909091),
#  ('plies', 5.090909090909091),
#  ('vista', 5.090909090909091),
#  ('rinds', 5.090909090909091),
#  ('filet', 5.090909090909091),
#  ('fitly', 5.090909090909091),
#  ('vials', 5.090909090909091),
#  ('frond', 5.090909090909091),
#  ('visas', 5.090909090909091),
#  ('wispy', 5.090909090909091),
#  ('flits', 5.090909090909091),
#  ('viler', 5.090909090909091),
#  ('vises', 5.090909090909091),
#  ('axiom', 5.090909090909091),
#  ('boric', 5.090909090909091),
#  ('anion', 5.090909090909091),
#  ('prima', 5.090909090909091),
#  ('viral', 5.090909090909091),
#  ('spiel', 5.090909090909091),
#  ('moire', 5.090909090909091),
#  ('lifer', 5.090909090909091),
#  ('winos', 5.090909090909091),
#  ('vibes', 5.090909090909091),
#  ('adlib', 5.090909090909091),
#  ('primp', 5.090909090909091),
#  ('mimeo', 5.090909090909091),
#  ('drubs', 5.090909090909091),
#  ('oinks', 5.090909090909091),
#  ('nitro', 5.090909090909091),
#  ('gimel', 5.090909090909091),
#  ('limen', 5.090909090909091),
#  ('noire', 5.090909090909091),
#  ('livre', 5.090909090909091),
#  ('nimbi', 5.090909090909091),
#  ('lippy', 5.090909090909091),
#  ('ville', 5.090909090909091),
#  ('phial', 5.090909090909091),
#  ('fisty', 5.090909090909091),
#  ('giros', 5.090909090909091),
#  ('limns', 5.090909090909091),
#  ('miaow', 5.090909090909091),
#  ('filar', 5.090909090909091),
#  ('filer', 5.090909090909091),
#  ('villi', 5.090909090909091),
#  ('oinky', 5.090909090909091),
#  ('vails', 5.090909090909091),
#  ('koine', 5.090909090909091),
#  ('prims', 5.090909090909091),
#  ('crink', 5.090909090909091),
#  ('pubis', 5.090909090909091),
#  ('idiom', 5.136363636363637),
#  ('found', 5.181818181818182),
#  ('quite', 5.181818181818182),
#  ('cried', 5.181818181818182),
#  ('quiet', 5.181818181818182),
#  ('rough', 5.181818181818182),
#  ('bound', 5.181818181818182),
#  ('route', 5.181818181818182),
#  ('suits', 5.181818181818182),
#  ('trout', 5.181818181818182),
#  ('suite', 5.181818181818182),
#  ('dimly', 5.181818181818182),
#  ('rouse', 5.181818181818182),
#  ('bravo', 5.181818181818182),
#  ('guise', 5.181818181818182),
#  ('rouge', 5.181818181818182),
#  ('quirk', 5.181818181818182),
#  ('rogue', 5.181818181818182),
#  ('quits', 5.181818181818182),
#  ('sinus', 5.181818181818182),
#  ('routs', 5.181818181818182),
#  ('frock', 5.818181818181818),
#  ('milks', 5.818181818181818),
#  ('rondo', 5.818181818181818),
#  ('miser', 5.818181818181818),
#  ('croon', 5.818181818181818),
#  ('vouch', 5.818181818181818),
#  ('crone', 5.818181818181818),
#  ('irked', 5.818181818181818),
#  ('crony', 5.818181818181818),
#  ('radix', 5.818181818181818),
#  ('triad', 5.818181818181818),
#  ('revue', 5.818181818181818),
#  ('crier', 5.818181818181818),
#  ('trice', 5.818181818181818),
#  ('miler', 5.818181818181818),
#  ('radon', 5.818181818181818),
#  ('crick', 5.818181818181818),
#  ('croft', 5.818181818181818),
#  ('belie', 5.818181818181818),
#  ('poufs', 5.818181818181818),
#  ('redid', 5.818181818181818),
#  ('slims', 5.818181818181818),
#  ('limey', 5.818181818181818),
#  ('missy', 5.818181818181818),
#  ('crits', 5.818181818181818),
#  ('ricer', 5.818181818181818),
#  ('rices', 5.818181818181818),
#  ('train', 5.909090909090909),
#  ('prove', 5.909090909090909),
#  ('rains', 5.909090909090909),
#  ('rainy', 5.909090909090909),
#  ('reins', 5.909090909090909),
#  ('rinse', 5.909090909090909),
#  ('undid', 5.909090909090909),
#  ('chimp', 5.909090909090909),
#  ('jumbo', 5.909090909090909),
#  ('ovule', 5.909090909090909),
#  ('rinks', 5.909090909090909),
#  ('gumbo', 5.909090909090909),
#  ('buxom', 5.909090909090909),
#  ('mogul', 5.909090909090909),
#  ('deice', 5.909090909090909),
#  ('ohmic', 5.909090909090909),
#  ('mumbo', 5.909090909090909),
#  ('nicad', 5.909090909090909),
#  ('musos', 5.909090909090909),
#  ('nudie', 5.909090909090909),
#  ('spiff', 5.909090909090909),
#  ('login', 5.909090909090909),
#  ('rules', 6.0),
#  ('ruler', 6.0),
#  ('truly', 6.0),
#  ('rural', 6.0),
#  ('rusty', 6.0),
#  ('fraud', 6.0),
#  ('tunic', 6.0),
#  ('gruel', 6.0),
#  ('rusts', 6.0),
#  ('ruses', 6.0),
#  ('rusks', 6.0),
#  ('vroom', 6.0),
#  ('russe', 6.0),
#  ('cruft', 6.0),
#  ('until', 6.090909090909091),
#  ('gives', 6.090909090909091),
#  ('royal', 6.090909090909091),
#  ('views', 6.090909090909091),
#  ('rolls', 6.090909090909091),
#  ('roses', 6.090909090909091),
#  ('veins', 6.090909090909091),
#  ('urban', 6.090909090909091),
#  ('vines', 6.090909090909091),
#  ('roles', 6.090909090909091),
#  ('sieve', 6.090909090909091),
#  ('naive', 6.090909090909091),
#  ('troll', 6.090909090909091),
#  ('grime', 6.090909090909091),
#  ('erode', 6.090909090909091),
#  ('conic', 6.090909090909091),
#  ('dogie', 6.090909090909091),
#  ('grimy', 6.090909090909091),
#  ('brunt', 6.090909090909091),
#  ('vixen', 6.090909090909091),
#  ('motif', 6.090909090909091),
#  ('giver', 6.090909090909091),
#  ('brung', 6.090909090909091),
#  ('unlit', 6.090909090909091),
#  ('veiny', 6.090909090909091),
#  ('avian', 6.090909090909091),
#  ('orals', 6.090909090909091),
#  ('modus', 6.090909090909091),
#  ('coqui', 6.090909090909091),
#  ('rifer', 6.181818181818182),
#  ('inode', 6.181818181818182),
#  ('finny', 6.181818181818182),
#  ('rimer', 6.181818181818182),
#  ('atilt', 6.181818181818182),
#  ('icily', 6.2272727272727275),
#  ('iliac', 6.2272727272727275),
#  ('chief', 6.2727272727272725),
#  ('plain', 6.2727272727272725),
#  ('pitch', 6.2727272727272725),
#  ('fixed', 6.2727272727272725),
#  ('brush', 6.2727272727272725),
#  ('claim', 6.2727272727272725),
#  ('birth', 6.2727272727272725),
#  ('fired', 6.2727272727272725),
#  ...]

# %%
guess2 = "lento"
guess_info = merge_guess_info(wordle_guess(guess2, answer), guess_info)
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ['ropes', 'roses', 'robes', 'roves']

# %%
word_scores = get_word_scores(words, remaining_words, guess_info)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('above', 1.5),
#  ('basic', 1.5),
#  ('verbs', 1.5),
#  ('visit', 1.5),
#  ('based', 1.5),
#  ('prove', 1.5),
#  ('basis', 1.5),
#  ('brave', 1.5),
#  ('vapor', 1.5),
#  ('bases', 1.5),
#  ('upset', 1.5),
#  ('paste', 1.5),
#  ('posts', 1.5),
#  ('basin', 1.5),
#  ('buses', 1.5),
#  ('paved', 1.5),
#  ('probe', 1.5),
#  ('bosom', 1.5),
#  ('bevel', 1.5),
#  ('bushy', 1.5),
#  ('bumps', 1.5),
#  ('pivot', 1.5),
#  ('pests', 1.5),
#  ('posed', 1.5),
#  ('plumb', 1.5),
#  ('bison', 1.5),
#  ('vases', 1.5),
#  ('wasps', 1.5),
#  ('beset', 1.5),
#  ('gasps', 1.5),
#  ('posse', 1.5),
#  ('poses', 1.5),
#  ('pussy', 1.5),
#  ('pesos', 1.5),
#  ('wisps', 1.5),
#  ('bossy', 1.5),
#  ('spasm', 1.5),
#  ('bravo', 1.5),
#  ('visor', 1.5),
#  ('beeps', 1.5),
#  ('baste', 1.5),
#  ('viper', 1.5),
#  ('vista', 1.5),
#  ('busts', 1.5),
#  ('baser', 1.5),
#  ('vests', 1.5),
#  ('rasps', 1.5),
#  ('pasta', 1.5),
#  ('visas', 1.5),
#  ('wispy', 1.5),
#  ('paves', 1.5),
#  ('bused', 1.5),
#  ('basks', 1.5),
#  ('lisps', 1.5),
#  ('bests', 1.5),
#  ('blimp', 1.5),
#  ('vises', 1.5),
#  ('bumpy', 1.5),
#  ('basil', 1.5),
#  ('basal', 1.5),
#  ('breve', 1.5),
#  ('privy', 1.5),
#  ('pesky', 1.5),
#  ('cusps', 1.5),
#  ('hasps', 1.5),
#  ('basso', 1.5),
#  ('pasty', 1.5),
#  ('raspy', 1.5),
#  ('bebop', 1.5),
#  ('poser', 1.5),
#  ('blips', 1.5),
#  ('apses', 1.5),
#  ('vibes', 1.5),
#  ('peeve', 1.5),
#  ('posit', 1.5),
#  ('biped', 1.5),
#  ('bosun', 1.5),
#  ('pesto', 1.5),
#  ('plebe', 1.5),
#  ('vamps', 1.5),
#  ('vapid', 1.5),
#  ('veeps', 1.5),
#  ('cuspy', 1.5),
#  ('bossa', 1.5),
#  ('busty', 1.5),
#  ('pushy', 1.5),
#  ('burps', 1.5),
#  ('poset', 1.5),
#  ('bipod', 1.5),
#  ('absit', 1.5),
#  ('pssst', 1.5),
#  ('epsom', 1.5),
#  ('spivs', 1.5),
#  ('passe', 1.5),
#  ('busby', 1.5),
#  ('vapes', 1.5),
#  ('poste', 1.5),
#  ('bosky', 1.5),
#  ('vised', 1.5),
#  ('pismo', 1.5),
#  ('bumph', 1.5),
#  ('waspy', 1.5),
#  ('pubic', 1.5),
#  ('pavan', 1.5),
#  ('plebs', 1.5),
#  ('boson', 1.5),
#  ('vocab', 1.5),
#  ('bassi', 1.5),
#  ('brava', 1.5),
#  ('pubes', 1.5),
#  ('paver', 1.5),
#  ('busks', 1.5),
#  ('pasha', 1.5),
#  ('apsos', 1.5),
#  ('besot', 1.5),
#  ('pasts', 1.5),
#  ('pubis', 1.5),
#  ('about', 2.5),
#  ('place', 2.5),
#  ('every', 2.5),
#  ('never', 2.5),
#  ('below', 2.5),
#  ('being', 2.5),
#  ('began', 2.5),
#  ('paper', 2.5),
#  ('parts', 2.5),
#  ('point', 2.5),
#  ('given', 2.5),
#  ('music', 2.5),
#  ('group', 2.5),
#  ('space', 2.5),
#  ('table', 2.5),
#  ('black', 2.5),
#  ('voice', 2.5),
#  ('power', 2.5),
#  ('lived', 2.5),
#  ('vowel', 2.5),
#  ('built', 2.5),
#  ('bring', 2.5),
#  ('piece', 2.5),
#  ('birds', 2.5),
#  ('river', 2.5),
#  ('leave', 2.5),
#  ('moved', 2.5),
#  ('plant', 2.5),
#  ('heavy', 2.5),
#  ('begin', 2.5),
#  ('plane', 2.5),
#  ('spell', 2.5),
#  ('books', 2.5),
#  ('party', 2.5),
#  ('build', 2.5),
#  ('blood', 2.5),
#  ('seven', 2.5),
#  ('solve', 2.5),
#  ('value', 2.5),
#  ('maybe', 2.5),
#  ('happy', 2.5),
#  ('gives', 2.5),
#  ('shape', 2.5),
#  ('lives', 2.5),
#  ('steps', 2.5),
#  ('sense', 2.5),
#  ('speak', 2.5),
#  ('speed', 2.5),
#  ('sleep', 2.5),
#  ('pages', 2.5),
#  ('ships', 2.5),
#  ('level', 2.5),
#  ('board', 2.5),
#  ('cover', 2.5),
#  ('waves', 2.5),
#  ('spoke', 2.5),
#  ('break', 2.5),
#  ('drive', 2.5),
#  ('spent', 2.5),
#  ('bread', 2.5),
#  ('brown', 2.5),
#  ('peace', 2.5),
#  ('helps', 2.5),
#  ('sharp', 2.5),
#  ('cases', 2.5),
#  ('crops', 2.5),
#  ('sheep', 2.5),
#  ('plain', 2.5),
#  ('bones', 2.5),
#  ('apart', 2.5),
#  ('moves', 2.5),
#  ('spend', 2.5),
#  ('empty', 2.5),
#  ('broke', 2.5),
#  ('pairs', 2.5),
#  ('paint', 2.5),
#  ('serve', 2.5),
#  ('alive', 2.5),
#  ('types', 2.5),
#  ('piano', 2.5),
#  ('upper', 2.5),
#  ('loved', 2.5),
#  ('drove', 2.5),
#  ('cabin', 2.5),
#  ('boats', 2.5),
#  ('proud', 2.5),
#  ('prime', 2.5),
#  ('plans', 2.5),
#  ('price', 2.5),
#  ('boxes', 2.5),
#  ('graph', 2.5),
#  ('doubt', 2.5),
#  ('block', 2.5),
#  ('topic', 2.5),
#  ('plate', 2.5),
#  ('plays', 2.5),
#  ('broad', 2.5),
#  ('press', 2.5),
#  ('taste', 2.5),
#  ('brain', 2.5),
#  ('beach', 2.5),
#  ('saved', 2.5),
#  ('avoid', 2.5),
#  ('keeps', 2.5),
#  ('bells', 2.5),
#  ('apple', 2.5),
#  ('climb', 2.5),
#  ('pitch', 2.5),
#  ('costs', 2.5),
#  ('blank', 2.5),
#  ('labor', 2.5),
#  ('globe', 2.5),
#  ('gases', 2.5),
#  ('poles', 2.5),
#  ('apply', 2.5),
#  ('brush', 2.5),
#  ('tests', 2.5),
#  ('waste', 2.5),
#  ('hoped', 2.5),
#  ('strip', 2.5),
#  ('begun', 2.5),
#  ('bound', 2.5),
#  ('depth', 2.5),
#  ('event', 2.5),
#  ('pound', 2.5),
#  ('drops', 2.5),
#  ('spite', 2.5),
#  ('orbit', 2.5),
#  ('banks', 2.5),
#  ('curve', 2.5),
#  ('tribe', 2.5),
#  ('blind', 2.5),
#  ('slept', 2.5),
#  ('issue', 2.5),
#  ('birth', 2.5),
#  ('brief', 2.5),
#  ('burst', 2.5),
#  ('bears', 2.5),
#  ('brass', 2.5),
#  ('opera', 2.5),
#  ('beats', 2.5),
#  ('poems', 2.5),
#  ('label', 2.5),
#  ('beans', 2.5),
#  ('split', 2.5),
#  ('rises', 2.5),
#  ('pride', 2.5),
#  ('badly', 2.5),
#  ('boots', 2.5),
#  ('pilot', 2.5),
#  ('swept', 2.5),
#  ('prize', 2.5),
#  ('stove', 2.5),
#  ('tubes', 2.5),
#  ('steep', 2.5),
#  ('porch', 2.5),
#  ('slave', 2.5),
#  ('waved', 2.5),
#  ('favor', 2.5),
#  ('views', 2.5),
#  ('spots', 2.5),
#  ('blend', 2.5),
#  ('balls', 2.5),
#  ('trips', 2.5),
#  ('hopes', 2.5),
#  ('bench', 2.5),
#  ('shops', 2.5),
#  ('movie', 2.5),
#  ('slope', 2.5),
#  ('bands', 2.5),
#  ('thumb', 2.5),
#  ('habit', 2.5),
#  ('reply', 2.5),
#  ('fever', 2.5),
#  ('print', 2.5),
#  ('verse', 2.5),
#  ('civil', 2.5),
#  ('blade', 2.5),
#  ('lists', 2.5),
#  ('stops', 2.5),
#  ('rapid', 2.5),
#  ('brick', 2.5),
#  ('beads', 2.5),
#  ('beast', 2.5),
#  ('nerve', 2.5),
#  ('penny', 2.5),
#  ('pulls', 2.5),
#  ('sport', 2.5),
#  ('blows', 2.5),
#  ('lever', 2.5),
#  ('proof', 2.5),
#  ('pause', 2.5),
#  ('novel', 2.5),
#  ('burnt', 2.5),
#  ('spare', 2.5),
#  ('pipes', 2.5),
#  ('bills', 2.5),
#  ('parks', 2.5),
#  ('bunch', 2.5),
#  ('paths', 2.5),
#  ('grave', 2.5),
#  ('pupil', 2.5),
#  ('patch', 2.5),
#  ('nests', 2.5),
#  ('vital', 2.5),
#  ('blame', 2.5),
#  ('vocal', 2.5),
#  ('bacon', 2.5),
#  ('loves', 2.5),
#  ('backs', 2.5),
#  ('ropes', 2.5),
#  ('phone', 2.5),
#  ('peaks', 2.5),
#  ('beard', 2.5),
#  ('opens', 2.5),
#  ('input', 2.5),
#  ('cubic', 2.5),
#  ('wives', 2.5),
#  ('burns', 2.5),
#  ('poets', 2.5),
#  ('apron', 2.5),
#  ('spear', 2.5),
#  ('stamp', 2.5),
#  ('baked', 2.5),
#  ('wiped', 2.5),
#  ('blown', 2.5),
#  ('piled', 2.5),
#  ('clubs', 2.5),
#  ('sweep', 2.5),
#  ('spoon', 2.5),
#  ('crept', 2.5),
#  ('maple', 2.5),
#  ('dusty', 2.5),
#  ('devil', 2.5),
#  ('tempo', 2.5),
#  ('roses', 2.5),
#  ('noble', 2.5),
#  ('cheap', 2.5),
#  ('woven', 2.5),
#  ('bowed', 2.5),
#  ('belts', 2.5),
#  ('grasp', 2.5),
#  ('blast', 2.5),
#  ('polar', 2.5),
#  ('pearl', 2.5),
#  ('veins', 2.5),
#  ('loses', 2.5),
#  ('hosts', 2.5),
#  ('diver', 2.5),
#  ('phase', 2.5),
#  ('tasks', 2.5),
#  ('puppy', 2.5),
#  ('jumps', 2.5),
#  ('spoil', 2.5),
#  ('spark', 2.5),
#  ('vivid', 2.5),
#  ('brook', 2.5),
#  ('spray', 2.5),
#  ('ports', 2.5),
#  ('urban', 2.5),
#  ('bride', 2.5),
#  ('hobby', 2.5),
#  ('bonds', 2.5),
#  ('pants', 2.5),
#  ('votes', 2.5),
#  ('voted', 2.5),
#  ('caves', 2.5),
#  ('broom', 2.5),
#  ('panel', 2.5),
#  ('olive', 2.5),
#  ('bends', 2.5),
#  ('prism', 2.5),
#  ('lamps', 2.5),
#  ('cable', 2.5),
#  ('peach', 2.5),
#  ('lambs', 2.5),
#  ('limbs', 2.5),
#  ('brake', 2.5),
#  ('cubes', 2.5),
#  ('beams', 2.5),
#  ('vines', 2.5),
#  ('picks', 2.5),
#  ('naval', 2.5),
#  ('purse', 2.5),
#  ('ponds', 2.5),
#  ('pools', 2.5),
#  ('brand', 2.5),
#  ('robot', 2.5),
#  ('bloom', 2.5),
#  ('risen', 2.5),
#  ('fiber', 2.5),
#  ('piles', 2.5),
#  ('rests', 2.5),
#  ('panic', 2.5),
#  ('crisp', 2.5),
#  ('dived', 2.5),
#  ('swamp', 2.5),
#  ('liver', 2.5),
#  ('breed', 2.5),
#  ('belly', 2.5),
#  ('bowls', 2.5),
#  ('haste', 2.5),
#  ('scope', 2.5),
#  ('essay', 2.5),
#  ('thump', 2.5),
#  ('bliss', 2.5),
#  ('bombs', 2.5),
#  ('palms', 2.5),
#  ('bored', 2.5),
#  ('camps', 2.5),
#  ('lover', 2.5),
#  ('punch', 2.5),
#  ('noses', 2.5),
#  ('pulse', 2.5),
#  ('elbow', 2.5),
#  ('rusty', 2.5),
#  ('traps', 2.5),
#  ('valid', 2.5),
#  ('robin', 2.5),
#  ('prior', 2.5),
#  ('polio', 2.5),
#  ('vague', 2.5),
#  ('weave', 2.5),
#  ('virus', 2.5),
#  ('pluck', 2.5),
#  ('burro', 2.5),
#  ('buggy', 2.5),
#  ('pumps', 2.5),
#  ('spins', 2.5),
#  ('pains', 2.5),
#  ('photo', 2.5),
#  ('rival', 2.5),
#  ('syrup', 2.5),
#  ('pints', 2.5),
#  ('scrap', 2.5),
#  ('gypsy', 2.5),
#  ('bless', 2.5),
#  ('bugle', 2.5),
#  ('loops', 2.5),
#  ('bites', 2.5),
#  ('debts', 2.5),
#  ('glove', 2.5),
#  ('poked', 2.5),
#  ('lumps', 2.5),
#  ('barns', 2.5),
#  ('masts', 2.5),
#  ('pours', 2.5),
#  ('plump', 2.5),
#  ('robes', 2.5),
#  ('pedal', 2.5),
#  ('beets', 2.5),
#  ('slash', 2.5),
#  ('creep', 2.5),
#  ('chips', 2.5),
#  ('fists', 2.5),
#  ('valve', 2.5),
#  ('ivory', 2.5),
#  ('clamp', 2.5),
#  ('barge', 2.5),
#  ('blues', 2.5),
#  ('strap', 2.5),
#  ('saves', 2.5),
#  ('stump', 2.5),
#  ('bulbs', 2.5),
#  ('lasts', 2.5),
#  ('slips', 2.5),
#  ('troop', 2.5),
#  ('bolts', 2.5),
#  ('tramp', 2.5),
#  ('blaze', 2.5),
#  ('scrub', 2.5),
#  ('crabs', 2.5),
#  ('adobe', 2.5),
#  ('rebel', 2.5),
#  ('spine', 2.5),
#  ('desks', 2.5),
#  ('grove', 2.5),
#  ('leaps', 2.5),
#  ('prose', 2.5),
#  ('tusks', 2.5),
#  ('bulls', 2.5),
#  ('plank', 2.5),
#  ('pines', 2.5),
#  ('brace', 2.5),
#  ('scalp', 2.5),
#  ('adopt', 2.5),
#  ('clump', 2.5),
#  ('perch', 2.5),
#  ('fable', 2.5),
#  ('sober', 2.5),
#  ('boast', 2.5),
#  ('swish', 2.5),
#  ('booth', 2.5),
#  ('eased', 2.5),
#  ('tombs', 2.5),
#  ('pouch', 2.5),
#  ('pinch', 2.5),
#  ('buyer', 2.5),
#  ('vigor', 2.5),
#  ('herbs', 2.5),
#  ('bleak', 2.5),
#  ('blunt', 2.5),
#  ('masks', 2.5),
#  ('risks', 2.5),
#  ('ample', 2.5),
#  ('bluff', 2.5),
#  ('bathe', 2.5),
#  ('bonus', 2.5),
#  ('birch', 2.5),
#  ('anvil', 2.5),
#  ('speck', 2.5),
#  ('spied', 2.5),
#  ('plows', 2.5),
#  ('blond', 2.5),
#  ('banjo', 2.5),
#  ('bulky', 2.5),
#  ('carve', 2.5),
#  ('pears', 2.5),
#  ('fives', 2.5),
#  ('flaps', 2.5),
#  ('spout', 2.5),
#  ('adapt', 2.5),
#  ('tasty', 2.5),
#  ('stoop', 2.5),
#  ('clips', 2.5),
#  ('disks', 2.5),
#  ('brisk', 2.5),
#  ('imply', 2.5),
#  ('super', 2.5),
#  ('typed', 2.5),
#  ('wiser', 2.5),
#  ('beaks', 2.5),
#  ('casts', 2.5),
#  ('baths', 2.5),
#  ('plots', 2.5),
#  ('resin', 2.5),
#  ('puffs', 2.5),
#  ('brood', 2.5),
#  ('abuse', 2.5),
#  ('ovary', 2.5),
#  ('heaps', 2.5),
#  ('civic', 2.5),
#  ('packs', 2.5),
#  ('corps', 2.5),
#  ('repay', 2.5),
#  ('repel', 2.5),
#  ('husky', 2.5),
#  ('mists', 2.5),
#  ('baker', 2.5),
#  ('spice', 2.5),
#  ('oasis', 2.5),
#  ('boils', 2.5),
#  ('spurs', 2.5),
#  ('doves', 2.5),
#  ('paces', 2.5),
#  ('bales', 2.5),
#  ('piped', 2.5),
#  ('nasty', 2.5),
#  ('boxer', 2.5),
#  ('shrub', 2.5),
#  ('larva', 2.5),
#  ('spool', 2.5),
#  ('spill', 2.5),
#  ('snaps', 2.5),
#  ('smash', 2.5),
#  ('plums', 2.5),
#  ('zebra', 2.5),
#  ('slabs', 2.5),
#  ('evils', 2.5),
#  ('peril', 2.5),
#  ('lobby', 2.5),
#  ('viola', 2.5),
#  ('chops', 2.5),
#  ('skips', 2.5),
#  ('misty', 2.5),
#  ('knobs', 2.5),
#  ('pails', 2.5),
#  ('borne', 2.5),
#  ('polls', 2.5),
#  ('nasal', 2.5),
#  ('tulip', 2.5),
#  ('nymph', 2.5),
#  ('budge', 2.5),
#  ('abide', 2.5),
#  ('depot', 2.5),
#  ('oases', 2.5),
#  ('asses', 2.5),
#  ('pills', 2.5),
#  ('rivet', 2.5),
#  ('boost', 2.5),
#  ('broth', 2.5),
#  ('heave', 2.5),
#  ('gravy', 2.5),
#  ('beech', 2.5),
#  ('bough', 2.5),
#  ('shave', 2.5),
#  ('spore', 2.5),
#  ('paced', 2.5),
#  ('braid', 2.5),
#  ('spies', 2.5),
#  ('discs', 2.5),
#  ('asset', 2.5),
#  ('taper', 2.5),
#  ('bully', 2.5),
#  ('aisle', 2.5),
#  ('bulge', 2.5),
#  ('tapes', 2.5),
#  ('bunks', 2.5),
#  ('panes', 2.5),
#  ('caste', 2.5),
#  ('pores', 2.5),
#  ('poise', 2.5),
#  ('epoch', 2.5),
#  ('risky', 2.5),
#  ('berry', 2.5),
#  ('grape', 2.5),
#  ('pelts', 2.5),
#  ('barks', 2.5),
#  ('whoop', 2.5),
#  ('whips', 2.5),
#  ('bikes', 2.5),
#  ('vault', 2.5),
#  ('blink', 2.5),
#  ('pupae', 2.5),
#  ('sieve', 2.5),
#  ('spike', 2.5),
#  ('pizza', 2.5),
#  ('brink', 2.5),
#  ('pagan', 2.5),
#  ('scoop', 2.5),
#  ('amber', 2.5),
#  ('gusts', 2.5),
#  ('lasso', 2.5),
#  ('debut', 2.5),
#  ('prone', 2.5),
#  ('dives', 2.5),
#  ('pinto', 2.5),
#  ('brows', 2.5),
#  ('batch', 2.5),
#  ('blush', 2.5),
#  ('onset', 2.5),
#  ('barbs', 2.5),
#  ('volts', 2.5),
#  ('beige', 2.5),
#  ('swoop', 2.5),
#  ('paddy', 2.5),
#  ('shove', 2.5),
#  ('poppy', 2.5),
#  ('brute', 2.5),
#  ('doses', 2.5),
#  ('petty', 2.5),
#  ('cobra', 2.5),
#  ('messy', 2.5),
#  ('ripen', 2.5),
#  ('plaid', 2.5),
#  ('spiny', 2.5),
#  ('baton', 2.5),
#  ('peers', 2.5),
#  ('vowed', 2.5),
#  ('pious', 2.5),
#  ('plugs', 2.5),
#  ('berth', 2.5),
#  ('grubs', 2.5),
#  ('hasty', 2.5),
#  ('baron', 2.5),
#  ('plead', 2.5),
#  ('pixel', 2.5),
#  ('bared', 2.5),
#  ('buddy', 2.5),
#  ('chaps', 2.5),
#  ('badge', 2.5),
#  ('mumps', 2.5),
#  ('ovens', 2.5),
#  ('fussy', 2.5),
#  ('bleed', 2.5),
#  ('elves', 2.5),
#  ('roped', 2.5),
#  ('baggy', 2.5),
#  ('grabs', 2.5),
#  ('album', 2.5),
#  ('burly', 2.5),
#  ('brine', 2.5),
#  ('vanes', 2.5),
#  ('spurt', 2.5),
#  ('combs', 2.5),
#  ('easel', 2.5),
#  ('humps', 2.5),
#  ('swiss', 2.5),
#  ('leapt', 2.5),
#  ('opium', 2.5),
#  ('pansy', 2.5),
#  ('soaps', 2.5),
#  ('husks', 2.5),
#  ('snips', 2.5),
#  ('naive', 2.5),
#  ('wraps', 2.5),
#  ('piers', 2.5),
#  ('booty', 2.5),
#  ('valor', 2.5),
#  ('mossy', 2.5),
#  ('psalm', 2.5),
#  ('scuba', 2.5),
#  ('polka', 2.5),
#  ('laser', 2.5),
#  ('bribe', 2.5),
#  ('flips', 2.5),
#  ('boxed', 2.5),
#  ('hoops', 2.5),
#  ('fuses', 2.5),
#  ('droop', 2.5),
#  ('bucks', 2.5),
#  ('pangs', 2.5),
#  ('haven', 2.5),
#  ('clasp', 2.5),
#  ('champ', 2.5),
#  ('piety', 2.5),
#  ('chirp', 2.5),
#  ('pleat', 2.5),
#  ('sunup', 2.5),
#  ('plaza', 2.5),
#  ('bangs', 2.5),
#  ('erupt', 2.5),
#  ('poker', 2.5),
#  ('cramp', 2.5),
#  ('voter', 2.5),
#  ('slump', 2.5),
#  ('grips', 2.5),
#  ('gaped', 2.5),
#  ('purge', 2.5),
#  ('sloop', 2.5),
#  ('prowl', 2.5),
#  ('bland', 2.5),
#  ('plume', 2.5),
#  ('slaps', 2.5),
#  ('soups', 2.5),
#  ('eaves', 2.5),
#  ('fused', 2.5),
#  ('veils', 2.5),
#  ('mused', 2.5),
#  ('bouts', 2.5),
#  ('sisal', 2.5),
#  ('hoses', 2.5),
#  ('hover', 2.5),
#  ('seeps', 2.5),
#  ('putty', 2.5),
#  ('guppy', 2.5),
#  ('dusky', 2.5),
#  ('oboes', 2.5),
#  ('spans', 2.5),
#  ('obeys', 2.5),
#  ('bakes', 2.5),
#  ('abyss', 2.5),
#  ('claps', 2.5),
#  ('spicy', 2.5),
#  ('vicar', 2.5),
#  ('musty', 2.5),
#  ('loser', 2.5),
#  ('lapse', 2.5),
#  ('vexed', 2.5),
#  ('spade', 2.5),
#  ('broil', 2.5),
#  ('aspen', 2.5),
#  ('avert', 2.5),
#  ('havoc', 2.5),
#  ('jeeps', 2.5),
#  ('props', 2.5),
#  ('prune', 2.5),
#  ('pokes', 2.5),
#  ('villa', 2.5),
#  ('binds', 2.5),
#  ('livid', 2.5),
#  ('booms', 2.5),
#  ('lusty', 2.5),
#  ('vigil', 2.5),
#  ('spars', 2.5),
#  ('dumps', 2.5),
#  ('panda', 2.5),
#  ('plied', 2.5),
#  ('booby', 2.5),
#  ('patio', 2.5),
#  ('rabbi', 2.5),
#  ('petal', 2.5),
#  ('polyp', 2.5),
#  ('phony', 2.5),
#  ('bleat', 2.5),
#  ('aptly', 2.5),
#  ('soapy', 2.5),
#  ('taped', 2.5),
#  ('spawn', 2.5),
#  ('burrs', 2.5),
#  ('alibi', 2.5),
#  ('lymph', 2.5),
#  ('covet', 2.5),
#  ('venom', 2.5),
#  ('sassy', 2.5),
#  ('prays', 2.5),
#  ('stave', 2.5),
#  ('pecks', 2.5),
#  ('stomp', 2.5),
#  ('tempt', 2.5),
#  ('capes', 2.5),
#  ('mesas', 2.5),
#  ('tepee', 2.5),
#  ('evoke', 2.5),
#  ('verge', 2.5),
#  ('crumb', 2.5),
#  ('spire', 2.5),
#  ('jumpy', 2.5),
#  ('buoys', 2.5),
#  ('stubs', 2.5),
#  ('arbor', 2.5),
#  ('bitch', 2.5),
#  ('gulps', 2.5),
#  ('waver', 2.5),
#  ('mason', 2.5),
#  ('lobes', 2.5),
#  ('ebony', 2.5),
#  ('adept', 2.5),
#  ('plush', 2.5),
#  ('paled', 2.5),
#  ('scamp', 2.5),
#  ('pawed', 2.5),
#  ('grope', 2.5),
#  ('gable', 2.5),
#  ('sever', 2.5),
#  ('babes', 2.5),
#  ('throb', 2.5),
#  ('pecan', 2.5),
#  ('butts', 2.5),
#  ('pence', 2.5),
#  ('saber', 2.5),
#  ('curbs', 2.5),
#  ('cheep', 2.5),
#  ('evade', 2.5),
#  ('vogue', 2.5),
#  ('dumpy', 2.5),
#  ('spits', 2.5),
#  ('nosed', 2.5),
#  ('bloat', 2.5),
#  ('balsa', 2.5),
#  ('sperm', 2.5),
#  ('copra', 2.5),
#  ('popes', 2.5),
#  ('tapir', 2.5),
#  ('spree', 2.5),
#  ('revel', 2.5),
#  ('raven', 2.5),
#  ('ember', 2.5),
#  ('wipes', 2.5),
#  ('piggy', 2.5),
#  ('inept', 2.5),
#  ('gusty', 2.5),
#  ('equip', 2.5),
#  ('leper', 2.5),
#  ('taboo', 2.5),
#  ('ovals', 2.5),
#  ('pleas', 2.5),
#  ('beret', 2.5),
#  ('spilt', 2.5),
#  ('rover', 2.5),
#  ('pygmy', 2.5),
#  ('abbey', 2.5),
#  ('vents', 2.5),
#  ('chimp', 2.5),
#  ('vinyl', 2.5),
#  ('bores', 2.5),
#  ('bunny', 2.5),
#  ('purer', 2.5),
#  ('blare', 2.5),
#  ('navel', 2.5),
#  ('paler', 2.5),
#  ('puffy', 2.5),
#  ('casks', 2.5),
#  ('derby', 2.5),
#  ('gavel', 2.5),
#  ('vomit', 2.5),
#  ('abhor', 2.5),
#  ('stabs', 2.5),
#  ('pored', 2.5),
#  ('loped', 2.5),
#  ('fishy', 2.5),
#  ('bible', 2.5),
#  ('jambs', 2.5),
#  ('rugby', 2.5),
#  ('expel', 2.5),
#  ('aback', 2.5),
#  ('valet', 2.5),
#  ('epics', 2.5),
#  ('pikes', 2.5),
#  ('caper', 2.5),
#  ('robed', 2.5),
#  ('salve', 2.5),
#  ('mushy', 2.5),
#  ('rumps', 2.5),
#  ('pinks', 2.5),
#  ('rusts', 2.5),
#  ('parka', 2.5),
#  ('booed', 2.5),
#  ('butte', 2.5),
#  ('poled', 2.5),
#  ('spank', 2.5),
#  ('tepid', 2.5),
#  ('spook', 2.5),
#  ('spiky', 2.5),
#  ('opals', 2.5),
#  ('miser', 2.5),
#  ('balmy', 2.5),
#  ('slosh', 2.5),
#  ('brawl', 2.5),
#  ('aphid', 2.5),
#  ('brags', 2.5),
#  ('video', 2.5),
#  ('eases', 2.5),
#  ('impel', 2.5),
#  ('savor', 2.5),
#  ('proxy', 2.5),
#  ('clove', 2.5),
#  ('briar', 2.5),
#  ('halve', 2.5),
#  ('mauve', 2.5),
#  ('envoy', 2.5),
#  ('arson', 2.5),
#  ('coves', 2.5),
#  ('brews', 2.5),
#  ('abbot', 2.5),
#  ('cribs', 2.5),
#  ('harps', 2.5),
#  ('coupe', 2.5),
#  ('flops', 2.5),
#  ('weeps', 2.5),
#  ('divan', 2.5),
#  ('vices', 2.5),
#  ('jumbo', 2.5),
#  ('blobs', 2.5),
#  ('blots', 2.5),
#  ('spunk', 2.5),
#  ('topaz', 2.5),
#  ('cubed', 2.5),
#  ('pumas', 2.5),
#  ('plies', 2.5),
#  ('brunt', 2.5),
#  ('tuber', 2.5),
#  ('bayou', 2.5),
#  ('fasts', 2.5),
#  ('damps', 2.5),
#  ('palsy', 2.5),
#  ('preen', 2.5),
#  ('pulpy', 2.5),
#  ('baled', 2.5),
#  ('hovel', 2.5),
#  ('lavas', 2.5),
#  ('crave', 2.5),
#  ('optic', 2.5),
#  ('knave', 2.5),
#  ('veers', 2.5),
#  ('sprig', 2.5),
#  ('snobs', 2.5),
#  ('pined', 2.5),
#  ('perky', 2.5),
#  ('booze', 2.5),
#  ('tripe', 2.5),
#  ('prong', 2.5),
#  ('drips', 2.5),
#  ('levee', 2.5),
#  ('pithy', 2.5),
#  ('yelps', 2.5),
#  ('buffs', 2.5),
#  ('bogey', 2.5),
#  ('vales', 2.5),
#  ('coped', 2.5),
#  ('bulks', 2.5),
#  ('vying', 2.5),
#  ('pacts', 2.5),
#  ('scabs', 2.5),
#  ('dusts', 2.5),
#  ('jibes', 2.5),
#  ('preys', 2.5),
#  ('peeks', 2.5),
#  ('assay', 2.5),
#  ('boars', 2.5),
#  ('belch', 2.5),
#  ('dosed', 2.5),
#  ('snipe', 2.5),
#  ...]

# %%
guess3 = "budge"
guess_info = merge_guess_info(wordle_guess(guess3, answer), guess_info)
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ['ropes', 'roses', 'roves']

# %%
word_scores = get_word_scores(words, remaining_words, guess_info)
sorted(word_scores, key=lambda x: x[1])
# Out:
# [('visit', 1.0),
#  ('prove', 1.0),
#  ('vapor', 1.0),
#  ('upset', 1.0),
#  ('paste', 1.0),
#  ('posts', 1.0),
#  ('paved', 1.0),
#  ('pivot', 1.0),
#  ('pests', 1.0),
#  ('posed', 1.0),
#  ('vases', 1.0),
#  ('wasps', 1.0),
#  ('gasps', 1.0),
#  ('posse', 1.0),
#  ('poses', 1.0),
#  ('pussy', 1.0),
#  ('pesos', 1.0),
#  ('wisps', 1.0),
#  ('spasm', 1.0),
#  ('visor', 1.0),
#  ('viper', 1.0),
#  ('vista', 1.0),
#  ('vests', 1.0),
#  ('rasps', 1.0),
#  ('pasta', 1.0),
#  ('visas', 1.0),
#  ('wispy', 1.0),
#  ('paves', 1.0),
#  ('lisps', 1.0),
#  ('vises', 1.0),
#  ('privy', 1.0),
#  ('pesky', 1.0),
#  ('cusps', 1.0),
#  ('hasps', 1.0),
#  ('pasty', 1.0),
#  ('raspy', 1.0),
#  ('poser', 1.0),
#  ('apses', 1.0),
#  ('peeve', 1.0),
#  ('posit', 1.0),
#  ('pesto', 1.0),
#  ('vamps', 1.0),
#  ('vapid', 1.0),
#  ('veeps', 1.0),
#  ('cuspy', 1.0),
#  ('pushy', 1.0),
#  ('poset', 1.0),
#  ('pssst', 1.0),
#  ('epsom', 1.0),
#  ('spivs', 1.0),
#  ('passe', 1.0),
#  ('vapes', 1.0),
#  ('poste', 1.0),
#  ('vised', 1.0),
#  ('pismo', 1.0),
#  ('waspy', 1.0),
#  ('pavan', 1.0),
#  ('paver', 1.0),
#  ('pasha', 1.0),
#  ('apsos', 1.0),
#  ('pasts', 1.0),
#  ('place', 1.6666666666666667),
#  ('every', 1.6666666666666667),
#  ('never', 1.6666666666666667),
#  ('above', 1.6666666666666667),
#  ('paper', 1.6666666666666667),
#  ('parts', 1.6666666666666667),
#  ('point', 1.6666666666666667),
#  ('given', 1.6666666666666667),
#  ('music', 1.6666666666666667),
#  ('group', 1.6666666666666667),
#  ('space', 1.6666666666666667),
#  ('voice', 1.6666666666666667),
#  ('power', 1.6666666666666667),
#  ('lived', 1.6666666666666667),
#  ('vowel', 1.6666666666666667),
#  ('piece', 1.6666666666666667),
#  ('river', 1.6666666666666667),
#  ('leave', 1.6666666666666667),
#  ('moved', 1.6666666666666667),
#  ('plant', 1.6666666666666667),
#  ('heavy', 1.6666666666666667),
#  ('plane', 1.6666666666666667),
#  ('spell', 1.6666666666666667),
#  ('party', 1.6666666666666667),
#  ('seven', 1.6666666666666667),
#  ('solve', 1.6666666666666667),
#  ('value', 1.6666666666666667),
#  ('happy', 1.6666666666666667),
#  ('gives', 1.6666666666666667),
#  ('shape', 1.6666666666666667),
#  ('lives', 1.6666666666666667),
#  ('steps', 1.6666666666666667),
#  ('sense', 1.6666666666666667),
#  ('speak', 1.6666666666666667),
#  ('speed', 1.6666666666666667),
#  ('sleep', 1.6666666666666667),
#  ('pages', 1.6666666666666667),
#  ('ships', 1.6666666666666667),
#  ('level', 1.6666666666666667),
#  ('cover', 1.6666666666666667),
#  ('waves', 1.6666666666666667),
#  ('unzip', 1.6666666666666667),
#  ('oomph', 1.6666666666666667),
#  ('getup', 1.6666666666666667),
#  ('venue', 1.6666666666666667),
#  ('peaty', 1.6666666666666667),
#  ('humpy', 1.6666666666666667),
#  ('nappy', 1.6666666666666667),
#  ('vizor', 1.6666666666666667),
#  ('yipes', 1.6666666666666667),
#  ('divot', 1.6666666666666667),
#  ('vetch', 1.6666666666666667),
#  ('unpin', 1.6666666666666667),
#  ('julep', 1.6666666666666667),
#  ('sushi', 1.6666666666666667),
#  ('kaput', 1.6666666666666667),
#  ('spiel', 1.6666666666666667),
#  ('viols', 1.6666666666666667),
#  ('epoxy', 1.6666666666666667),
#  ('lapis', 1.6666666666666667),
#  ('nosey', 1.6666666666666667),
#  ('paean', 1.6666666666666667),
#  ('riven', 1.6666666666666667),
#  ('unset', 1.6666666666666667),
#  ('prigs', 1.6666666666666667),
#  ('bebop', 1.6666666666666667),
#  ('tempi', 1.6666666666666667),
#  ('rapes', 1.6666666666666667),
#  ('guava', 1.6666666666666667),
#  ('scarp', 1.6666666666666667),
#  ('sepia', 1.6666666666666667),
#  ('prams', 1.6666666666666667),
#  ('verso', 1.6666666666666667),
#  ('blips', 1.6666666666666667),
#  ('clave', 1.6666666666666667),
#  ('chump', 1.6666666666666667),
#  ('trump', 1.6666666666666667),
#  ('chomp', 1.6666666666666667),
#  ('purty', 1.6666666666666667),
#  ('maser', 1.6666666666666667),
#  ('patsy', 1.6666666666666667),
#  ('rusks', 1.6666666666666667),
#  ('avast', 1.6666666666666667),
#  ('shish', 1.6666666666666667),
#  ('payer', 1.6666666666666667),
#  ('sappy', 1.6666666666666667),
#  ('septa', 1.6666666666666667),
#  ('peaky', 1.6666666666666667),
#  ('payee', 1.6666666666666667),
#  ('spoof', 1.6666666666666667),
#  ('phyla', 1.6666666666666667),
#  ('sumps', 1.6666666666666667),
#  ('crypt', 1.6666666666666667),
#  ('calve', 1.6666666666666667),
#  ('vibes', 1.6666666666666667),
#  ('gassy', 1.6666666666666667),
#  ('nervy', 1.6666666666666667),
#  ('recap', 1.6666666666666667),
#  ('typos', 1.6666666666666667),
#  ('polly', 1.6666666666666667),
#  ('pates', 1.6666666666666667),
#  ...]

# %% [markdown]
# #### Final Test

# %%
# This will possibly take up to 2 minutes to run
answer = random_word()
work_out_word(answer, True)
print(f"Answer: {answer}")
# Out:
# tares
# sonly
# Final Guess: soyas
# Number of guesses: 3
# Answer: soyas

# %% [markdown]
# #### Real World Test

# %%
# First Guess
guess_info = wordle_guess("tares","___ra")
print(guess_info)
remaining_words = filter_words(words, *guess_info)
print(len(remaining_words))
word_scores = get_word_scores(words, remaining_words, guess_info)
word_scores[:5]
# Out:
# ({}, {('r', 2), ('a', 1)}, {'t', 'e', 's'}, {}, {})
# 102
# [('blond', 6.0588235294117645),
#  ('bland', 6.411764705882353),
#  ('crony', 6.450980392156863),
#  ('bronc', 6.450980392156863),
#  ('irony', 6.490196078431373)]

# %%
# Second Guess
guess_info = merge_guess_info(guess_info, wordle_guess("blond", "___n_"))
print(guess_info)
remaining_words = filter_words(words, *guess_info)
print(remaining_words)
word_scores = get_word_scores(words, remaining_words, guess_info)
word_scores[:5]
# Out:
# ({3: 'n'}, {('r', 2), ('a', 1)}, {'l', 'e', 'o', 'b', 's', 't', 'd'}, {}, {})
# ['crank', 'frank', 'franc', 'prank']
# [('force', 1.0),
#  ('facts', 1.0),
#  ('chief', 1.0),
#  ('crops', 1.0),
#  ('faces', 1.0)]

# %%
guess_info = merge_guess_info(guess_info, wordle_guess("force", "rc   "))
print(guess_info)
remaining_words = filter_words(remaining_words, *guess_info)
remaining_words
# Out:
# ({3: 'n'}, {('r', 2), ('c', 3), ('a', 1)}, {'e', 'b', 't', 'f', 'd', 'l', 'o', 's'}, {}, {})
# ['crank']

# %% [markdown]
# CRANK was correct.

# %% [markdown]
# ---

# %%
guess_info = merge_guess_info(None, wordle_guess("tares", "re___"))
remaining_words = filter_words(words, *guess_info)
word_scores = get_word_scores(words, remaining_words, guess_info)
print(word_scores[:5])
print(len(remaining_words))
# Out:
# [('moire', 6.877551020408164), ('bride', 7.326530612244898), ('noire', 7.408163265306122), ('oldie', 7.714285714285714), ('guide', 7.877551020408164)]
# 98

# %%
guess_info = merge_guess_info(guess_info, wordle_guess("moire", "e__r_"))
remaining_words = filter_words(words, *guess_info)
word_scores = get_word_scores(words, remaining_words, guess_info)
print(word_scores[:5])
print(len(remaining_words))
print(remaining_words)
print(guess_info)
# Out:
# [('blend', 1.2), ('rebel', 1.2), ('beech', 1.2), ('bleed', 1.2), ('elude', 1.2)]
# 10
# ['every', 'clerk', 'query', 'henry', 'decry', 'heerd', 'leery', 'refry', 'exurb', 'beery']
# ({3: 'r'}, {('e', 4), ('e', 3), ('r', 2)}, {'a', 'o', 's', 't', 'i', 'm'}, {}, {})

# %%
guess_info = merge_guess_info(guess_info, wordle_guess("blend", "__e__"))
remaining_words = filter_words(words, *guess_info)
word_scores = get_word_scores(words, remaining_words, guess_info)
print(word_scores[:5])
# Out:
# [('there', 1.0), ('about', 1.0), ('would', 1.0), ('these', 1.0), ('could', 1.0)]

# %%
remaining_words
# Out:
# ['every', 'query']

# %%
guess_info = merge_guess_info(guess_info, wordle_guess("there", "__er_"))
remaining_words = filter_words(words, *guess_info)

# %%
remaining_words
# Out:
# ['query']

# %%
guess_info = wordle_guess("____u", "u    ")
remaining_words = filter_words(words, *guess_info)

# %%
remaining_words
# Out:
# ['about',
#  'would',
#  'could',
#  'sound',
#  'found',
#  'under',
#  'house',
#  'until',
#  'study',
#  'young',
#  'music',
#  'using',
#  'group',
#  'built',
#  'quite',
#  'round',
#  'hours',
#  'human',
#  'build',
#  'mouth',
#  'value',
#  'south',
#  'equal',
#  'guess',
#  'cause',
#  'quiet',
#  'sugar',
#  'rules',
#  'units',
#  'fruit',
#  'nouns',
#  'turns',
#  'touch',
#  'count',
#  'quick',
#  'truck',
#  'upper',
#  'usual',
#  'proud',
#  'court',
#  'truth',
#  'lunch',
#  'doubt',
#  'guide',
#  'cloud',
#  'funny',
#  'hurry',
#  'ought',
#  'rough',
#  'laugh',
#  'occur',
#  'outer',
#  'ruler',
#  'youth',
#  'brush',
#  'judge',
#  'begun',
#  'bound',
#  'aloud',
#  'pound',
#  'fully',
#  'flour',
#  'curve',
#  'queen',
#  'union',
#  'issue',
#  'guard',
#  'yours',
#  'burst',
#  'route',
#  'lungs',
#  'uncle',
#  'mouse',
#  'tough',
#  'stuck',
#  'truly',
#  'swung',
#  'lucky',
#  'tubes',
#  'wound',
#  'trunk',
#  'juice',
#  'trust',
#  'adult',
#  'stuff',
#  'thumb',
#  'shout',
#  'ruled',
#  'crust',
#  'fault',
#  'ducks',
#  'pulls',
#  'drums',
#  'drugs',
#  'pause',
#  'clues',
#  'burnt',
#  'sunny',
#  'guest',
#  'suits',
#  'upset',
#  'unity',
#  'bunch',
#  'funds',
#  'pupil',
#  'cruel',
#  'urged',
#  'queer',
#  'input',
#  'cubic',
#  'burns',
#  'rural',
#  'clubs',
#  'muddy',
#  'dusty',
#  'humor',
#  'fungi',
#  'focus',
#  'puppy',
#  'jumps',
#  'quart',
#  'flung',
#  'urban',
#  'minus',
#  'tunes',
#  'crude',
#  'flute',
#  'skull',
#  'argue',
#  'ruins',
#  'cubes',
#  'purse',
#  'sauce',
#  'fluid',
#  'buses',
#  'drunk',
#  'tuned',
#  'clung',
#  'gauge',
#  'gulls',
#  'thump',
#  'dough',
#  'punch',
#  'lunar',
#  'pulse',
#  'mount',
#  'usage',
#  'rusty',
#  'vague',
#  'mound',
#  'mules',
#  'virus',
#  'scout',
#  'acute',
#  'stout',
#  'pluck',
#  'dunes',
#  'burro',
#  'trout',
#  'souls',
#  'buggy',
#  'pumps',
#  'syrup',
#  'curly',
#  'couch',
#  'ounce',
#  'utter',
#  'fours',
#  'bugle',
#  'hound',
#  'lumps',
#  'pours',
#  'curse',
#  'plump',
#  'curls',
#  'blues',
#  'stump',
#  'juicy',
#  'bulbs',
#  'fuels',
#  'suite',
#  'quilt',
#  'scrub',
#  'tusks',
#  'bulls',
#  'humid',
#  'guilt',
#  'quote',
#  'clump',
#  'tumor',
#  'unite',
#  'cough',
#  'pouch',
#  'buyer',
#  'users',
#  'blunt',
#  'nurse',
#  'cured',
#  'bluff',
#  'bonus',
#  'quest',
#  'glued',
#  'bulky',
#  'stunt',
#  'flush',
#  'genus',
#  'spout',
#  'fumes',
#  'cuffs',
#  'super',
#  'furry',
#  'stung',
#  'serum',
#  'slums',
#  'puffs',
#  'mourn',
#  'abuse',
#  'quack',
#  'aunts',
#  'gaunt',
#  'chuck',
#  'surge',
#  'hurts',
#  'husky',
#  'hunts',
#  'spurs',
#  'strum',
#  'humus',
#  'shrub',
#  'amuse',
#  'slung',
#  'crush',
#  'plums',
#  'bushy',
#  'squad',
#  'tutor',
#  'bumps',
#  'snout',
#  'urine',
#  'tulip',
#  'budge',
#  'fudge',
#  'quail',
#  'bough',
#  'quill',
#  'chunk',
#  'fuzzy',
#  'mucus',
#  'awful',
#  'churn',
#  'bully',
#  'curds',
#  'bulge',
#  'bunks',
#  'squat',
#  'dummy',
#  'fauna',
#  'squid',
#  'vault',
#  'pupae',
#  'ducts',
#  'plumb',
#  'nudge',
#  'rouse',
#  'chute',
#  'gusts',
#  'debut',
#  'quota',
#  'untie',
#  'blush',
#  'squaw',
#  'brute',
#  'undue',
#  'curry',
#  'pious',
#  'plugs',
#  'grubs',
#  'mummy',
#  'auger',
#  'buddy',
#  'gully',
#  'mumps',
#  'gauze',
#  'fussy',
#  'gouge',
#  'unfit',
#  'lousy',
#  'album',
#  'murky',
#  'burly',
#  'spurt',
#  'humps',
#  'rumor',
#  'opium',
#  'husks',
#  'fraud',
#  'scuba',
#  'tours',
#  'gaudy',
#  'shrug',
#  'tufts',
#  'truss',
#  'muted',
#  'cures',
#  'yucca',
#  'fuses',
#  'bucks',
#  'urges',
#  'sunup',
#  'menus',
#  'quake',
#  'erupt',
#  'slump',
#  'purge',
#  'fluff',
#  'strut',
#  'plume',
#  'soups',
#  'dully',
#  'fused',
#  'mused',
#  'bouts',
#  'shuts',
#  'putty',
#  'guppy',
#  'dusky',
#  'haunt',
#  'undid',
#  'pussy',
#  'gruff',
#  'musty',
#  'snuff',
#  'hunch',
#  'truce',
#  'autos',
#  'studs',
#  'grunt',
#  'slugs',
#  'ruddy',
#  'taunt',
#  'prune',
#  'lusty',
#  'usher',
#  'tucks',
#  'dumps',
#  'ulcer',
#  'guile',
#  'burrs',
#  'saucy',
#  'muggy',
#  'lured',
#  'wrung',
#  'forum',
#  'guild',
#  'hauls',
#  'cluck',
#  'lunge',
#  'queue',
#  'outdo',
#  'crumb',
#  'jumpy',
#  'buoys',
#  'stubs',
#  'lucid',
#  'hulls',
#  'gulps',
#  'skunk',
#  'exult',
#  'plush',
#  'unify',
#  'butts',
#  'gulfs',
#  'curbs',
#  'lures',
#  'vogue',
#  'tunic',
#  'dumpy',
#  'lurch',
#  'guise',
#  'junks',
#  'scuff',
#  'truer',
#  'rouge',
#  'sulky',
#  'recur',
#  'surer',
#  'gusty',
#  'equip',
#  'fumed',
#  'clout',
#  'bunny',
#  'surly',
#  'purer',
#  'query',
#  'gruel',
#  'puffy',
#  'louse',
#  'feuds',
#  'thuds',
#  'quirk',
#  'rugby',
#  'glues',
#  'lotus',
#  'lurid',
#  'rungs',
#  'hutch',
#  'mushy',
#  'rumps',
#  'fetus',
#  'rusts',
#  'chugs',
#  'juror',
#  'gummy',
#  'butte',
#  'rogue',
#  'quays',
#  'duets',
#  'ultra',
#  'suede',
#  'mauve',
#  'chums',
#  'scour',
#  'suing',
#  'coupe',
#  'munch',
#  'jumbo',
#  'spunk',
#  'cubed',
#  'slurs',
#  'pumas',
#  'dukes',
#  'fouls',
#  'brunt',
#  'tuber',
#  'mulch',
#  'udder',
#  'quits',
#  'pulpy',
#  'busts',
#  'mutes',
#  'shuns',
#  'lulls',
#  'buffs',
#  'elude',
#  'bulks',
#  'dusts',
#  'quell',
#  'lurks',
#  'lutes',
#  'umbra',
#  'upped',
#  'shush',
#  'slush',
#  'sulfa',
#  'vouch',
#  'runts',
#  'datum',
#  'musky',
#  'ovule',
#  'lemur',
#  'dudes',
#  'ensue',
#  'dulls',
#  'sinus',
#  'duped',
#  'punks',
#  'duels',
#  'ruffs',
#  'gauss',
#  'jaunt',
#  'gauzy',
#  'huffs',
#  'hulks',
#  'bluer',
#  'pupas',
#  'flunk',
#  'douse',
#  'blurs',
#  'slunk',
#  'sirup',
#  'squab',
#  'etude',
#  'sucks',
#  'sulks',
#  'croup',
#  'junky',
#  'gumbo',
#  'daunt',
#  'hunks',
#  'buxom',
#  'unbar',
#  'routs',
#  'culls',
#  'lucks',
#  'stunk',
#  'snubs',
#  'usurp',
#  'blurb',
#  'daubs',
#  'sours',
#  'stuns',
#  'musts',
#  'rummy',
#  'skulk',
#  'quaff',
#  'kudos',
#  'scull',
#  'punts',
#  'hurls',
#  'musks',
#  'bused',
#  'cruet',
#  'muses',
#  'shuck',
#  'prude',
#  'scums',
#  'tubas',
#  'qualm',
#  'gluts',
#  'dunce',
#  'tunas',
#  'gushy',
#  'huger',
#  'flues',
#  'pouts',
#  'yules',
#  'mutts',
#  'spuds',
#  'dupes',
#  'clued',
#  'cuter',
#  'cupid',
#  'mauls',
#  'beaus',
#  'alums',
#  'grump',
#  'mulls',
#  'ruder',
#  'ousts',
#  'pucks',
#  'gulch',
#  'suets',
#  'turfs',
#  'quips',
#  'flout',
#  'putts',
#  'blurt',
#  'dunks',
#  'jutes',
#  'surfs',
#  'dusks',
#  'furls',
#  'murks',
#  'slues',
#  'purrs',
#  'bunts',
#  'ruses',
#  'judos',
#  'pulps',
#  'lauds',
#  'mucks',
#  'fugue',
#  'gourd',
#  'bumpy',
#  'cubit',
#  'annum',
#  'setup',
#  'junta',
#  'audio',
#  'fluke',
#  'humph',
#  'mould',
#  'azure',
#  'locus',
#  'lumpy',
#  'tuner',
#  'mural',
#  'quoth',
#  'sumac',
#  'unwed',
#  'duple',
#  'revue',
#  'cults',
#  'gamut',
#  'dunno',
#  'incur',
#  'tummy',
#  'bogus',
#  'gusto',
#  'spurn',
#  'rebut',
#  'quirt',
#  'hullo',
#  'pique',
#  'uncut',
#  'louis',
#  'quint',
#  'clunk',
#  'nutty',
#  'gunny',
#  'runic',
#  'rupee',
#  'yummy',
#  'soupy',
#  'ghoul',
#  'cumin',
#  'quire',
#  'thugs',
#  'furor',
#  'runes',
#  'annul',
#  'audit',
#  'letup',
#  'fount',
#  'amuck',
#  'umber',
#  'pudgy',
#  'umped',
#  'slurp',
#  'puree',
#  'coups',
#  'afoul',
#  'suave',
#  'curvy',
#  'tulle',
#  'curio',
#  'demur',
#  'cusps',
#  'quads',
#  'saute',
#  'aught',
#  'ducal',
#  'bulgy',
#  'lusts',
#  'unary',
#  'brung',
#  'huffy',
#  'shunt',
#  'femur',
#  'mousy',
#  'vaunt',
#  'cutie',
#  'joust',
#  'nukes',
#  'blued',
#  'tubby',
#  'unzip',
#  'funky',
#  'ducat',
#  'getup',
#  'runty',
#  'venue',
#  'louts',
#  'humpy',
#  'beaut',
#  'unfed',
#  'rebus',
#  'squib',
#  'zebus',
#  'knurl',
#  'runny',
#  'unpin',
#  'julep',
#  'nudes',
#  'sushi',
#  'kaput',
#  'butch',
#  'hulas',
#  'outgo',
#  'fudgy',
#  'segue',
#  'turbo',
#  'moult',
#  'rumen',
#  'cruse',
#  'abuts',
#  'ennui',
#  'unset',
#  'augur',
#  'odium',
#  'kraut',
#  'aural',
#  'snuck',
#  'guava',
#  'tufty',
#  'hubba',
#  'joule',
#  'cubby',
#  'lumen',
#  'chump',
#  'trump',
#  'purty',
#  'rusks',
#  'hubby',
#  'quasi',
#  'imbue',
#  'sumps',
#  'inure',
#  'outen',
#  'ducky',
#  'unlit',
#  'ouija',
#  'gurus',
#  'rerun',
#  'surds',
#  'nulls',
#  'mogul',
#  'debug',
#  'talus',
#  'hokum',
#  'furze',
#  'curie',
#  'nutsy',
#  'hilum',
#  'burls',
#  'flume',
#  'lubes',
#  'butyl',
#  'donut',
#  'wurst',
#  'quash',
#  'quals',
#  'cushy',
#  'puked',
#  'frump',
#  'pukes',
#  'duffs',
#  'bruin',
#  'reuse',
#  'cutup',
#  'agues',
#  'upend',
#  'numbs',
#  'rubes',
#  'hocus',
#  'bunco',
#  'yucky',
#  'scuzz',
#  'souse',
#  'pinup',
#  'vagus',
#  'gulag',
#  'bosun',
#  'educe',
#  'auras',
#  'gouty',
#  'druid',
#  'situs',
#  'unjam',
#  'torus',
#  'recut',
#  'caulk',
#  'sully',
#  'tuxes',
#  'rutty',
#  'grout',
#  'hussy',
#  'amour',
#  'durst',
#  'tutus',
#  'mixup',
#  'flubs',
#  'aquas',
#  'exude',
#  'hulky',
#  'nexus',
#  'lulus',
#  'poufs',
#  'roust',
#  'burgs',
#  'unmet',
#  'cuspy',
#  'quark',
#  'fungo',
#  'sutra',
#  'busty',
#  'odour',
#  'sluff',
#  'houri',
#  'gutsy',
#  'pushy',
#  'drubs',
#  'mufti',
#  'burps',
#  'deuce',
#  'duper',
#  'muffs',
#  'sauna',
#  'usury',
#  'muxes',
#  'umpty',
#  'luaus',
#  'touts',
#  'nuked',
#  'sluts',
#  'futon',
#  'tuple',
#  'duals',
#  'klutz',
#  'suras',
#  'dutch',
#  'mucky',
#  'layup',
#  'duvet',
#  'sudsy',
#  'suety',
#  'gouda',
#  'taupe',
#  'duchy',
#  'ruble',
#  'quais',
#  'gluey',
#  'outta',
#  'culpa',
#  'fusty',
#  'supra',
#  'buffa',
#  'pukka',
#  'tagua',
#  'haute',
#  'modus',
#  'bueno',
#  'rheum',
#  'scurf',
#  'sprue',
#  'plumy',
#  'yourn',
#  'spume',
#  'mucho',
#  'spued',
#  'harum',
#  'laude',
#  'thrum',
#  'gigue',
#  'humpf',
#  'youse',
#  'lubra',
#  'mecum',
#  'coqui',
#  'ouzel',
#  'klunk',
#  'summa',
#  'purls',
#  'lulab',
#  'toque',
#  'fugit',
#  'plunk',
#  'lucre',
#  'injun',
#  'feued',
#  'baulk',
#  'casus',
#  'scrum',
#  'scuse',
#  'feuar',
#  'juste',
#  'ukase',
#  'beaux',
#  'tusky',
#  'musta',
#  'quiff',
#  'tuans',
#  'mahua',
#  'curia',
#  'fucks',
#  'russe',
#  'tutti',
#  'pruta',
#  'unsee',
#  'ileum',
#  'thunk',
#  'shute',
#  'uncap',
#  'turps',
#  'solum',
#  'mumbo',
#  'unbox',
#  'vacuo',
#  'slued',
#  'muser',
#  'endue',
#  'ileus',
#  'busby',
#  'buffo',
#  'bruit',
#  'punky',
#  'aquae',
#  'bunds',
#  'degum',
#  'unman',
#  'dungy',
#  'bunko',
#  'ulnas',
#  'deque',
#  'fulls',
#  'churl',
#  'whump',
#  'duces',
#  'unrig',
#  'quids',
#  'gunks',
#  'smuts',
#  'yurts',
#  'exurb',
#  'nuder',
#  'nurbs',
#  'scudi',
#  'mungs',
#  'muons',
#  'ureas',
#  'unhip',
#  'uvula',
#  'unapt',
#  'buret',
#  'oakum',
#  'fusee',
#  'ousel',
#  'umiak',
#  'cuppy',
#  'bumph',
#  'junco',
#  'pubic',
#  'lupus',
#  'sebum',
#  'ajuga',
#  'unsew',
#  'bauds',
#  'cuppa',
#  'chuff',
#  'unarm',
#  'yukky',
#  'guano',
#  'scuds',
#  'klugy',
#  'umbel',
#  'unpeg',
#  'supes',
#  'mujik',
#  'trued',
#  'punny',
#  'fauns',
#  'pseud',
#  'lurer',
#  'magus',
#  'ulnar',
#  'eruct',
#  'vacua',
#  'arums',
#  'tubal',
#  'buzzy',
#  'kulak',
#  'duddy',
#  'fugal',
#  'duomo',
#  'musos',
#  'luvya',
#  'unate',
#  'luxes',
#  'cruft',
#  'quoin',
#  'fumer',
#  'vulva',
#  'lunes',
#  'nudie',
#  'gouts',
#  'stoup',
#  'jujus',
#  'pubes',
#  'defun',
#  'kluge',
#  'tubed',
#  'sputa',
#  'boule',
#  'thous',
#  'quoit',
#  'tecum',
#  'redux',
#  'abuzz',
#  'couth',
#  'trues',
#  'guyed',
#  'fuzes',
#  'hurly',
#  'utero',
#  'unsay',
#  'cunts',
#  'muter',
#  'smurf',
#  'hunky',
#  'busks',
#  'ilium',
#  'mulct',
#  'scudo',
#  'knout',
#  'uteri',
#  'gunky',
#  'urger',
#  'gluon',
#  'ruing',
#  'cauls',
#  ...]

# %%
len(filter_words(words, *wordle_guess("___r_", "   r ")))
# Out:
# 310

# %%
len(filter_words(words, *wordle_guess("oiast", "_____")))
# Out:
# 402

# %%
g1 = wordle_guess("a____", "     ")
len(filter_words(words, *g1))
# Out:
# 3576

# %%
g2 = wordle_guess("i____", "     ")
len(filter_words(words, *g2))
# Out:
# 4218

# %%
len(filter_words(words, *merge_guess_info(g1, g2)))
# Out:
# 2348

# %%
len(words)
# Out:
# 5757

# %%
5757 - 2348
# Out:
# 3409

# %% [markdown]
# #### Unified Class

# %%
class wordle_solver():
    def __init__(self, answer=None):
        self.answer = answer
        with open("sgb-words.txt", "r") as f:
            self.all_words = [w for w in f.read().split("\n") if len(w) == 5]
        
        
    def guess_from_answer(self, guess, answer=None):
        green = {}
        yellow = {}
        red = set()
        bad_duplicates = {}
        good_duplicates = {}

        current_chars = []

        for i in range(5):
            q_char = guess[i]
            current_chars.append(q_char)

            if (q_char in bad_duplicates) or (q_char in red):
                # Letter already used and not present, skip
                continue

            if not q_char in answer:
                # Character is not in word
                red.add(q_char)
                continue

            if answer[i] == q_char:
                # Character is present, and in correct place
                green[i] = q_char
                continue

            # Check whether it is a duplicate letter
            guess_count = current_chars.count(q_char)
            answer_count = answer.count(q_char)
            if answer_count < guess_count:
                # Letter is a duplicate, and the subsequent one is not in answer
                bad_duplicates[q_char] = guess_count
                continue
            elif guess_count > 1:
                good_duplicates[q_char] = guess_count

            # Letter must be present in answer, but in wrong place.
            if q_char not in yellow:
                yellow[q_char] = set()
            yellow[q_char].add(i)
            continue

        return wordle_guess_info(green, yellow, red, bad_duplicates, good_duplicates)
    
    
    def guess_from_code(self, guess, code):
        green = {}
        yellow = set()
        red = set()
        bad_duplicates = {}
        good_duplicates = {}

        current_chars = []

        for i in range(len(code)):
            char = guess[i]

            if code[i] in "Gg":
                green[i] = char

            elif code[i] in "Yy":
                if char not in yellow:
                    yellow[char] = set()
                yellow[char].add(i)
                if char in current_chars:
                    good_duplicates[char] = current_chars.count(char) + 1

            elif code[i] in "Rr_":
                if char in current_chars:
                    if char not in bad_duplicates:
                        bad_duplicates[char] = current_chars.count(char) + 1

                else :
                    red.add(char)

            current_chars.append(char)

        return wordle_guess_info(green, yellow, red, bad_duplicates, good_duplicates)
    
    
    def get_word_scores(self, remaining_words, current_info=None):
        results = []
        for assumed_guess in self.all_words:
            guess_results = []
            for assumed_answer in remaining_words:
                assumed_info = self.guess_from_answer(assumed_guess, assumed_answer) + current_info
                assumed_remaining_words = self.filter_words(remaining_words, assumed_info)
                guess_results.append(len(assumed_remaining_words))

            score = stats.mean(guess_results)
            results.append( (assumed_guess, score) )
        return sorted(results, key=lambda x: x[1])
    
    
    def filter_words(self, remaining_words, info):
        return [word for word in remaining_words if self.check_word(word, info)]
                    
        
    def check_word(self, word, info):
        for i in info.green:
            if word[i] != info.green[i]:
                return False
            
        for char in info.yellow:
            for i in info.yellow[char]:
                if word[i] == char:
                    return False
                
        for char in info.red:
            if char in word:
                return False
            
        for char in info.bad_duplicates:
            if word.count(char) >= info.bad_duplicates[char]:
                return False
            
        for char in info.good_duplicates:
            if word.count(char) < info.good_duplicates[char]:
                return False
            
        return True
    
    
    def solve(self, verbose=False):
        if answer == None:
            print("No answer specified. Cannot solve.")
            return
        
        guess = "tares"
        guesses = [guess]
        info = self.guess_from_answer(guess, self.answer)
        remaining_words = self.filter_words(self.all_words, info)
        
        while len(remaining_words) > 1:
            if verbose:
                print(f"Guess: {guess} - Remaining Words: {len(remaining_words)}")
            word_scores = self.get_word_scores(remaining_words, info)
            guess = word_scores[0][0]
            guesses.append(guess)
            info = self.guess_from_answer(guess, self.answer) + info
            remaining_words = self.filter_words(remaining_words, info)
            
        print(f"Answer: {remaining_words[0]}")
        print(f"Guesses: {len(guesses)}")
        return len(guesses)
    
    
    def manual_guess(self, guess):
        guess = guess.lower()
        response = ""
        for i in range(len(guess)):
            char = guess[i]
            if char == self.answer[i]:
                response += char.upper()
            elif char not in self.answer:
                response += "-"
            else:
                if answer.count(char) > response.lower().count(char):
                    response += char
                else:
                    response += "-"
        print(response)

# %%
ws = wordle_solver("banal")

# %%
ws.manual_guess("henna")
# Out:
# --N-a

# %%
ws.manual_guess("banan")
# Out:
# BANA-

# %%
class wordle_guess_info():
    def __init__(self, green={}, yellow={}, red=set(), bad_duplicates={}, good_duplicates={}):
        self.green = green
        self.yellow = yellow
        self.red = red
        self.bad_duplicates = bad_duplicates
        self.good_duplicates = good_duplicates
        
    def __add__(self, info):
        if info == None:
            return self
        elif type(info) != type(self):
            raise Exception(f"Can only add wordle_guess_info to similar objects, not to type {type(info)}.")
        
        green = {**self.green, **info.green}
        red = self.red.union(info.red)
        bad_duplicates = {**self.bad_duplicates, **info.bad_duplicates}
        
        # Good duplicate propogation        
        good_duplicates = self.good_duplicates
        for key in info.good_duplicates:
            if key in good_duplicates:
                good_duplicates[key] = max(self.good_duplicates[key],
                                           info.good_duplicates[key])
            else:
                good_duplicates[key] = info.good_duplicates[key]
        
        # Yellow propogation
        yellow = {}
        for d in (self.yellow, info.yellow):
            for char in d:
                if char not in yellow:
                    yellow[char] = set()
                yellow[char].update(d[char])
                
        return wordle_guess_info(green, yellow, red, bad_duplicates, good_duplicates)
                
    def __str__(self):
        return f"{self.green}, {self.yellow}, {self.red}, {self.bad_duplicates}, {self.good_duplicates}"

# %%
wgi+1
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-119-fda5b1212d00> in <module>
# ----> 1 wgi+1
#
# <ipython-input-114-a63f3c512ce3> in __add__(self, info)
#      11             return self
#      12         elif type(info) != type(self):
# ---> 13             raise Exception(f"Can only add wordle_guess_info to similar objects, not to type {type(info)}.")
#      14
#      15         green = {**self.green, **info.green}
#
# Exception: Can only add wordle_guess_info to similar objects, not to type <class 'int'>.

# %%
info = wordle_guess("henna", "banal")
info
# Out:
# ({2: 'n'}, {('a', 4)}, {'e', 'h'}, {'n': 2}, {})

# %%
wgi = wordle_guess_info(info[0], {"a": set([4])}, info[2], info[3], info[4])
print(wgi)
# Out:
# {2: 'n'}, {'a': {4}}, {'e', 'h'}, {'n': 2}, {}

# %%
info2 = wordle_guess("manly", "banal")
info2
# Out:
# ({1: 'a', 2: 'n'}, {('l', 3)}, {'m', 'y'}, {}, {})

# %%
wgi2 = wordle_guess_info(info2[0], {"l": set([3])}, info2[2], info2[3], info2[4])
print(wgi2)
# Out:
# {1: 'a', 2: 'n'}, {'l': {3}}, {'m', 'y'}, {}, {}

# %%
wgi3 = wgi + wgi2

# %%
print(wgi3)
# Out:
# {2: 'n', 1: 'a'}, {'a': {4}, 'l': {3}}, {'e', 'm', 'y', 'h'}, {'n': 2}, {}

# %%
print(info)
# Out:
# ({2: 'n'}, {('a', 4)}, {'e', 'h'}, {'n': 2}, {})

# %%
print(avaad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-58ab7a860e12> in <module>
# ----> 1 print(avaad)
#
# NameError: name 'avaad' is not defined

# %%
"a".upper()
# Out:
# 'A'

# %%
"-----"
# Out:
# '-----'
